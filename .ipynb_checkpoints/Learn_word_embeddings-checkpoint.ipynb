# %%
# Here I am using gensim for learning the word embeddings from the EUADR corpus
# This is just a rough start to learn 
import gensim
import logging
import os
import pandas as pd

# %%
# start the log
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO)

# %%
# get the current working directory
data_path = '/home/stirunag/Work/OTAR dumps/'

# Although the dataset says csv, it is tab delimited. In addition to this, they have severe codels problems. 
# So best to parse throught codes first. 
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 2: invalid start byte

#open for reading with "universal" type set

import codecs

sentences_t = codecs.open(data_path+'OTAR_sentences'+'.csv','rU','UTF-8') 
met_gen_sentences = pd.read_csv(sentences_t, header = None)

logging.info("Done reading data files")
# Out:
# 2019-08-08 17:08:38,378 : INFO : Done reading data files

# %%
met_gen_sentences.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
sentences =  met_gen_sentences[6].values.tolist()

# %%
sentences[1:10]
# Out:
# ['Tyrosine aminotransferase induction in normal and tumor-bearing chickens.',
#  'Tyrosine aminotransferase (TAT) induction by glucagon and dexamethasone in the liver of tumor-bearing chickens was studied and compared with induction in healthy animals.',
#  'The value of a histamine H2-receptor antagonist in the management of patients with the Zollinger-Ellison syndrome.',
#  'Metiamide an histamine H2-receptors antagonist has been used to treat a case of Zollinger-Ellison syndrome characterized by a long standing diarrhea, an important gastric hypersecretion and a moderatly elevated plasma gastrin but without digestive ulceration.',
#  'Metiamide an histamine H2-receptors antagonist has been used to treat a case of Zollinger-Ellison syndrome characterized by a long standing diarrhea, an important gastric hypersecretion and a moderatly elevated plasma gastrin but without digestive ulceration.',
#  'A simple and convenient colorimetric method is described for the quantitative determination of 5-aminosalicylic acid (5-ASA) and N-acetyl-5-ASA in urine and feces after oral administration of salicylazosulfa-pyridine (SASP), the drug of choice in the treatment of ulcerative colitis.',
#  'Discussion: Metachromatic leukodystrophy, an unusual case with a subtle cerebroside sulfatase defect.',
#  'Acetylcholinesterase in atopic skin in relation to the B blockade model of atopy.',
#  'Results from our study suggest an intricate nature of this dysmetabolic disorder, which shows ultrastructural changes usually seen in classic MLD, a deficiency of arylsulfatase A only, concomitant with those seen in mucopolysaccharidoses such as Hurler and Sanfilippo syndromes.']

# %%
#########################  tokenisation ###############################################
documents = []
for row in sentences:
    try:
        documents.append(row.split())
    except AttributeError:
        pass

# %%
documents[1:3]
# Out:
# [['tyrosine',
#   'aminotransferase',
#   'induction',
#   'in',
#   'normal',
#   'and',
#   'tumor-bearing',
#   'chickens.'],
#  ['tyrosine',
#   'aminotransferase',
#   '(tat)',
#   'induction',
#   'by',
#   'glucagon',
#   'and',
#   'dexamethasone',
#   'in',
#   'the',
#   'liver',
#   'of',
#   'tumor-bearing',
#   'chickens',
#   'was',
#   'studied',
#   'and',
#   'compared',
#   'with',
#   'induction',
#   'in',
#   'healthy',
#   'animals.']]

# %%
from gensim.models import Word2Vec, Phrases, phrases, KeyedVectors


# OTAR_wv = KeyedVectors.load_word2vec_format('/home/santosh/pre-trained_word_embeddings/PubMed-and-PMC-w2v.bin', binary=True)

# min_count = 3
# model = Word2Vec(size=200, min_count=min_count, iter=10, window=10, workers=10)
# model.build_vocab(documents)
# training_examples_count = model.corpus_count
# # below line will make it 1, so saving it before
# model.build_vocab([list(PMC_wv.vocab.keys())], update=True)
# model.intersect_word2vec_format("/home/santosh/pre-trained_word_embeddings/PubMed-and-PMC-w2v.bin", binary=True, lockf=1.0)
# model.train(sentences, total_examples=training_examples_count, epochs=model.iter)


model = gensim.models.Word2Vec(
    documents,
    size=300,
    window=10,
    min_count=5,
    workers=10)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# 2019-08-08 17:12:18,600 : INFO : collecting all words and their counts
# 2019-08-08 17:12:18,601 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-08-08 17:12:18,652 : INFO : PROGRESS: at sentence #10000, processed 286780 words, keeping 23499 word types
# 2019-08-08 17:12:18,691 : INFO : PROGRESS: at sentence #20000, processed 580541 words, keeping 37545 word types
# 2019-08-08 17:12:18,729 : INFO : PROGRESS: at sentence #30000, processed 868154 words, keeping 48600 word types
# 2019-08-08 17:12:18,765 : INFO : PROGRESS: at sentence #40000, processed 1155859 words, keeping 59047 word types
# 2019-08-08 17:12:18,804 : INFO : PROGRESS: at sentence #50000, processed 1446157 words, keeping 68094 word types
# 2019-08-08 17:12:18,842 : INFO : PROGRESS: at sentence #60000, processed 1729910 words, keeping 76434 word types
# 2019-08-08 17:12:18,881 : INFO : PROGRESS: at sentence #70000, processed 2016700 words, keeping 84576 word types
# 2019-08-08 17:12:18,920 : INFO : PROGRESS: at sentence #80000, processed 2305593 words, keeping 91899 word types
# 2019-08-08 17:12:18,961 : INFO : PROGRESS: at sentence #90000, processed 2588622 words, keeping 99634 word types
# 2019-08-08 17:12:19,001 : INFO : PROGRESS: at sentence #100000, processed 2870356 words, keeping 106552 word types
# 2019-08-08 17:12:19,042 : INFO : PROGRESS: at sentence #110000, processed 3156042 words, keeping 113482 word types
# 2019-08-08 17:12:19,084 : INFO : PROGRESS: at sentence #120000, processed 3444617 words, keeping 120053 word types
# 2019-08-08 17:12:19,125 : INFO : PROGRESS: at sentence #130000, processed 3731806 words, keeping 126484 word types
# 2019-08-08 17:12:19,166 : INFO : PROGRESS: at sentence #140000, processed 4016600 words, keeping 132702 word types
# 2019-08-08 17:12:19,207 : INFO : PROGRESS: at sentence #150000, processed 4301244 words, keeping 138943 word types
# 2019-08-08 17:12:19,248 : INFO : PROGRESS: at sentence #160000, processed 4582264 words, keeping 144706 word types
# 2019-08-08 17:12:19,289 : INFO : PROGRESS: at sentence #170000, processed 4864628 words, keeping 150627 word types
# 2019-08-08 17:12:19,330 : INFO : PROGRESS: at sentence #180000, processed 5150626 words, keeping 155958 word types
# 2019-08-08 17:12:19,372 : INFO : PROGRESS: at sentence #190000, processed 5433088 words, keeping 161470 word types
# 2019-08-08 17:12:19,412 : INFO : PROGRESS: at sentence #200000, processed 5712188 words, keeping 167018 word types
# 2019-08-08 17:12:19,454 : INFO : PROGRESS: at sentence #210000, processed 5995200 words, keeping 172595 word types
# 2019-08-08 17:12:19,497 : INFO : PROGRESS: at sentence #220000, processed 6280267 words, keeping 177874 word types
# 2019-08-08 17:12:19,537 : INFO : PROGRESS: at sentence #230000, processed 6562500 words, keeping 183029 word types
# 2019-08-08 17:12:19,577 : INFO : PROGRESS: at sentence #240000, processed 6841758 words, keeping 188258 word types
# 2019-08-08 17:12:19,617 : INFO : PROGRESS: at sentence #250000, processed 7126746 words, keeping 193108 word types
# 2019-08-08 17:12:19,660 : INFO : PROGRESS: at sentence #260000, processed 7419390 words, keeping 198119 word types
# 2019-08-08 17:12:19,702 : INFO : PROGRESS: at sentence #270000, processed 7711428 words, keeping 203018 word types
# 2019-08-08 17:12:19,743 : INFO : PROGRESS: at sentence #280000, processed 7990872 words, keeping 207899 word types
# 2019-08-08 17:12:19,784 : INFO : PROGRESS: at sentence #290000, processed 8271115 words, keeping 212683 word types
# 2019-08-08 17:12:19,827 : INFO : PROGRESS: at sentence #300000, processed 8558064 words, keeping 217348 word types
# 2019-08-08 17:12:19,870 : INFO : PROGRESS: at sentence #310000, processed 8846130 words, keeping 222101 word types
# 2019-08-08 17:12:19,914 : INFO : PROGRESS: at sentence #320000, processed 9125771 words, keeping 226721 word types
# 2019-08-08 17:12:19,960 : INFO : PROGRESS: at sentence #330000, processed 9406665 words, keeping 231492 word types
# 2019-08-08 17:12:20,005 : INFO : PROGRESS: at sentence #340000, processed 9692004 words, keeping 236042 word types
# 2019-08-08 17:12:20,047 : INFO : PROGRESS: at sentence #350000, processed 9976879 words, keeping 240469 word types
# 2019-08-08 17:12:20,090 : INFO : PROGRESS: at sentence #360000, processed 10259770 words, keeping 245213 word types
# 2019-08-08 17:12:20,132 : INFO : PROGRESS: at sentence #370000, processed 10549053 words, keeping 249457 word types
# 2019-08-08 17:12:20,173 : INFO : PROGRESS: at sentence #380000, processed 10832398 words, keeping 254125 word types
# 2019-08-08 17:12:20,216 : INFO : PROGRESS: at sentence #390000, processed 11117334 words, keeping 258592 word types
# 2019-08-08 17:12:20,257 : INFO : PROGRESS: at sentence #400000, processed 11397645 words, keeping 262966 word types
# 2019-08-08 17:12:20,299 : INFO : PROGRESS: at sentence #410000, processed 11686294 words, keeping 267233 word types
# 2019-08-08 17:12:20,342 : INFO : PROGRESS: at sentence #420000, processed 11981197 words, keeping 272108 word types
# 2019-08-08 17:12:20,384 : INFO : PROGRESS: at sentence #430000, processed 12264844 words, keeping 276521 word types
# 2019-08-08 17:12:20,426 : INFO : PROGRESS: at sentence #440000, processed 12548694 words, keeping 280752 word types
# 2019-08-08 17:12:20,468 : INFO : PROGRESS: at sentence #450000, processed 12836375 words, keeping 284828 word types
# 2019-08-08 17:12:20,509 : INFO : PROGRESS: at sentence #460000, processed 13119368 words, keeping 288946 word types
# 2019-08-08 17:12:20,551 : INFO : PROGRESS: at sentence #470000, processed 13401365 words, keeping 293160 word types
# 2019-08-08 17:12:20,594 : INFO : PROGRESS: at sentence #480000, processed 13686215 words, keeping 297447 word types
# 2019-08-08 17:12:20,636 : INFO : PROGRESS: at sentence #490000, processed 13969045 words, keeping 301600 word types
# 2019-08-08 17:12:20,678 : INFO : PROGRESS: at sentence #500000, processed 14256929 words, keeping 305552 word types
# 2019-08-08 17:12:20,720 : INFO : PROGRESS: at sentence #510000, processed 14536518 words, keeping 309340 word types
# 2019-08-08 17:12:20,762 : INFO : PROGRESS: at sentence #520000, processed 14819775 words, keeping 313158 word types
# 2019-08-08 17:12:20,805 : INFO : PROGRESS: at sentence #530000, processed 15103949 words, keeping 317390 word types
# 2019-08-08 17:12:20,847 : INFO : PROGRESS: at sentence #540000, processed 15387894 words, keeping 321421 word types
# 2019-08-08 17:12:20,889 : INFO : PROGRESS: at sentence #550000, processed 15671893 words, keeping 325420 word types
# 2019-08-08 17:12:20,931 : INFO : PROGRESS: at sentence #560000, processed 15955212 words, keeping 329254 word types
# 2019-08-08 17:12:20,973 : INFO : PROGRESS: at sentence #570000, processed 16233427 words, keeping 333366 word types
# 2019-08-08 17:12:21,016 : INFO : PROGRESS: at sentence #580000, processed 16515450 words, keeping 337302 word types
# 2019-08-08 17:12:21,059 : INFO : PROGRESS: at sentence #590000, processed 16799988 words, keeping 341395 word types
# 2019-08-08 17:12:21,103 : INFO : PROGRESS: at sentence #600000, processed 17082604 words, keeping 345218 word types
# 2019-08-08 17:12:21,148 : INFO : PROGRESS: at sentence #610000, processed 17362819 words, keeping 349052 word types
# 2019-08-08 17:12:21,199 : INFO : PROGRESS: at sentence #620000, processed 17644414 words, keeping 352719 word types
# 2019-08-08 17:12:21,243 : INFO : PROGRESS: at sentence #630000, processed 17933413 words, keeping 356657 word types
# 2019-08-08 17:12:21,288 : INFO : PROGRESS: at sentence #640000, processed 18216256 words, keeping 360620 word types
# 2019-08-08 17:12:21,349 : INFO : PROGRESS: at sentence #650000, processed 18497093 words, keeping 364329 word types
# 2019-08-08 17:12:21,391 : INFO : PROGRESS: at sentence #660000, processed 18776234 words, keeping 368158 word types
# 2019-08-08 17:12:21,433 : INFO : PROGRESS: at sentence #670000, processed 19059455 words, keeping 372022 word types
# 2019-08-08 17:12:21,474 : INFO : PROGRESS: at sentence #680000, processed 19338982 words, keeping 375625 word types
# 2019-08-08 17:12:21,515 : INFO : PROGRESS: at sentence #690000, processed 19614935 words, keeping 379275 word types
# 2019-08-08 17:12:21,558 : INFO : PROGRESS: at sentence #700000, processed 19900823 words, keeping 382985 word types
# 2019-08-08 17:12:21,600 : INFO : PROGRESS: at sentence #710000, processed 20180426 words, keeping 387418 word types
# 2019-08-08 17:12:21,642 : INFO : PROGRESS: at sentence #720000, processed 20455137 words, keeping 392035 word types
# 2019-08-08 17:12:21,686 : INFO : PROGRESS: at sentence #730000, processed 20736598 words, keeping 396290 word types
# 2019-08-08 17:12:21,729 : INFO : PROGRESS: at sentence #740000, processed 21016469 words, keeping 400340 word types
# 2019-08-08 17:12:21,772 : INFO : PROGRESS: at sentence #750000, processed 21310634 words, keeping 403968 word types
# 2019-08-08 17:12:21,815 : INFO : PROGRESS: at sentence #760000, processed 21601026 words, keeping 407680 word types
# 2019-08-08 17:12:21,857 : INFO : PROGRESS: at sentence #770000, processed 21881433 words, keeping 411219 word types
# 2019-08-08 17:12:21,899 : INFO : PROGRESS: at sentence #780000, processed 22165273 words, keeping 414794 word types
# 2019-08-08 17:12:21,940 : INFO : PROGRESS: at sentence #790000, processed 22442761 words, keeping 418258 word types
# 2019-08-08 17:12:21,982 : INFO : PROGRESS: at sentence #800000, processed 22722369 words, keeping 421828 word types
# 2019-08-08 17:12:22,023 : INFO : PROGRESS: at sentence #810000, processed 23000484 words, keeping 425357 word types
# 2019-08-08 17:12:22,065 : INFO : PROGRESS: at sentence #820000, processed 23276475 words, keeping 428954 word types
# 2019-08-08 17:12:22,106 : INFO : PROGRESS: at sentence #830000, processed 23558490 words, keeping 432705 word types
# 2019-08-08 17:12:22,149 : INFO : PROGRESS: at sentence #840000, processed 23841634 words, keeping 436257 word types
# 2019-08-08 17:12:22,211 : INFO : PROGRESS: at sentence #850000, processed 24129128 words, keeping 439553 word types
# 2019-08-08 17:12:22,254 : INFO : PROGRESS: at sentence #860000, processed 24413710 words, keeping 443090 word types
# 2019-08-08 17:12:22,296 : INFO : PROGRESS: at sentence #870000, processed 24693146 words, keeping 446547 word types
# 2019-08-08 17:12:22,339 : INFO : PROGRESS: at sentence #880000, processed 24974856 words, keeping 450162 word types
# 2019-08-08 17:12:22,381 : INFO : PROGRESS: at sentence #890000, processed 25261143 words, keeping 453561 word types
# 2019-08-08 17:12:22,423 : INFO : PROGRESS: at sentence #900000, processed 25541376 words, keeping 457010 word types
# 2019-08-08 17:12:22,465 : INFO : PROGRESS: at sentence #910000, processed 25825533 words, keeping 460323 word types
# 2019-08-08 17:12:22,508 : INFO : PROGRESS: at sentence #920000, processed 26107212 words, keeping 463936 word types
# 2019-08-08 17:12:22,550 : INFO : PROGRESS: at sentence #930000, processed 26392042 words, keeping 467483 word types
# 2019-08-08 17:12:22,594 : INFO : PROGRESS: at sentence #940000, processed 26682150 words, keeping 470960 word types
# 2019-08-08 17:12:22,636 : INFO : PROGRESS: at sentence #950000, processed 26963571 words, keeping 474388 word types
# 2019-08-08 17:12:22,679 : INFO : PROGRESS: at sentence #960000, processed 27241920 words, keeping 477897 word types
# 2019-08-08 17:12:22,724 : INFO : PROGRESS: at sentence #970000, processed 27529145 words, keeping 481193 word types
# 2019-08-08 17:12:22,768 : INFO : PROGRESS: at sentence #980000, processed 27824908 words, keeping 484678 word types
# 2019-08-08 17:12:22,811 : INFO : PROGRESS: at sentence #990000, processed 28106364 words, keeping 488092 word types
# 2019-08-08 17:12:22,855 : INFO : PROGRESS: at sentence #1000000, processed 28398134 words, keeping 491520 word types
# 2019-08-08 17:12:22,898 : INFO : PROGRESS: at sentence #1010000, processed 28686764 words, keeping 495016 word types
# 2019-08-08 17:12:22,940 : INFO : PROGRESS: at sentence #1020000, processed 28964541 words, keeping 498395 word types
# 2019-08-08 17:12:22,982 : INFO : PROGRESS: at sentence #1030000, processed 29237339 words, keeping 501690 word types
# 2019-08-08 17:12:23,026 : INFO : PROGRESS: at sentence #1040000, processed 29525996 words, keeping 505048 word types
# 2019-08-08 17:12:23,069 : INFO : PROGRESS: at sentence #1050000, processed 29806549 words, keeping 508338 word types
# 2019-08-08 17:12:23,110 : INFO : PROGRESS: at sentence #1060000, processed 30085952 words, keeping 511516 word types
# 2019-08-08 17:12:23,152 : INFO : PROGRESS: at sentence #1070000, processed 30363541 words, keeping 514861 word types
# 2019-08-08 17:12:23,196 : INFO : PROGRESS: at sentence #1080000, processed 30646395 words, keeping 518183 word types
# 2019-08-08 17:12:23,239 : INFO : PROGRESS: at sentence #1090000, processed 30933012 words, keeping 521621 word types
# 2019-08-08 17:12:23,282 : INFO : PROGRESS: at sentence #1100000, processed 31214714 words, keeping 524855 word types
# 2019-08-08 17:12:23,325 : INFO : PROGRESS: at sentence #1110000, processed 31495804 words, keeping 528117 word types
# 2019-08-08 17:12:23,367 : INFO : PROGRESS: at sentence #1120000, processed 31780386 words, keeping 531141 word types
# 2019-08-08 17:12:23,410 : INFO : PROGRESS: at sentence #1130000, processed 32064995 words, keeping 534345 word types
# 2019-08-08 17:12:23,453 : INFO : PROGRESS: at sentence #1140000, processed 32346996 words, keeping 537595 word types
# 2019-08-08 17:12:23,495 : INFO : PROGRESS: at sentence #1150000, processed 32630157 words, keeping 540795 word types
# 2019-08-08 17:12:23,559 : INFO : PROGRESS: at sentence #1160000, processed 32946627 words, keeping 544063 word types
# 2019-08-08 17:12:23,602 : INFO : PROGRESS: at sentence #1170000, processed 33230231 words, keeping 547250 word types
# 2019-08-08 17:12:23,645 : INFO : PROGRESS: at sentence #1180000, processed 33508651 words, keeping 550519 word types
# 2019-08-08 17:12:23,688 : INFO : PROGRESS: at sentence #1190000, processed 33799102 words, keeping 553578 word types
# 2019-08-08 17:12:23,732 : INFO : PROGRESS: at sentence #1200000, processed 34084091 words, keeping 556854 word types
# 2019-08-08 17:12:23,776 : INFO : PROGRESS: at sentence #1210000, processed 34371935 words, keeping 559916 word types
# 2019-08-08 17:12:23,820 : INFO : PROGRESS: at sentence #1220000, processed 34657422 words, keeping 563137 word types
# 2019-08-08 17:12:23,864 : INFO : PROGRESS: at sentence #1230000, processed 34941923 words, keeping 566306 word types
# 2019-08-08 17:12:23,907 : INFO : PROGRESS: at sentence #1240000, processed 35226037 words, keeping 569457 word types
# 2019-08-08 17:12:23,951 : INFO : PROGRESS: at sentence #1250000, processed 35512453 words, keeping 572690 word types
# 2019-08-08 17:12:23,997 : INFO : PROGRESS: at sentence #1260000, processed 35798150 words, keeping 575969 word types
# 2019-08-08 17:12:24,040 : INFO : PROGRESS: at sentence #1270000, processed 36080468 words, keeping 579086 word types
# 2019-08-08 17:12:24,083 : INFO : PROGRESS: at sentence #1280000, processed 36364708 words, keeping 582132 word types
# 2019-08-08 17:12:24,126 : INFO : PROGRESS: at sentence #1290000, processed 36650740 words, keeping 585276 word types
# 2019-08-08 17:12:24,170 : INFO : PROGRESS: at sentence #1300000, processed 36931584 words, keeping 588515 word types
# 2019-08-08 17:12:24,214 : INFO : PROGRESS: at sentence #1310000, processed 37212293 words, keeping 591779 word types
# 2019-08-08 17:12:24,257 : INFO : PROGRESS: at sentence #1320000, processed 37492700 words, keeping 594940 word types
# 2019-08-08 17:12:24,301 : INFO : PROGRESS: at sentence #1330000, processed 37778351 words, keeping 598096 word types
# 2019-08-08 17:12:24,345 : INFO : PROGRESS: at sentence #1340000, processed 38060258 words, keeping 601233 word types
# 2019-08-08 17:12:24,390 : INFO : PROGRESS: at sentence #1350000, processed 38344274 words, keeping 604296 word types
# 2019-08-08 17:12:24,437 : INFO : PROGRESS: at sentence #1360000, processed 38623625 words, keeping 607397 word types
# 2019-08-08 17:12:24,483 : INFO : PROGRESS: at sentence #1370000, processed 38901067 words, keeping 610432 word types
# 2019-08-08 17:12:24,532 : INFO : PROGRESS: at sentence #1380000, processed 39187019 words, keeping 613668 word types
# 2019-08-08 17:12:24,579 : INFO : PROGRESS: at sentence #1390000, processed 39468066 words, keeping 616900 word types
# 2019-08-08 17:12:24,629 : INFO : PROGRESS: at sentence #1400000, processed 39744894 words, keeping 620004 word types
# 2019-08-08 17:12:24,676 : INFO : PROGRESS: at sentence #1410000, processed 40021636 words, keeping 623078 word types
# 2019-08-08 17:12:24,723 : INFO : PROGRESS: at sentence #1420000, processed 40304754 words, keeping 626228 word types
# 2019-08-08 17:12:24,769 : INFO : PROGRESS: at sentence #1430000, processed 40589591 words, keeping 629243 word types
# 2019-08-08 17:12:24,813 : INFO : PROGRESS: at sentence #1440000, processed 40870321 words, keeping 632388 word types
# 2019-08-08 17:12:24,858 : INFO : PROGRESS: at sentence #1450000, processed 41156202 words, keeping 635453 word types
# 2019-08-08 17:12:24,909 : INFO : PROGRESS: at sentence #1460000, processed 41479780 words, keeping 638518 word types
# 2019-08-08 17:12:24,956 : INFO : PROGRESS: at sentence #1470000, processed 41764884 words, keeping 641658 word types
# 2019-08-08 17:12:25,001 : INFO : PROGRESS: at sentence #1480000, processed 42044188 words, keeping 644800 word types
# 2019-08-08 17:12:25,045 : INFO : PROGRESS: at sentence #1490000, processed 42329697 words, keeping 647965 word types
# 2019-08-08 17:12:25,091 : INFO : PROGRESS: at sentence #1500000, processed 42615940 words, keeping 651099 word types
# 2019-08-08 17:12:25,139 : INFO : PROGRESS: at sentence #1510000, processed 42899109 words, keeping 654246 word types
# 2019-08-08 17:12:25,184 : INFO : PROGRESS: at sentence #1520000, processed 43179626 words, keeping 657571 word types
# 2019-08-08 17:12:25,230 : INFO : PROGRESS: at sentence #1530000, processed 43459116 words, keeping 660674 word types
# 2019-08-08 17:12:25,276 : INFO : PROGRESS: at sentence #1540000, processed 43739811 words, keeping 663757 word types
# 2019-08-08 17:12:25,322 : INFO : PROGRESS: at sentence #1550000, processed 44017475 words, keeping 666831 word types
# 2019-08-08 17:12:25,367 : INFO : PROGRESS: at sentence #1560000, processed 44299992 words, keeping 669755 word types
# 2019-08-08 17:12:25,409 : INFO : PROGRESS: at sentence #1570000, processed 44576723 words, keeping 672603 word types
# 2019-08-08 17:12:25,458 : INFO : PROGRESS: at sentence #1580000, processed 44858902 words, keeping 675574 word types
# 2019-08-08 17:12:25,504 : INFO : PROGRESS: at sentence #1590000, processed 45145315 words, keeping 678625 word types
# 2019-08-08 17:12:25,549 : INFO : PROGRESS: at sentence #1600000, processed 45420708 words, keeping 681599 word types
# 2019-08-08 17:12:25,593 : INFO : PROGRESS: at sentence #1610000, processed 45697319 words, keeping 684501 word types
# 2019-08-08 17:12:25,638 : INFO : PROGRESS: at sentence #1620000, processed 45978109 words, keeping 687452 word types
# 2019-08-08 17:12:25,683 : INFO : PROGRESS: at sentence #1630000, processed 46258493 words, keeping 690458 word types
# 2019-08-08 17:12:25,731 : INFO : PROGRESS: at sentence #1640000, processed 46538875 words, keeping 693492 word types
# 2019-08-08 17:12:25,775 : INFO : PROGRESS: at sentence #1650000, processed 46821602 words, keeping 696404 word types
# 2019-08-08 17:12:25,852 : INFO : PROGRESS: at sentence #1660000, processed 47102245 words, keeping 699424 word types
# 2019-08-08 17:12:25,896 : INFO : PROGRESS: at sentence #1670000, processed 47380660 words, keeping 702412 word types
# 2019-08-08 17:12:25,941 : INFO : PROGRESS: at sentence #1680000, processed 47659847 words, keeping 705469 word types
# 2019-08-08 17:12:25,987 : INFO : PROGRESS: at sentence #1690000, processed 47942349 words, keeping 708420 word types
# 2019-08-08 17:12:26,030 : INFO : PROGRESS: at sentence #1700000, processed 48224842 words, keeping 711296 word types
# 2019-08-08 17:12:26,075 : INFO : PROGRESS: at sentence #1710000, processed 48514033 words, keeping 714230 word types
# 2019-08-08 17:12:26,118 : INFO : PROGRESS: at sentence #1720000, processed 48794465 words, keeping 717178 word types
# 2019-08-08 17:12:26,160 : INFO : PROGRESS: at sentence #1730000, processed 49080066 words, keeping 719903 word types
# 2019-08-08 17:12:26,203 : INFO : PROGRESS: at sentence #1740000, processed 49362694 words, keeping 722866 word types
# 2019-08-08 17:12:26,245 : INFO : PROGRESS: at sentence #1750000, processed 49646412 words, keeping 725938 word types
# 2019-08-08 17:12:26,288 : INFO : PROGRESS: at sentence #1760000, processed 49931991 words, keeping 728984 word types
# 2019-08-08 17:12:26,332 : INFO : PROGRESS: at sentence #1770000, processed 50213540 words, keeping 731816 word types
# 2019-08-08 17:12:26,374 : INFO : PROGRESS: at sentence #1780000, processed 50494595 words, keeping 734757 word types
# 2019-08-08 17:12:26,417 : INFO : PROGRESS: at sentence #1790000, processed 50780105 words, keeping 737576 word types
# 2019-08-08 17:12:26,459 : INFO : PROGRESS: at sentence #1800000, processed 51065286 words, keeping 740294 word types
# 2019-08-08 17:12:26,501 : INFO : PROGRESS: at sentence #1810000, processed 51345118 words, keeping 743104 word types
# 2019-08-08 17:12:26,542 : INFO : PROGRESS: at sentence #1820000, processed 51622022 words, keeping 745927 word types
# 2019-08-08 17:12:26,585 : INFO : PROGRESS: at sentence #1830000, processed 51903712 words, keeping 748794 word types
# 2019-08-08 17:12:26,626 : INFO : PROGRESS: at sentence #1840000, processed 52186669 words, keeping 751726 word types
# 2019-08-08 17:12:26,694 : INFO : PROGRESS: at sentence #1850000, processed 52473629 words, keeping 754747 word types
# 2019-08-08 17:12:26,738 : INFO : PROGRESS: at sentence #1860000, processed 52756658 words, keeping 757520 word types
# 2019-08-08 17:12:26,781 : INFO : PROGRESS: at sentence #1870000, processed 53033732 words, keeping 760446 word types
# 2019-08-08 17:12:26,826 : INFO : PROGRESS: at sentence #1880000, processed 53312527 words, keeping 763232 word types
# 2019-08-08 17:12:26,870 : INFO : PROGRESS: at sentence #1890000, processed 53593517 words, keeping 766138 word types
# 2019-08-08 17:12:26,912 : INFO : PROGRESS: at sentence #1900000, processed 53872643 words, keeping 769037 word types
# 2019-08-08 17:12:26,958 : INFO : PROGRESS: at sentence #1910000, processed 54163105 words, keeping 772001 word types
# 2019-08-08 17:12:27,018 : INFO : PROGRESS: at sentence #1920000, processed 54439351 words, keeping 774932 word types
# 2019-08-08 17:12:27,059 : INFO : PROGRESS: at sentence #1930000, processed 54717990 words, keeping 777872 word types
# 2019-08-08 17:12:27,101 : INFO : PROGRESS: at sentence #1940000, processed 54996205 words, keeping 780773 word types
# 2019-08-08 17:12:27,143 : INFO : PROGRESS: at sentence #1950000, processed 55274554 words, keeping 783756 word types
# 2019-08-08 17:12:27,186 : INFO : PROGRESS: at sentence #1960000, processed 55560016 words, keeping 786880 word types
# 2019-08-08 17:12:27,229 : INFO : PROGRESS: at sentence #1970000, processed 55837624 words, keeping 789993 word types
# 2019-08-08 17:12:27,271 : INFO : PROGRESS: at sentence #1980000, processed 56118634 words, keeping 792913 word types
# 2019-08-08 17:12:27,313 : INFO : PROGRESS: at sentence #1990000, processed 56400037 words, keeping 795609 word types
# 2019-08-08 17:12:27,356 : INFO : PROGRESS: at sentence #2000000, processed 56687870 words, keeping 798467 word types
# 2019-08-08 17:12:27,397 : INFO : PROGRESS: at sentence #2010000, processed 56975455 words, keeping 801308 word types
# 2019-08-08 17:12:27,439 : INFO : PROGRESS: at sentence #2020000, processed 57251172 words, keeping 804089 word types
# 2019-08-08 17:12:27,482 : INFO : PROGRESS: at sentence #2030000, processed 57539302 words, keeping 807163 word types
# 2019-08-08 17:12:27,524 : INFO : PROGRESS: at sentence #2040000, processed 57822182 words, keeping 810093 word types
# 2019-08-08 17:12:27,567 : INFO : PROGRESS: at sentence #2050000, processed 58109261 words, keeping 812850 word types
# 2019-08-08 17:12:27,641 : INFO : PROGRESS: at sentence #2060000, processed 58392522 words, keeping 815652 word types
# 2019-08-08 17:12:27,688 : INFO : PROGRESS: at sentence #2070000, processed 58683340 words, keeping 818547 word types
# 2019-08-08 17:12:27,731 : INFO : PROGRESS: at sentence #2080000, processed 58972189 words, keeping 821300 word types
# 2019-08-08 17:12:28,939 : INFO : PROGRESS: at sentence #2360000, processed 66816957 words, keeping 900459 word types
# 2019-08-08 17:12:28,982 : INFO : PROGRESS: at sentence #2370000, processed 67099057 words, keeping 903477 word types
# 2019-08-08 17:12:29,025 : INFO : PROGRESS: at sentence #2380000, processed 67377154 words, keeping 906236 word types
# 2019-08-08 17:12:29,067 : INFO : PROGRESS: at sentence #2390000, processed 67652765 words, keeping 908937 word types
# 2019-08-08 17:12:29,109 : INFO : PROGRESS: at sentence #2400000, processed 67927817 words, keeping 911792 word types
# 2019-08-08 17:12:29,152 : INFO : PROGRESS: at sentence #2410000, processed 68205600 words, keeping 914478 word types
# 2019-08-08 17:12:29,194 : INFO : PROGRESS: at sentence #2420000, processed 68482673 words, keeping 917021 word types
# 2019-08-08 17:12:29,237 : INFO : PROGRESS: at sentence #2430000, processed 68761294 words, keeping 919842 word types
# 2019-08-08 17:12:29,279 : INFO : PROGRESS: at sentence #2440000, processed 69041303 words, keeping 922675 word types
# 2019-08-08 17:12:29,340 : INFO : PROGRESS: at sentence #2450000, processed 69321964 words, keeping 925509 word types
# 2019-08-08 17:12:29,382 : INFO : PROGRESS: at sentence #2460000, processed 69597426 words, keeping 928415 word types
# 2019-08-08 17:12:29,424 : INFO : PROGRESS: at sentence #2470000, processed 69875719 words, keeping 931150 word types
# 2019-08-08 17:12:29,467 : INFO : PROGRESS: at sentence #2480000, processed 70151231 words, keeping 934016 word types
# 2019-08-08 17:12:29,510 : INFO : PROGRESS: at sentence #2490000, processed 70429513 words, keeping 936968 word types
# 2019-08-08 17:12:29,552 : INFO : PROGRESS: at sentence #2500000, processed 70706538 words, keeping 939766 word types
# 2019-08-08 17:12:29,595 : INFO : PROGRESS: at sentence #2510000, processed 70986956 words, keeping 942678 word types
# 2019-08-08 17:12:29,637 : INFO : PROGRESS: at sentence #2520000, processed 71272641 words, keeping 945586 word types
# 2019-08-08 17:12:29,681 : INFO : PROGRESS: at sentence #2530000, processed 71556139 words, keeping 948682 word types
# 2019-08-08 17:12:29,703 : INFO : collected 950225 word types from a corpus of 71700450 raw words and 2535087 sentences
# 2019-08-08 17:12:29,704 : INFO : Loading a fresh vocabulary
# 2019-08-08 17:12:30,248 : INFO : min_count=5 retains 266810 unique words (28% of original 950225, drops 683415)
# 2019-08-08 17:12:30,249 : INFO : min_count=5 leaves 70466956 word corpus (98% of original 71700450, drops 1233494)
# 2019-08-08 17:12:30,834 : INFO : deleting the raw counts dictionary of 950225 items
# 2019-08-08 17:12:30,855 : INFO : sample=0.001 downsamples 32 most-common words
# 2019-08-08 17:12:30,856 : INFO : downsampling leaves estimated 56236129 word corpus (79.8% of prior 70466956)
# 2019-08-08 17:12:31,645 : INFO : estimated required memory for 266810 words and 300 dimensions: 773749000 bytes
# 2019-08-08 17:12:31,646 : INFO : resetting layer weights
# 2019-08-08 17:12:33,747 : INFO : training model with 10 workers on 266810 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 
words/s, in_qsize 18, out_qsize 1
# 2019-08-08 17:22:25,186 : INFO : EPOCH 10 - PROGRESS: at 92.10% examples, 1431862 words/s, in_qsize 18, out_qsize 1
# 2019-08-08 17:22:26,206 : INFO : EPOCH 10 - PROGRESS: at 94.64% examples, 1430513 words/s, in_qsize 19, out_qsize 0
# 2019-08-08 17:22:27,207 : INFO : EPOCH 10 - PROGRESS: at 97.21% examples, 1430379 words/s, in_qsize 20, out_qsize 0
# 2019-08-08 17:22:28,213 : INFO : EPOCH 10 - PROGRESS: at 99.76% examples, 1429858 words/s, in_qsize 18, out_qsize 0
# 2019-08-08 17:22:28,259 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-08-08 17:22:28,262 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-08-08 17:22:28,263 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-08-08 17:22:28,270 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-08-08 17:22:28,279 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-08-08 17:22:28,281 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-08-08 17:22:28,282 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-08-08 17:22:28,282 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-08-08 17:22:28,285 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-08-08 17:22:28,287 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-08-08 17:22:28,288 : INFO : EPOCH - 10 : training on 71700450 raw words (56232766 effective words) took 39.3s, 1430587 effective words/s
# 2019-08-08 17:22:28,288 : INFO : training on a 717004500 raw words (562360746 effective words) took 395.0s, 1423831 effective words/s
# (562360746, 717004500)

# %%
model.save("/home/stirunag/OTAR_wv_model")
model.wv.save("/home/stirunag/OTAR_wv")

# %%
w1 = "tyrosine"
print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))
# Out:
# Most similar to tyrosine [('protein-tyrosine', 0.6535204648971558), ('(egfr)-tyrosine', 0.5887869596481323), ('egfr-tyrosine', 0.581829309463501), ('non-tyrosine', 0.5753749012947083), ('thyrosine', 0.5688590407371521), ('receptor-tyrosine', 0.5560238361358643), ('rhoa/rho', 0.5433630347251892), ('tropomyosin-related', 0.5422796010971069), ('ste20-like', 0.5313653349876404), ('(tyrosine', 0.5225860476493835)]

# %%
# w1 = "antibiotics".lower()

# print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))
# Out:
# Most similar to antibiotics [('antimicrobials', 0.8927945494651794), ('antibiotic', 0.8428863883018494), ('antibacterials', 0.8385289907455444), ('fluoroquinolones', 0.7828431725502014), ('quinolones', 0.7789057493209839), ('aminoglycosides', 0.7778674364089966), ('antifungals', 0.7597489356994629), ('vancomycin', 0.7558470368385315), ('beta-lactams', 0.7551823258399963), ('anti-anaerobic', 0.7500982284545898)]

# %%
# w1 = "ias".lower()

# print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))
# Out:
# Most similar to ias [('iPCS', 0.6238598823547363), ('pr.con', 0.6014829874038696), ('PreCS', 0.590514600276947), ('Subocular', 0.5778242349624634), ('retrocalcarine', 0.5754884481430054), ('Cheilion', 0.5727605819702148), ('P1/delta', 0.5714455246925354), ('psaf', 0.5705984234809875), ('vco', 0.568203866481781), ('lh.preCG', 0.5660292506217957)]
# /home/santosh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# word = 'gut'
# new_sentence = word.split()
# model.wv.most_similar(positive=filter(lambda x: x in model.wv.vocab, new_sentence), topn=20)
# Out:
# [('intestinal', 0.803631603717804),
#  ('microbiota', 0.7318477630615234),
#  ('microflora', 0.696231484413147),
#  ('dysbiosis', 0.6888571977615356),
#  ('hindgut', 0.6792138814926147),
#  ('microecology', 0.6745806336402893),
#  ('commensal', 0.6492570638656616),
#  ('flora', 0.6477329730987549),
#  ('intestines', 0.6453707218170166),
#  ('microbiome', 0.6398791670799255),
#  ('intestine', 0.638823926448822),
#  ('colonic', 0.6239259243011475),
#  ('mucosal', 0.6233099699020386),
#  ('enterocytes', 0.6227790117263794),
#  ('commensals', 0.6165361404418945),
#  ('digestive', 0.5974258780479431),
#  ('proventriculus', 0.5922425985336304),
#  ('mucosa', 0.5844686031341553),
#  ('ceca', 0.5819832682609558),
#  ('stomach', 0.5814363956451416)]

# %%
# word = 'fresh-water microbiome'
# new_sentence = word.split()
# model.wv.most_similar(positive=filter(lambda x: x in model.wv.vocab, new_sentence), topn=50)
# Out:
# [('microbiomes', 0.7728435397148132),
#  ('freshwater', 0.7352666258811951),
#  ('marine', 0.7324556708335876),
#  ('microbiota', 0.7100852131843567),
#  ('mollusks', 0.6891988515853882),
#  ('inhabiting', 0.6758404970169067),
#  ('filter-feeding', 0.6750960946083069),
#  ('deep-sea', 0.6745919585227966),
#  ('benthic', 0.6743195652961731),
#  ('fungus-cultivating', 0.6721211075782776),
#  ('pelagic', 0.6625490188598633),
#  ('flora', 0.660830557346344),
#  ('virome', 0.6548612713813782),
#  ('crustaceans', 0.6539419293403625),
#  ('plankton', 0.6535860300064087),
#  ('microflora', 0.6497483849525452),
#  ('epibionts', 0.6449277400970459),
#  ('cephalopods', 0.6427677273750305),
#  ('fishes', 0.6417897939682007),
#  ('fauna', 0.6353350877761841),
#  ('zooplankton', 0.6347795128822327),
#  ('shrimps', 0.6339887380599976),
#  ('chemosynthetic', 0.6317940354347229),
#  ('estuarine', 0.631584107875824),
#  ('coral', 0.6313155889511108),
#  ('carnivorous', 0.6281996369361877),
#  ('protistan', 0.627354085445404),
#  ('gut', 0.6266062259674072),
#  ('microbial', 0.6255075931549072),
#  ('euryhaline', 0.6251593232154846),
#  ('biota', 0.6249402761459351),
#  ('assemblages', 0.621676504611969),
#  ('cephalopod', 0.6206387281417847),
#  ('inhabit', 0.6191437840461731),
#  ('copepods', 0.6190696358680725),
#  ('copepod', 0.6180428862571716),
#  ('aquatic', 0.6177237033843994),
#  ('inhabits', 0.6170161962509155),
#  ('oysters', 0.616900622844696),
#  ('guts', 0.6156280636787415),
#  ('oyster', 0.6150339245796204),
#  ('ecology', 0.6124994158744812),
#  ('intertidal', 0.6124154329299927),
#  ('mussels', 0.6123822331428528),
#  ('terrestrial', 0.612204372882843),
#  ('invertebrate', 0.6087221503257751),
#  ('microbiotas', 0.6079533696174622),
#  ('isopod', 0.6072388887405396),
#  ('bacterioplankton', 0.6068664789199829),
#  ('reef', 0.6065714955329895)]

# %%
# import spacy
# parse = spacy.load('biobio')

# text = u'INTRODUCTION The hydrolysis of phosphatidylcholine (PC) by phospholipase D (PLD) generates the signaling lipid phosphatidic acid (PA) (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ). PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis (Way et al. , 2000 ; Caumont et al. , 1998 ) or endocytosis (Schmidt et al. , 1999a ). PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase (Rizzo et al. , 2000 ), as regulators of cell shape through the stimulation of PI4P5-kinase (Honda et al. , 1999 ) or as the substrate to generate diacylglycerol or lysophosphatidic acid (LPA) through further metabolism (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ). Many cell types express the known PLD1 (Hammond et al. , 1995 ) and/or PLD2 (Colley et al. , 1997 ) isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors (reviewed in Liscovitch et al. , 2000 ). It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C (PKC), ADP-ribosylation factor (ARF), and Rho family members (Singer et al. , 1995 ; Siddiqi et al. , 1995 ; Liscovitch et al. , 2000 ), which have been shown to stimulate PLD1 directly using in vitro reconstitution assays (Hammond et al. , 1997 ). Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events. Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them (Liscovitch et al. , 2000 ). A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical. Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent (Liscovitch et al. , 2000 ). This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo. Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway (Schmidt et al. , 1999b ). However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation. These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  (a required cofactor for PLD). In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity (Zhang et al. , 1999 ). Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins. In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation. These include mutants that are inactive (Sung et al. , 1997 ), selectively nonresponsive to PKC (Zhang et al. , 1999 ), or insensitive to PI4,5P2  (Sciorra et al. , 1999 ). The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule (Hammond et al. , 1997 ; Sung et al. , 1997 ; Sung et al. , 1999b ; Yamazaki et al. , 1999 ). Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists. In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles. Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.'
# Out:
# INTRODUCTION
# The
# hydrolysis
# of
# phosphatidylcholine E B
# (
# PC
# )
# by
# phospholipase
# D
# (
# PLD
# )
# generates
# the
# signaling
# lipid
# phosphatidic E B
# acid E I
# (
# PA
# )
# (
# reviewed
# in
# Frohman
# et
# al
# .
# ,
# 1999
# ;
# Jones
# et
# al
# .
# ,
# 1999
# )
# .
# PA
# has
# been
# hypothesized
# to
# act
# as
# a
# fusogenic
# lipid
# in
# vesicular
# transport
# such
# as
# exocytosis
# (
# Way
# et
# al
# .
# ,
# 2000
# ;
# Caumont E B
# et
# al
# .
# ,
# 1998
# )
# or
# endocytosis
# (
# Schmidt
# et
# al
# .
# ,
# 1999a
# )
# .
# PA
# also
# may
# act
# as
# an
# anchor
# for
# signaling
# molecules
# that
# act
# in
# proliferation
# pathways
# ,
# such
# as
# the
# Raf-1
# kinase
# (
# Rizzo
# et
# al
# .
# ,
# 2000
# )
# ,
# as
# regulators
# of
# cell
# shape
# through
# the
# stimulation
# of
# PI4P5-kinase
# (
# Honda
# et
# al
# .
# ,
# 1999
# )
# or
# as
# the
# substrate
# to
# generate
# diacylglycerol E B
# or
# lysophosphatidic E B
# acid E I
# (
# LPA E B
# )
# through
# further
# metabolism
# (
# reviewed
# in
# Frohman
# et
# al
# .
# ,
# 1999
# ;
# Jones
# et
# al
# .
# ,
# 1999
# )
# .
# Many
# cell
# types
# express
# the
# known
# PLD1
# (
# Hammond
# et
# al
# .
# ,
# 1995
# )
# and/or
# PLD2
# (
# Colley
# et
# al
# .
# ,
# 1997
# )
# isoenzymes
# ,
# which
# become
# activated
# in
# response
# to
# a
# wide
# variety
# of
# agonists
# that
# signal
# through
# heterotrimeric
# G
# protein
# -
# coupled
# or
# tyrosine E B
# kinase
# receptors
# (
# reviewed
# in
# Liscovitch
# et
# al
# .
# ,
# 2000
# )
# .
# It
# has
# been
# proposed
# that
# the
# link
# between
# receptor
# stimulation
# and
# PLD
# activation
# is
# mediated
# by
# protein
# kinase
# C
# (
# PKC
# )
# ,
# ADP E B
# -
# ribosylation
# factor
# (
# ARF
# )
# ,
# and
# Rho
# family
# members
# (
# Singer
# et
# al
# .
# ,
# 1995
# ;
# Siddiqi
# et
# al
# .
# ,
# 1995
# ;
# Liscovitch
# et
# al
# .
# ,
# 2000
# )
# ,
# which
# have
# been
# shown
# to
# stimulate
# PLD1
# directly
# using
# in
# vitro
# reconstitution
# assays
# (
# Hammond
# et
# al
# .
# ,
# 1997
# )
# .
# Since
# ARF E B
# ,
# Rho
# ,
# and
# PKC
# stimulate
# multiple
# downstream
# effector
# pathways
# that
# ultimately
# regulate
# cellular
# morphology
# ,
# proliferation
# ,
# and
# secretion
# ,
# there
# has
# been
# intense
# interest
# in
# determining
# the
# relationship
# of
# PLD
# stimulation
# through
# each
# activator
# to
# these
# cell
# biological
# events
# .
# Such
# studies
# generally
# have
# been
# approached
# through
# the
# manipulation
# of
# PKC
# ,
# Rho
# ,
# or
# ARF
# activity
# using
# the
# overexpression
# of
# activated
# or
# inactive
# alleles
# ,
# toxins
# ,
# or
# pharmacologic
# agents
# to
# activate
# or
# inhibit
# them
# (
# Liscovitch
# et
# al
# .
# ,
# 2000
# )
# .
# A
# key
# issue
# raised
# by
# many
# of
# these
# studies
# has
# been
# whether
# PLD1
# is
# actually
# activated
# in
# vivo
# through
# direct
# stimulation
# by
# its
# effectors
# ,
# or
# whether
# indirect
# pathways
# are
# more
# critical
# .
# Specifically
# ,
# inhibitors
# of
# the
# enzymatic
# activity
# of
# PKC E B
# have
# been
# shown
# to
# block
# PLD
# activation
# ,
# even
# though
# the
# direct
# stimulation
# of
# PLD1
# by
# PKC
# in
# vitro
# involves
# an
# interaction
# with
# the
# regulatory
# domain
# of
# PKC
# and
# is
# ATP E B
# -
# independent
# (
# Liscovitch
# et
# al
# .
# ,
# 2000
# )
# .
# This
# suggests
# that
# a
# PKC
# target
# other
# than
# PLD
# is
# critical
# for
# the
# activation
# of
# PLD
# by
# PKC
# in
# vivo
# .
# Similarly
# ,
# it
# has
# been
# proposed
# that
# the
# primary
# mechanism
# through
# which
# Rho
# activates
# PLD1
# is
# an
# indirect
# one
# in
# which
# Rho
# activates
# Rho
# -
# kinase
# ,
# which
# then
# activates
# PLD
# via
# an
# unknown
# pathway
# (
# Schmidt
# et
# al
# .
# ,
# 1999b
# )
# .
# However
# ,
# these
# approaches
# involve
# complicated
# interpretations
# ,
# since
# manipulation
# of
# PKC
# ,
# Rho
# ,
# and
# ARF
# levels
# of
# activity
# affect
# many
# things
# aside
# from
# PLD
# regulation
# .
# These
# include
# cross
# -
# regulation
# of
# the
# other
# stimulators
# and
# alterations
# in
# availability
# of
# PI4,5P2 E B
#
# (
# a
# required
# cofactor
# for
# PLD
# )
# .
# In
# addition
# ,
# the
# pharmacologic
# agents
# are
# inevitably
# found
# to
# exhibit
# less
# than
# complete
# specificity
# (
# Zhang
# et
# al
# .
# ,
# 1999
# )
# .
# Moreover
# ,
# reagents
# such
# as
# Rho
# -
# dominant
# negative
# alleles
# cause
# undesired
# widespread
# effects
# by
# sequestering
# the
# guanine?nucleotide
# exchange
# factors
# required
# to
# activate
# other
# small
# G
# -
# proteins
# .
# In
# recent
# years
# ,
# we
# have
# described
# an
# alternative
# approach
# based
# on
# generating
# alleles
# of
# PLD
# that
# exhibit
# altered
# regulation
# .
# These
# include
# mutants
# that
# are
# inactive
# (
# Sung
# et
# al
# .
# ,
# 1997
# )
# ,
# selectively
# nonresponsive
# to
# PKC
# (
# Zhang
# et
# al
# .
# ,
# 1999
# )
# ,
# or
# insensitive
# to
# PI4,5P2 E B
#
# (
# Sciorra
# et
# al
# .
# ,
# 1999
# )
# .
# The
# rationale
# for
# this
# scheme
# was
# given
# in
# earlier
# studies
# that
# demonstrated
# that
# the
# stimulators
# of
# PLD1
# physically
# interact
# with
# it
# at
# distinct
# sites
# in
# the
# molecule
# (
# Hammond
# et
# al
# .
# ,
# 1997
# ;
# Sung
# et
# al
# .
# ,
# 1997
# ;
# Sung
# et
# al
# .
# ,
# 1999b
# ;
# Yamazaki
# et
# al
# .
# ,
# 1999
# )
# .
# Our
# previous
# study
# using
# an
# allele
# selectively
# nonresponsive
# to
# PKC
# revealed
# that
# direct
# stimulation
# of
# PLD1
# by
# PKC
# is
# required
# for
# much
# of
# the
# response
# of
# PLD1
# to
# G
# protein
# -
# coupled
# agonists
# .
# In
# this
# report
# ,
# we
# demonstrate
# that
# direct
# stimulation
# of
# PLD1
# by
# Rho
# is
# also
# critical
# using
# novel
# ,
# selectively
# nonresponsive
# alleles
# .
# Taken
# together
# ,
# our
# results
# demonstrate
# that
# signal
# integration
# through
# both
# PKC
# and
# Rho
# via
# direct
# contact
# is
# required
# for
# significant
# physiologic
# in
# vivo
# activation
# of
# PLD1
# during
# agonist
# signaling
# .

# %%
# doc = parse(text)

# for w in doc:
#     # Prints "E" for being part of a biomedical entity, and shows IOB tagging.
#     print(w, w.ent_type_, w.ent_iob_)

# %%
# for s in doc.sents:
#     print('sentence: ' + str(s) + '\n')
# Out:
# sentence: INTRODUCTION The hydrolysis of phosphatidylcholine (PC) by phospholipase D (PLD) generates the signaling lipid phosphatidic acid (PA) (reviewed in Frohman et al. ,
#
# sentence: 1999 ; Jones et al. ,
#
# sentence: 1999 ).
#
# sentence: PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis (Way et al. ,
#
# sentence: 2000 ; Caumont et al. ,
#
# sentence: 1998 ) or endocytosis (Schmidt et al. ,
#
# sentence: 1999a ).
#
# sentence: PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase (Rizzo et al. ,
#
# sentence: 2000 ), as regulators of cell shape through the stimulation of PI4P5-kinase (Honda et al. ,
#
# sentence: 1999 ) or as the substrate to generate diacylglycerol or lysophosphatidic acid (LPA) through further metabolism (reviewed in Frohman et al. ,
#
# sentence: 1999 ; Jones et al. ,
#
# sentence: 1999 ).
#
# sentence: Many cell types express the known PLD1 (Hammond et al. ,
#
# sentence: 1995 ) and/or PLD2 (Colley et al. ,
#
# sentence: 1997 ) isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors (reviewed in Liscovitch et al. ,
#
# sentence: 2000 ).
#
# sentence: It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C (PKC), ADP-ribosylation factor (ARF), and Rho family members (Singer et al. ,
#
# sentence: 1995 ; Siddiqi et al. ,
#
# sentence: 1995 ; Liscovitch et al. ,
#
# sentence: 2000 ), which have been shown to stimulate PLD1 directly using in vitro reconstitution assays (Hammond et al. ,
#
# sentence: 1997 ).
#
# sentence: Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events.
#
# sentence: Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them (Liscovitch et al. ,
#
# sentence: 2000 ).
#
# sentence: A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical.
#
# sentence: Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent (Liscovitch et al. ,
#
# sentence: 2000 ).
#
# sentence: This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo.
#
# sentence: Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway (Schmidt et al. ,
#
# sentence: 1999b ).
#
# sentence: However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation.
#
# sentence: These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  (a required cofactor for PLD).
#
# sentence: In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity (Zhang et al. ,
#
# sentence: 1999 ).
#
# sentence: Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins.
#
# sentence: In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation.
#
# sentence: These include mutants that are inactive (Sung et al. ,
#
# sentence: 1997 ), selectively nonresponsive to PKC (Zhang et al. ,
#
# sentence: 1999 ), or insensitive to PI4,5P2  (Sciorra et al. ,
#
# sentence: 1999 ).
#
# sentence: The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule (Hammond et al. ,
#
# sentence: 1997 ; Sung et al. ,
#
# sentence: 1997 ; Sung et al. ,
#
# sentence: 1999b ; Yamazaki et al. ,
#
# sentence: 1999 ).
#
# sentence: Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists.
#
# sentence: In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles.
#
# sentence: Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.

# %%
# import re

# def remove_parenthesized_chunks(text):
#     new_text = re.sub('[\(\[].*?[\)\]]', '', text)
# #     new_text = re.sub(r'\(.*\)', '', text)
#     return new_text

# %%
# parse_1 = spacy.load('en')
# doc_1 = parse_1(text)
# for s in doc_1.sents:
#     print('sentence: ' + str(s) + '\n')
# Out:
# sentence: INTRODUCTION
#
# sentence: The hydrolysis of phosphatidylcholine (PC) by phospholipase D (PLD) generates the signaling lipid phosphatidic acid (PA) (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ).
#
# sentence: PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis (Way et al. , 2000 ; Caumont et al. , 1998 ) or endocytosis (Schmidt et al. , 1999a ).
#
# sentence: PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase (Rizzo et al. , 2000 ), as regulators of cell shape through the stimulation of PI4P5-kinase (Honda et al. , 1999 ) or as the substrate to generate diacylglycerol or lysophosphatidic acid (LPA) through further metabolism (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ).
#
# sentence: Many cell types express the known PLD1 (Hammond et al. , 1995 )
#
# sentence: and/or PLD2 (Colley et al. , 1997 ) isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors (reviewed in Liscovitch et al. , 2000 ).
#
# sentence: It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C (PKC), ADP-ribosylation factor (ARF), and Rho family members (Singer et al. , 1995 ;
#
# sentence: Siddiqi et al. , 1995 ; Liscovitch et al. , 2000 ), which have been shown to stimulate PLD1 directly using in vitro reconstitution assays (Hammond et al. , 1997 ).
#
# sentence: Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events.
#
# sentence: Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them (Liscovitch et al. , 2000 ).
#
# sentence: A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical.
#
# sentence: Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent (Liscovitch et al. , 2000 ).
#
# sentence: This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo.
#
# sentence: Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway (Schmidt et al. , 1999b ).
#
# sentence: However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation.
#
# sentence: These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  (a required cofactor for PLD).
#
# sentence: In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity (Zhang et al. , 1999 ).
#
# sentence: Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins.
#
# sentence: In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation.
#
# sentence: These include mutants that are inactive (Sung et al. , 1997 ), selectively nonresponsive to PKC (Zhang et al. , 1999 ), or insensitive to PI4,5P2  (Sciorra et al. , 1999 ).
#
# sentence: The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule (Hammond et al. , 1997 ;
#
# sentence: Sung et al. ,
#
# sentence: 1997 ; Sung et al. , 1999b ; Yamazaki et al. , 1999 ).
#
# sentence: Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists.
#
# sentence: In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles.
#
# sentence: Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.

# %%
# remove_parenthesized_chunks(text)
# Out:
# 'INTRODUCTION The hydrolysis of phosphatidylcholine  by phospholipase D  generates the signaling lipid phosphatidic acid  . PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis  or endocytosis . PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase , as regulators of cell shape through the stimulation of PI4P5-kinase  or as the substrate to generate diacylglycerol or lysophosphatidic acid  through further metabolism . Many cell types express the known PLD1  and/or PLD2  isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors . It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C , ADP-ribosylation factor , and Rho family members , which have been shown to stimulate PLD1 directly using in vitro reconstitution assays . Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events. Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them . A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical. Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent . This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo. Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway . However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation. These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  . In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity . Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins. In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation. These include mutants that are inactive , selectively nonresponsive to PKC , or insensitive to PI4,5P2  . The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule . Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists. In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles. Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.'

# %%
# doc_1 = parse_1(remove_parenthesized_chunks(text))
# for s in doc_1.sents:
#     print('sentence: ' + str(s) + '\n')
# Out:
# sentence: INTRODUCTION
#
# sentence: The hydrolysis of phosphatidylcholine  by phospholipase D  generates the signaling lipid phosphatidic acid  .
#
# sentence: PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis  or endocytosis .
#
# sentence: PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase , as regulators of cell shape through the stimulation of PI4P5-kinase  or as the substrate to generate diacylglycerol or lysophosphatidic acid  through further metabolism .
#
# sentence: Many cell types express the known PLD1  and/or PLD2  isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors .
#
# sentence: It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C , ADP-ribosylation factor , and Rho family members , which have been shown to stimulate PLD1 directly using in vitro reconstitution assays .
#
# sentence: Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events.
#
# sentence: Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them .
#
# sentence: A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical.
#
# sentence: Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent .
#
# sentence: This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo.
#
# sentence: Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway .
#
# sentence: However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation.
#
# sentence: These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  .
#
# sentence: In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity .
#
# sentence: Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins.
#
# sentence: In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation.
#
# sentence: These include mutants that are inactive , selectively nonresponsive to PKC , or insensitive to PI4,5P2  .
#
# sentence: The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule .
#
# sentence: Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists.
#
# sentence: In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles.
#
# sentence: Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.

# %%
# doc = parse(text)

# for w in doc:
#     # Prints "E" for being part of a biomedical entity, and shows IOB tagging.
#     print(w, w.ent_type_, w.ent_iob_)
