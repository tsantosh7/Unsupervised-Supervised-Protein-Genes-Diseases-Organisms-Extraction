# %%
from bs4 import BeautifulSoup
import lxml
import pandas as pd
import os
from tqdm import tqdm 
from collections import defaultdict

# %%
datapath = '/nfs/gns/literature/Santosh_Tirunagari/GitHub/Unsupervised-Protein-Genes-Diseases-Extraction/Datasets/'
infile = open(datapath+'CoMAGC/'+'CoMAGC.xml','r')
contents = infile.read()
soup = BeautifulSoup(contents,'html.parser')

# %%
annotations = soup.find_all('annotation_unit')

# %%
reldataset = defaultdict(list)

for repElem in tqdm(annotations):
    sentence = repElem.sentence.text
    try:
        GP = [int(repElem.gene.get('range').split('-')[0]), int(repElem.gene.get('range').split('-')[1]), repElem.gene.text, 'GP']
        reldataset[sentence].append(GP)
    except:
        pass
    try:    
        DS = [int(repElem.cancer_term.get('range').split('-')[0]),int(repElem.cancer_term.get('range').split('-')[1]), repElem.cancer_term.text, 'DS']
        reldataset[sentence].append(DS)
    except:
        pass
    try:
        rel1 = [int(repElem.expression_change_keyword_1.get('range').split('-')[0]),int(repElem.expression_change_keyword_1.get('range').split('-')[1]), repElem.expression_change_keyword_1.text, repElem.expression_change_keyword_1.get('type')] 
        reldataset[sentence].append(rel1)
    except:
        pass   
    try:
        rel2 = [int(repElem.expression_change_keyword_2.get('range').split('-')[0]), int(repElem.expression_change_keyword_2.get('range').split('-')[1]), repElem.expression_change_keyword_2.text, repElem.expression_change_keyword_2.get('type')]
        reldataset[sentence].append(rel2)
    except:
        pass
# Out:
# 100%|██████████| 821/821 [00:00<00:00, 1055.77it/s]

# %%
reldataset
# Out:
# defaultdict(list,
#             {'Thus, FGF6 is increased in PIN and prostate cancer and can promote the proliferation of the transformed prostatic epithelial cells via paracrine and autocrine mechanisms.': [[6,
#                9,
#                'FGF6',
#                'GP'],
#               [35, 49, 'prostate cancer', 'DS'],
#               [14, 22, 'increased', 'Positive_regulation']],
#              'Isolation and characterization of the major form of human MUC18 cDNA gene and correlation of MUC18 over-expression in prostate cancer cell lines and tissues with malignant progression.': [[93,
#                97,
#                'MUC18',
#                'GP'],
#               [118, 132, 'prostate cancer', 'DS'],
#               [99, 113, 'over-expression', 'Gene_expression'],
#               [99, 113, 'over-expression', 'Positive_regulation']],
#              'We therefore conclude that MUC18 expression is increased during prostate cancer initiation (high grade PIN) and progression to carcinoma, and in metastatic cell lines and metastatic carcinoma.': [[27,
#                31,
#                'MUC18',
#                'GP'],
#               [64, 78, 'prostate cancer', 'DS'],
#               [33, 42, 'expression', 'Gene_expression'],
#               [47, 55, 'increased', 'Positive_regulation']],
#              'These results demonstrate that in a sequence-specific manner, RIalpha antisense, via efficient depletion of the growth stimulatory molecule RIalpha, induces growth inhibition, apoptosis, and phenotypic (cell morphology) changes, providing an innovative approach to combat hormone-insensitive prostate cancer cell growth.': [[112,
#                146,
#                'growth stimulatory molecule RIalpha',
#                'GP'],
#               [292, 306, 'prostate cancer', 'DS'],
#               [95, 103, 'depletion', 'Negative_regulation']],
#              'We have found that Cdc6 expression is down-regulated in prostate cancer as detected by semiquantitative reverse transcriptase-PCR of prostate cell lines and laser-captured microdissected prostate tissues.': [[19,
#                22,
#                'Cdc6',
#                'GP'],
#               [56, 70, 'prostate cancer', 'DS'],
#               [24, 33, 'expression', 'Gene_expression'],
#               [38, 51, 'down-regulated', 'Negative_regulation']],
#              'Furthermore, a 100-fold reduction in the transcription efficiency of the Cdc6 promoter-luciferase construct was noted in the metastatic PC3 cells compared with that in BPH-1 cells.': [[73,
#                106,
#                'Cdc6 promoter-luciferase construct',
#                'GP'],
#               [136, 138, 'PC3', 'DS'],
#               [24, 32, 'reduction', 'Negative_regulation']],
#              'Sustained increase of the c-myc gene product was detectable in PC-3 but not in DU-145 cells.': [[26,
#                43,
#                'c-myc gene product',
#                'GP'],
#               [63, 66, 'PC-3', 'DS'],
#               [10, 17, 'increase', 'Positive_regulation']],
#              'Concurrently, we demonstrated BN-dependent activation of the transcription factor Elk-1 and significant increase of cell proliferation in both prostate cancer cell lines.': [[61,
#                86,
#                'transcription factor Elk-1',
#                'GP'],
#               [143, 157, 'prostate cancer', 'DS'],
#               [43, 52, 'activation', 'Positive_regulation']],
#              'Electronic profiling of publicly available expressed sequence tag databases identified a gene, cysteine-rich secretoryprotein-3 (CRISP-3), that is up-regulated in prostate cancer, and of which the expression is relatively prostate-specific.': [[129,
#                135,
#                'CRISP-3',
#                'GP'],
#               [163, 177, 'prostate cancer', 'DS'],
#               [147, 158, 'up-regulated', 'Positive_regulation']],
#              'Cdc25B is frequently overexpressed in human prostate cancer tissues (29 of 30; 97%).': [[0,
#                5,
#                'Cdc25B',
#                'GP'],
#               [44, 58, 'prostate cancer', 'DS'],
#               [21, 33, 'overexpressed', 'Gene_expression'],
#               [21, 33, 'overexpressed', 'Positive_regulation']],
#              'PTOV1 was recently identified as a novel gene and protein during a differential display screening for genes overexpressed in prostate cancer.': [[0,
#                4,
#                'PTOV1',
#                'GP'],
#               [125, 139, 'prostate cancer', 'DS'],
#               [108, 120, 'overexpressed', 'Gene_expression'],
#               [108, 120, 'overexpressed', 'Positive_regulation']],
#              'By immunohistochemical analysis, we have found that PTOV1 is overexpressed in 71% of 38 prostate carcinomas and in 80% of samples with prostate intraepithelial neoplasia.': [[52,
#                56,
#                'PTOV1',
#                'GP'],
#               [88, 106, 'prostate carcinomas', 'DS'],
#               [61, 73, 'overexpressed', 'Gene_expression'],
#               [61, 73, 'overexpressed', 'Positive_regulation']],
#              'MEK5 overexpression is associated with metastatic prostate cancer, and stimulates proliferation, MMP-9 expression and invasion.': [[0,
#                3,
#                'MEK5',
#                'GP'],
#               [50, 64, 'prostate cancer', 'DS'],
#               [5, 18, 'overexpression', 'Gene_expression'],
#               [5, 18, 'overexpression', 'Positive_regulation']],
#              'The overexpression of Bax inhibitor-1 (BI-1) in prostate carcinoma and prostate cancer cell lines was confirmed by using Northern blot and Western blot analyses.': [[39,
#                42,
#                'BI-1',
#                'GP'],
#               [71, 85, 'prostate cancer', 'DS'],
#               [4, 17, 'overexpression', 'Gene_expression'],
#               [4, 17, 'overexpression', 'Positive_regulation']],
#              'These observations suggest that U19 is growth inhibitory and tumor suppressive and that the disruption of androgen-dependent growth inhibition via U19 down-regulation is commonly associated with prostate cancer progression.': [[147,
#                149,
#                'U19',
#                'GP'],
#               [195, 209, 'prostate cancer', 'DS'],
#               [151, 165, 'down-regulation', 'Negative_regulation']],
#              'First, a comprehensive serial immunohistochemical analysis of primary and metastatic prostate cancer samples showed increased stage-specific expression of IL-11Ralpha during disease progression.': [[155,
#                165,
#                'IL-11Ralpha',
#                'GP'],
#               [85, 99, 'prostate cancer', 'DS'],
#               [141, 150, 'expression', 'Gene_expression'],
#               [116, 124, 'increased', 'Positive_regulation']],
#              'We have shown previously that although AP-2 is expressed highly in normal prostatic epithelium, its expression is lost in high-grade prostatic intraepithelial neoplasia and prostate cancer, suggesting that loss of AP-2 plays a role in prostate cancer development.': [[214,
#                217,
#                'AP-2',
#                'GP'],
#               [173, 187, 'prostate cancer', 'DS'],
#               [206, 209, 'loss', 'Negative_regulation']],
#              'Elucidating the molecular events resulting from loss of AP-2 in the prostate epithelium has implications for the understanding and prevention of the onset of prostate cancer.': [[56,
#                59,
#                'AP-2',
#                'GP'],
#               [158, 172, 'prostate cancer', 'DS'],
#               [48, 51, 'loss', 'Negative_regulation']],
#              'The interaction between FADD and caspase-8 was inhibited, but abrogation of JNK activity or HIPK3 expression was found to restore this interaction and increased the sensitivity of DU 145 cells to Fas receptor-mediated apoptosis.': [[92,
#                96,
#                'HIPK3',
#                'GP'],
#               [180, 185, 'DU 145', 'DS'],
#               [98, 107, 'expression', 'Gene_expression'],
#               [62, 71, 'abrogation', 'Negative_regulation']],
#              'In clinical prostate cancer specimens from patients with varying grades of disease, the stained tissue sections showed high levels of SREBP-1 protein compared with noncancerous prostate tissue.': [[134,
#                148,
#                'SREBP-1 protein',
#                'GP'],
#               [12, 26, 'prostate cancer', 'DS'],
#               [124, 129, 'levels', 'Positive_regulation']],
#              'In summary, the LNCaP xenograft model of human prostate cancer as well as clinical specimens of prostate cancer demonstrated an up-regulation of SREBPs and their downstream effector genes during progression to androgen independence.': [[145,
#                150,
#                'SREBPs',
#                'GP'],
#               [47, 61, 'prostate cancer', 'DS'],
#               [128, 140, 'up-regulation', 'Positive_regulation']],
#              'An increase in the activity of mitogen-activated protein kinase (MAPK) has been correlated with the progression of prostate cancer to advanced disease in humans.': [[31,
#                62,
#                'mitogen-activated protein kinase',
#                'GP'],
#               [115, 129, 'prostate cancer', 'DS'],
#               [3, 10, 'increase', 'Positive_regulation']],
#              'Increasing RSK isoform 2 (RSK2) levels in the human prostate cancer line, LNCaP, enhanced prostate-specific antigen (PSA) expression, an important diagnostic marker for prostate cancer, whereas inhibiting RSK activity using a RSK-specific inhibitor, 3Ac-SL0101, decreased PSA expression.': [[117,
#                119,
#                'PSA',
#                'GP'],
#               [52, 66, 'prostate cancer', 'DS'],
#               [122, 131, 'expression', 'Gene_expression'],
#               [81, 88, 'enhanced', 'Positive_regulation'],
#               [272, 274, 'PSA', 'GP'],
#               [52, 66, 'prostate cancer', 'DS'],
#               [276, 285, 'expression', 'Gene_expression'],
#               [262, 270, 'decreased', 'Negative_regulation']],
#              'Down-regulation of ATM protein sensitizes human prostate cancer cells to radiation-induced apoptosis.': [[19,
#                29,
#                'ATM protein',
#                'GP'],
#               [48, 62, 'prostate cancer', 'DS'],
#               [0, 14, 'Down-regulation', 'Negative_regulation']],
#              'CBX7 overexpression in LNCaP cells resulted in a slight growth advantage in both androgen-dependent and -independent conditions.': [[0,
#                3,
#                'CBX7',
#                'GP'],
#               [23, 27, 'LNCaP', 'DS'],
#               [5, 18, 'overexpression', 'Gene_expression'],
#               [5, 18, 'overexpression', 'Positive_regulation']],
#              'Cytochrome P450 1B1 (CYP1B1), a dioxin inducible member of the CYP supergene family, is overexpressed in various human malignancies including prostate cancer.': [[0,
#                27,
#                'Cytochrome P450 1B1 (CYP1B1)',
#                'GP'],
#               [142, 156, 'prostate cancer', 'DS'],
#               [88, 100, 'overexpressed', 'Gene_expression'],
#               [88, 100, 'overexpressed', 'Positive_regulation']],
#              'Increased expression of osteopontin contributes to the progression of prostate cancer.': [[24,
#                34,
#                'osteopontin',
#                'GP'],
#               [70, 84, 'prostate cancer', 'DS'],
#               [10, 19, 'expression', 'Gene_expression'],
#               [0, 8, 'Increased', 'Positive_regulation']],
#              'Increased expression of type 2 3alpha-hydroxysteroid dehydrogenase/type 5 17beta-hydroxysteroid dehydrogenase (AKR1C3) and its relationship with androgen receptor in prostate carcinoma.': [[24,
#                117,
#                'type 2 3alpha-hydroxysteroid dehydrogenase/type 5 17beta-hydroxysteroid dehydrogenase (AKR1C3)',
#                'GP'],
#               [166, 183, 'prostate carcinoma', 'DS'],
#               [10, 19, 'expression', 'Gene_expression'],
#               [0, 8, 'Increased', 'Positive_regulation']],
#              'We conclude that elevated expression of AKR1C3 is highly associated with prostate carcinoma.': [[40,
#                45,
#                'AKR1C3',
#                'GP'],
#               [73, 90, 'prostate carcinoma', 'DS'],
#               [26, 35, 'expression', 'Gene_expression'],
#               [17, 24, 'elevated', 'Positive_regulation']],
#              'Kaplan-Meier survival analysis confirmed increased RPL19 expression to be highly predictive of shorter patient survival (P &lt; 0.05), revealing RPL19 to be a sensitive predictor of prostate cancer progression.': [[51,
#                55,
#                'RPL19',
#                'GP'],
#               [182, 196, 'prostate cancer', 'DS'],
#               [57, 66, 'expression', 'Gene_expression'],
#               [41, 49, 'increased', 'Positive_regulation']],
#              'Transfection-mediated WWOX overexpression in DU145 cells suppressed colony growth (P = 0.0012), and WWOX overexpression by infection with Ad-WWOX virus induced apoptosis through a caspase-dependent mechanism and suppressed cell growth.': [[100,
#                103,
#                'WWOX',
#                'GP'],
#               [45, 49, 'DU145', 'DS'],
#               [105, 118, 'overexpression', 'Gene_expression'],
#               [105, 118, 'overexpression', 'Positive_regulation']],
#              'Together, our data suggest that strong Tiam1 overexpression relative to the corresponding benign epithelial cells is a new and independent predictor of decreased DFS for patients with prostate cancer.': [[39,
#                43,
#                'Tiam1',
#                'GP'],
#               [184, 198, 'prostate cancer', 'DS'],
#               [45, 58, 'overexpression', 'Gene_expression'],
#               [45, 58, 'overexpression', 'Positive_regulation']],
#              'Polycomb-group oncogenes EZH2, BMI1, and RING1 are overexpressed in prostate cancer with adverse pathologic and clinical features.': [[0,
#                28,
#                'Polycomb-group oncogenes EZH2',
#                'GP'],
#               [68, 82, 'prostate cancer', 'DS'],
#               [51, 63, 'overexpressed', 'Gene_expression'],
#               [51, 63, 'overexpressed', 'Positive_regulation']],
#              'Out of seven isoforms of gal8, the proto isoform gal8e and our newly discovered proto isoform gal8g were upregulated in LNCaP cells compared to PrEC, whereas the two tandem-repeat isoforms gal8a and gal8b were equally expressed in these cells.': [[49,
#                53,
#                'gal8e',
#                'GP'],
#               [120, 124, 'LNCaP', 'DS'],
#               [105, 115, 'upregulated', 'Positive_regulation'],
#               [94, 98, 'gal8g', 'GP'],
#               [120, 124, 'LNCaP', 'DS'],
#               [105, 115, 'upregulated', 'Positive_regulation']],
#              'Increased expression of cyclin B1 sensitizes prostate cancer cells to apoptosis induced by chemotherapy.': [[24,
#                32,
#                'cyclin B1',
#                'GP'],
#               [45, 59, 'prostate cancer', 'DS'],
#               [10, 19, 'expression', 'Gene_expression'],
#               [0, 8, 'Increased', 'Positive_regulation']],
#              'We present here for the first time that signal transducers and activators of transcription 3 (Stat3), which is constitutively activated in a wide variety of human cancers, including prostate cancer, interacts with PKCepsilon.': [[40,
#                91,
#                'signal transducers and activators of transcription 3',
#                'GP'],
#               [182, 196, 'prostate cancer', 'DS'],
#               [126, 134, 'activated', 'Positive_regulation']],
#              'Smad3 is overexpressed in advanced human prostate cancer and necessary for progressive growth of prostate cancer cells in nude mice.': [[0,
#                4,
#                'Smad3',
#                'GP'],
#               [41, 55, 'prostate cancer', 'DS'],
#               [9, 21, 'overexpressed', 'Gene_expression'],
#               [9, 21, 'overexpressed', 'Positive_regulation']],
#              'Clinical data showed that the levels of interleukin-4 (IL-4) are significantly elevated in serum of patients with ablation resistant prostate cancer.': [[40,
#                52,
#                'interleukin-4',
#                'GP'],
#               [133, 147, 'prostate cancer', 'DS'],
#               [30, 35, 'levels', 'Gene_expression'],
#               [79, 86, 'elevated', 'Positive_regulation']],
#              'Overexpression of IL-4 increases the sensitivity of androgen-sensitive LNCaP prostate cancer cells in response to androgen stimulation and enhances the growth of LNCaP cells both in the presence and absence of androgen in vitro and in vivo.': [[18,
#                21,
#                'IL-4',
#                'GP'],
#               [77, 91, 'prostate cancer', 'DS'],
#               [0, 13, 'Overexpression', 'Gene_expression'],
#               [0, 13, 'Overexpression', 'Positive_regulation']],
#              'Loss of BRCA2 promotes prostate cancer cell invasion through up-regulation of matrix metalloproteinase-9.': [[8,
#                12,
#                'BRCA2',
#                'GP'],
#               [23, 37, 'prostate cancer', 'DS'],
#               [0, 3, 'Loss', 'Negative_regulation']],
#              'Consistently, PI3-kinase inhibition with a dominant-negative mutant or MAPK/ERK activation with a gain-of-function mutant reduced MMP-9 levels and prevented migration and invasion in wild-type PC-3 cells.': [[14,
#                23,
#                'PI3-kinase',
#                'GP'],
#               [193, 196, 'PC-3', 'DS'],
#               [25, 34, 'inhibition', 'Negative_regulation']],
#              'Hyaluronan synthase 3 overexpression promotes the growth of TSU prostate cancer cells.': [[0,
#                20,
#                'Hyaluronan synthase 3',
#                'GP'],
#               [64, 78, 'prostate cancer', 'DS'],
#               [22, 35, 'overexpression', 'Gene_expression'],
#               [22, 35, 'overexpression', 'Positive_regulation']],
#              'We have previously described the increased expression of two prostate-specific G-protein coupled receptors (PSGR and PSGR2) in human prostate cancer.': [[108,
#                111,
#                'PSGR',
#                'GP'],
#               [133, 147, 'prostate cancer', 'DS'],
#               [43, 52, 'expression', 'Gene_expression'],
#               [33, 41, 'increased', 'Positive_regulation'],
#               [117, 121, 'PSGR2', 'GP'],
#               [133, 147, 'prostate cancer', 'DS'],
#               [43, 52, 'expression', 'Gene_expression'],
#               [33, 41, 'increased', 'Positive_regulation']],
#              'AMACR was the best single marker of prostate cancer but in 7 of the 59 total cases the expression of AMACR was not significantly elevated while PSGR and/or PSGR2 were substantially elevated.': [[144,
#                147,
#                'PSGR',
#                'GP'],
#               [36, 50, 'prostate cancer', 'DS'],
#               [181, 188, 'elevated', 'Positive_regulation']],
#              'Reduction of AR expression in the two androgen-sensitive prostate cancer cell lines, LNCaP and LAPC4, significantly decreased AR-mediated transcription and cell growth.': [[13,
#                14,
#                'AR',
#                'GP'],
#               [57, 71, 'prostate cancer', 'DS'],
#               [16, 25, 'expression', 'Gene_expression'],
#               [0, 8, 'Reduction', 'Negative_regulation']],
#              'Downregulation of protein kinase C suppresses induction of apoptosis in human prostatic carcinoma cells.': [[18,
#                33,
#                'protein kinase C',
#                'GP'],
#               [78, 96, 'prostatic carcinoma', 'DS'],
#               [0, 13, 'Downregulation', 'Negative_regulation']],
#              'PKC isozyme analysis revealed that chronic PDBu treatment caused downregulation of PKC-alpha and -epsilon in DU-145 cells.': [[83,
#                104,
#                'PKC-alpha and -epsilon',
#                'GP'],
#               [109, 114, 'DU-145', 'DS'],
#               [65, 78, 'downregulation', 'Negative_regulation']],
#              'Antisense bcl-2 oligodeoxynucleotides decreased Bcl-2 protein levels and significantly inhibited PC-3 cell growth in a dose dependent manner.': [[48,
#                60,
#                'Bcl-2 protein',
#                'GP'],
#               [97, 100, 'PC-3', 'DS'],
#               [38, 46, 'decreased', 'Negative_regulation']],
#              'Experimental work in various prostate cancer models revealed that the androgen receptor is frequently upregulated and implicated in tumor progression.': [[70,
#                86,
#                'androgen receptor',
#                'GP'],
#               [29, 43, 'prostate cancer', 'DS'],
#               [102, 112, 'upregulated', 'Positive_regulation']],
#              'EPCR expression is up-regulated both at the mRNA and protein levels in invasive prostate DU-145 and PC-3 cells in comparison to normal prostate epithelial cells (PrEC) and less-invasive LNCaP cells.': [[0,
#                3,
#                'EPCR',
#                'GP'],
#               [89, 94, 'DU-145', 'DS'],
#               [5, 14, 'expression', 'Gene_expression'],
#               [19, 30, 'up-regulated', 'Positive_regulation']],
#              'Response to bicalutamide in LNCaP cells was represented by downregulation of androgen-regulated genes, activation of the p53 pathway and inhibition of telomerase, which was associated with downregulation of v-myc avian myelocytomatosis viral oncogene homologue (MYC) and telomerase reverse transcriptase subunit.': [[121,
#                123,
#                'p53',
#                'GP'],
#               [28, 32, 'LNCaP', 'DS'],
#               [103, 112, 'activation', 'Positive_regulation'],
#               [262, 264, 'MYC', 'GP'],
#               [28, 32, 'LNCaP', 'DS'],
#               [189, 202, 'downregulation', 'Negative_regulation'],
#               [271, 310, 'telomerase reverse transcriptase subunit', 'GP'],
#               [28, 32, 'LNCaP', 'DS'],
#               [189, 202, 'downregulation', 'Negative_regulation']],
#              'In conclusion, we provide an explanation for telomerase inhibition after androgen receptor blockade in LNCaP cells and we also report activation of the p53 pathway in LNCaP cells and in-vitro sensitivity to bicalutamide of low confluent androgen-insensitive DU145 cells.': [[152,
#                154,
#                'p53',
#                'GP'],
#               [103, 107, 'LNCaP', 'DS'],
#               [134, 143, 'activation', 'Positive_regulation'],
#               [73, 89, 'androgen receptor', 'GP'],
#               [103, 107, 'LNCaP', 'DS'],
#               [91, 98, 'blockade', 'Negative_regulation']],
#              'Reactivation of androgen receptor-regulated TMPRSS2:ERG gene expression in castration-resistant prostate cancer.': [[16,
#                50,
#                'androgen receptor-regulated TMPRSS2',
#                'GP'],
#               [96, 110, 'prostate cancer', 'DS'],
#               [0, 11, 'Reactivation', 'Positive_regulation'],
#               [52, 59, 'ERG gene', 'GP'],
#               [96, 110, 'prostate cancer', 'DS'],
#               [61, 70, 'expression', 'Gene_expression'],
#               [0, 11, 'Reactivation', 'Positive_regulation']],
#              'Moreover, as observed in the clinical samples, ERG expression was fully restored in the VCaP xenografts that relapsed after castration, coincident with AR reactivation.': [[47,
#                49,
#                'ERG',
#                'GP'],
#               [88, 91, 'VCaP', 'DS'],
#               [51, 60, 'expression', 'Gene_expression'],
#               [72, 79, 'restored', 'Positive_regulation'],
#               [152, 153, 'AR', 'GP'],
#               [88, 91, 'VCaP', 'DS'],
#               [155, 166, 'reactivation', 'Positive_regulation']],
#              'We observed that re-expression of AR in the AR-negative cells PC3 decreases anchorage-independent growth and Matrigel invasiveness of PC3-AR cells where plasma membrane interaction between AR and EGFR led to an interference with downstream signalling and internalization of activated EGFR.': [[284,
#                287,
#                'EGFR',
#                'GP'],
#               [62, 64, 'PC3', 'DS'],
#               [274, 282, 'activated', 'Positive_regulation']],
#              'M12 cells, like many other human cancer cells, contain constitutively activated signal transducer and activator of transcription 3 (STAT3).': [[132,
#                136,
#                'STAT3',
#                'GP'],
#               [0, 2, 'M12', 'DS'],
#               [70, 78, 'activated', 'Positive_regulation']],
#              'Strikingly, IFN-gamma-induced apoptosis and growth inhibition of M12 cells were associated with persistent suppression of the constitutive tyrosine-phosphorylated STAT3 (pY-STAT3).': [[163,
#                167,
#                'STAT3',
#                'GP'],
#               [65, 67, 'M12', 'DS'],
#               [107, 117, 'suppression', 'Negative_regulation']],
#              'In this study, while demonstrating suppressed levels of Tm1 in the prostate cancer cell lines LNCaP, PC3, and DU-145 compared to normal prostate epithelial cell primary isolates (PrEC), a novel splice variant of the TPM2 gene was identified.': [[56,
#                58,
#                'Tm1',
#                'GP'],
#               [67, 81, 'prostate cancer', 'DS'],
#               [35, 44, 'suppressed', 'Negative_regulation']],
#              'These findings suggest that inhibition of COX-2 development may lead not only to inhibition of the proliferation and metastasis of prostate carcinoma but also to the inhibition of prostate carcinogenesis.': [[42,
#                46,
#                'COX-2',
#                'GP'],
#               [131, 148, 'prostate carcinoma', 'DS'],
#               [28, 37, 'inhibition', 'Negative_regulation']],
#              'Prostate cancer bony metastases show increased expression of the PTH receptor (PTH-IR) and PTH promotes the growth and invasiveness of prostate cancer cells in bone.': [[65,
#                76,
#                'PTH receptor',
#                'GP'],
#               [135, 149, 'prostate cancer', 'DS'],
#               [47, 56, 'expression', 'Gene_expression'],
#               [37, 45, 'increased', 'Positive_regulation'],
#               [79, 84, 'PTH-IR', 'GP'],
#               [135, 149, 'prostate cancer', 'DS'],
#               [47, 56, 'expression', 'Gene_expression'],
#               [37, 45, 'increased', 'Positive_regulation'],
#               [91, 93, 'PTH', 'GP'],
#               [135, 149, 'prostate cancer', 'DS'],
#               [47, 56, 'expression', 'Gene_expression'],
#               [37, 45, 'increased', 'Positive_regulation']],
#              'A broad spectrum of tumor derived cell lines, from varied tissue sources and blood samples from patients having confirmed prostate carcinoma, all scored positive for expression of PTI-1, while corresponding normal tissues or blood samples were negative.': [[180,
#                184,
#                'PTI-1',
#                'GP'],
#               [122, 139, 'prostate carcinoma', 'DS'],
#               [166, 175, 'expression', 'Gene_expression'],
#               [153, 160, 'positive', 'Positive_regulation']],
#              'A decrease in PSA level is associated with both survival and response in soft tissue lesions and should be incorporated into the response criteria and reporting of trials of cytotoxic agents in prostate cancer.': [[14,
#                16,
#                'PSA',
#                'GP'],
#               [194, 208, 'prostate cancer', 'DS'],
#               [2, 9, 'decrease', 'Negative_regulation']],
#              'miR 488* inhibits androgen receptor expression in prostate carcinoma cells.': [[18,
#                34,
#                'androgen receptor',
#                'GP'],
#               [50, 67, 'prostate carcinoma', 'DS'],
#               [36, 45, 'expression', 'Gene_expression'],
#               [9, 16, 'inhibits', 'Negative_regulation']],
#              'NSAIDs exert their anti-inflammatory effects by inhibiting cyclooxygenase (COX) activity; however, evidence suggests that COX-independent mechanisms mediate decreased prostate cancer cell survival.': [[59,
#                72,
#                'cyclooxygenase',
#                'GP'],
#               [167, 181, 'prostate cancer', 'DS'],
#               [48, 57, 'inhibiting', 'Negative_regulation'],
#               [75, 77, 'COX', 'GP'],
#               [167, 181, 'prostate cancer', 'DS'],
#               [48, 57, 'inhibiting', 'Negative_regulation']],
#              'Hence, R-flurbiprofen and ibuprofen selectively induce p75(NTR)-dependent decreased survival of prostate cancer cells independently of COX inhibition.': [[135,
#                137,
#                'COX',
#                'GP'],
#               [96, 110, 'prostate cancer', 'DS'],
#               [139, 148, 'inhibition', 'Negative_regulation']],
#              'Here we show that an increase in the level of expression of Bcl-2 in the human prostate carcinoma cell line LNCaP observed in response to hormone withdrawal is further augmented by TNF-alpha treatment, and this effect is abated by inhibitors of NF-kappa B.': [[245,
#                254,
#                'NF-kappa B',
#                'GP'],
#               [79, 96, 'prostate carcinoma', 'DS'],
#               [231, 240, 'inhibitors', 'Negative_regulation'],
#               [60, 64, 'Bcl-2', 'GP'],
#               [79, 96, 'prostate carcinoma', 'DS'],
#               [46, 55, 'expression', 'Gene_expression'],
#               [21, 28, 'increase', 'Positive_regulation']],
#              'Concomitantly, bcl-2 p2 promoter studies in LNCaP cells show a 40-fold increase in promoter activity after stimulation with TNF-alpha in the absence of hormone.': [[124,
#                132,
#                'TNF-alpha',
#                'GP'],
#               [44, 48, 'LNCaP', 'DS'],
#               [107, 117, 'stimulation', 'Positive_regulation']],
#              'For example, some studies showed that CLU expression is increased in advanced stages of prostate cancer and that suppression of CLU expression sensitizes prostate cancer cells to chemotherapeutic drugs killing.': [[128,
#                130,
#                'CLU',
#                'GP'],
#               [88, 102, 'prostate cancer', 'DS'],
#               [132, 141, 'expression', 'Gene_expression'],
#               [113, 123, 'suppression', 'Negative_regulation'],
#               [38, 40, 'CLU', 'GP'],
#               [88, 102, 'prostate cancer', 'DS'],
#               [42, 51, 'expression', 'Gene_expression'],
#               [56, 64, 'increased', 'Positive_regulation']],
#              'In contrast with the hypothesis that CLU is a positive modulator of prostate cancer, we and others have observed that CLU is downregulated during human prostate cancer progression.': [[118,
#                120,
#                'CLU',
#                'GP'],
#               [68, 82, 'prostate cancer', 'DS'],
#               [125, 137, 'downregulated', 'Negative_regulation']],
#              'Accordingly, a meta-analysis of available microarray data shows that CLU mRNA is significantly downregulated in prostate cancer tissue compared to normal prostate in 14 out of 15 independent studies.': [[69,
#                76,
#                'CLU mRNA',
#                'GP'],
#               [112, 126, 'prostate cancer', 'DS'],
#               [95, 107, 'downregulated', 'Negative_regulation']],
#              'Consistently, CLU expression was found to be significantly reduced in untreated and hormone-refractory human prostate carcinomas.': [[14,
#                16,
#                'CLU',
#                'GP'],
#               [109, 127, 'prostate carcinomas', 'DS'],
#               [18, 27, 'expression', 'Gene_expression'],
#               [59, 65, 'reduced', 'Negative_regulation']],
#              'In PC-3 cells, adhesion molecule expression, analyzed by immunoblotting, was unaffected by LA, while a down-regulation of c-met (up to 28%) was observed after 24 h of treatment but which did not hold up over time (48-144 h).': [[122,
#                126,
#                'c-met',
#                'GP'],
#               [3, 6, 'PC-3', 'DS'],
#               [103, 117, 'down-regulation', 'Negative_regulation']],
#              'Our findings demonstrate the efficacy of LA in upregulating E-cadherin, β- and γ-catenin in LNCaP cells.': [[60,
#                69,
#                'E-cadherin',
#                'GP'],
#               [92, 96, 'LNCaP', 'DS'],
#               [47, 58, 'upregulating', 'Positive_regulation'],
#               [79, 87, 'γ-catenin', 'GP'],
#               [92, 96, 'LNCaP', 'DS'],
#               [47, 58, 'upregulating', 'Positive_regulation']],
#              'In BPH samples there was a significant correlation between CD38 loss (mean 21% of acini) and HLA-DR up-regulation (mean 20%; P &lt; 0.001).': [[93,
#                98,
#                'HLA-DR',
#                'GP'],
#               [3, 5, 'BPH', 'DS'],
#               [100, 112, 'up-regulation', 'Positive_regulation']],
#              'Moreover, 76% of all CD38-negative acini in BPH had HLA-DR up-regulation in the same prostate epithelial cells, predominantly in atrophic and cystic glands, and in cells with retained secretions (74%).': [[52,
#                57,
#                'HLA-DR',
#                'GP'],
#               [44, 46, 'BPH', 'DS'],
#               [59, 71, 'up-regulation', 'Positive_regulation']],
#              'The absence of CD38 and presence of HLA-DR expression in prostatic epithelium is consistent in BPH and tissue surrounding tumour, and strongly related to gland atrophy.': [[15,
#                18,
#                'CD38',
#                'GP'],
#               [95, 97, 'BPH', 'DS'],
#               [4, 10, 'absence', 'Negative_regulation']],
#              'The prostate cancer detection rate in patients with elevated prostate specific antigen (PSA) increases with extended needle biopsy protocols.': [[61,
#                85,
#                'prostate specific antigen',
#                'GP'],
#               [4, 18, 'prostate cancer', 'DS'],
#               [52, 59, 'elevated', 'Positive_regulation'],
#               [88, 90, 'PSA', 'GP'],
#               [4, 18, 'prostate cancer', 'DS'],
#               [52, 59, 'elevated', 'Positive_regulation']],
#              'R-etodolac, a nonsteroidal anti-inflammatory drug, inhibits the progression of CWRSA6 androgen-independent and LuCaP-35 androgen-dependent prostate cancer xenograft growth through downregulation of cyclin D1 expression via the PPARgamma pathway.': [[198,
#                206,
#                'cyclin D1',
#                'GP'],
#               [139, 153, 'prostate cancer', 'DS'],
#               [208, 217, 'expression', 'Gene_expression'],
#               [180, 193, 'downregulation', 'Negative_regulation']],
#              'Constitutive activation of MAPK/ERK inhibits prostate cancer cell proliferation through upregulation of BRCA2.': [[104,
#                108,
#                'BRCA2',
#                'GP'],
#               [45, 59, 'prostate cancer', 'DS'],
#               [88, 99, 'upregulation', 'Positive_regulation']],
#              'Overexpressing PKIB in prostate cancer promotes its aggressiveness by linking between PKA and Akt pathways.': [[15,
#                18,
#                'PKIB',
#                'GP'],
#               [23, 37, 'prostate cancer', 'DS'],
#               [0, 13, 'Overexpressing', 'Gene_expression'],
#               [0, 13, 'Overexpressing', 'Positive_regulation']],
#              'DHT-induced E2F-1 protein and mRNA expressions was also inhibited by BMP-2, suggesting that BMP-2 inhibits DHT-induced growth of LNCaP cells through a decrease in E2F protein expression and suppression of E2F activity by hypophosphorylation of Rb.': [[205,
#                207,
#                'E2F',
#                'GP'],
#               [129, 133, 'LNCaP', 'DS'],
#               [190, 200, 'suppression', 'Negative_regulation'],
#               [163, 173, 'E2F protein', 'GP'],
#               [129, 133, 'LNCaP', 'DS'],
#               [175, 184, 'expression', 'Gene_expression'],
#               [151, 158, 'decrease', 'Negative_regulation'],
#               [12, 24, 'E2F-1 protein', 'GP'],
#               [129, 133, 'LNCaP', 'DS'],
#               [56, 64, 'inhibited', 'Negative_regulation']],
#              'Dual blockade of PKA and NF-κB inhibits H2 relaxin-mediated castrate-resistant growth of prostate cancer sublines and induces apoptosis.': [[17,
#                19,
#                'PKA',
#                'GP'],
#               [89, 103, 'prostate cancer', 'DS'],
#               [5, 12, 'blockade', 'Negative_regulation'],
#               [25, 29, 'NF-κB', 'GP'],
#               [89, 103, 'prostate cancer', 'DS'],
#               [5, 12, 'blockade', 'Negative_regulation']],
#              'Immunohistochemical analysis of tissue microarrays in combination with multispectral quantitative imaging comparing RLN2 levels in patients with benign prostatic hyperplasia (BPH), prostatic intraepithelial neoplasia, and CaP determined that RLN2 is significantly upregulated in CaP vs BPH (p\u2009=\u20090.002).': [[242,
#                245,
#                'RLN2',
#                'GP'],
#               [181, 215, 'prostatic intraepithelial neoplasia', 'DS'],
#               [264, 274, 'upregulated', 'Positive_regulation']],
#              'In surgically excised adult human prostate tissues, localized accumulations of TGF-beta1 are associated with prostate cancer and benign prostatic hyperplasia (BPH).': [[79,
#                87,
#                'TGF-beta1',
#                'GP'],
#               [129, 156, 'benign prostatic hyperplasia', 'DS'],
#               [62, 74, 'accumulations', 'Positive_regulation']],
#              'In human prostate cancer cells, knockdown of ILK expression with siRNA, or inhibition of ILK activity, results in significant inhibition of HIF-1alpha and VEGF expression.': [[140,
#                149,
#                'HIF-1alpha',
#                'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [126, 135, 'inhibition', 'Negative_regulation'],
#               [45, 47, 'ILK', 'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [49, 58, 'expression', 'Gene_expression'],
#               [32, 40, 'knockdown', 'Negative_regulation'],
#               [140, 149, 'HIF-1alpha', 'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [160, 169, 'expression', 'Gene_expression'],
#               [126, 135, 'inhibition', 'Negative_regulation'],
#               [155, 158, 'VEGF', 'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [126, 135, 'inhibition', 'Negative_regulation'],
#               [155, 158, 'VEGF', 'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [160, 169, 'expression', 'Gene_expression'],
#               [126, 135, 'inhibition', 'Negative_regulation'],
#               [89, 91, 'ILK', 'GP'],
#               [9, 23, 'prostate cancer', 'DS'],
#               [75, 84, 'inhibition', 'Negative_regulation']],
#              'Inhibition of ILK activity also inhibits prostate tumor angiogenesis and suppresses tumor growth.': [[14,
#                16,
#                'ILK',
#                'GP'],
#               [41, 54, 'prostate tumor', 'DS'],
#               [0, 9, 'Inhibition', 'Negative_regulation']],
#              'GRP78 up-regulation is associated with androgen receptor status, Hsp70-Hsp90 client proteins and castrate-resistant prostate cancer.': [[0,
#                4,
#                'GRP78',
#                'GP'],
#               [116, 130, 'prostate cancer', 'DS'],
#               [6, 18, 'up-regulation', 'Positive_regulation']],
#              'In keeping with our clinical data, activation of AR by dihydrotestosterone (DHT) potently activated GRP78 expression in both LNCaP and LNCaP-CR cells.': [[100,
#                104,
#                'GRP78',
#                'GP'],
#               [125, 129, 'LNCaP', 'DS'],
#               [106, 115, 'expression', 'Gene_expression'],
#               [90, 98, 'activated', 'Positive_regulation'],
#               [49, 50, 'AR', 'GP'],
#               [125, 129, 'LNCaP', 'DS'],
#               [35, 44, 'activation', 'Positive_regulation']],
#              'Up-regulated expression of AR and GRP78 expression in untreated prostate cancer predicts a less favourable outcome.': [[27,
#                28,
#                'AR',
#                'GP'],
#               [64, 78, 'prostate cancer', 'DS'],
#               [13, 22, 'expression', 'Gene_expression'],
#               [0, 11, 'Up-regulated', 'Positive_regulation']],
#              'TRPV6 and prostate cancer: cancer growth beyond the prostate correlates with increased TRPV6 Ca2+ channel expression.': [[87,
#                91,
#                'TRPV6',
#                'GP'],
#               [10, 24, 'prostate cancer', 'DS'],
#               [106, 115, 'expression', 'Gene_expression'],
#               [77, 85, 'increased', 'Positive_regulation']],
#              'In vitro and in vivo xenograft experiments in NOD/SCID mice further demonstrated that SOX2 increased the apoptosis-resistant properties of DU145 cells with decreased function of store-operated Ca(2+) entry and reduced expression of Orai1 at both mRNA and protein levels, suggesting a potential mechanism that contributes to the anti-apoptotic property of SOX2.': [[232,
#                236,
#                'Orai1',
#                'GP'],
#               [139, 143, 'DU145', 'DS'],
#               [218, 227, 'expression', 'Gene_expression'],
#               [210, 216, 'reduced', 'Negative_regulation']],
#              'TSPO expression is increased in prostatic intraepithelial neoplasia, primary prostate cancer, and metastases compared with normal prostate tissue and benign prostatic hyperplasia.': [[0,
#                3,
#                'TSPO',
#                'GP'],
#               [32, 66, 'prostatic intraepithelial neoplasia', 'DS'],
#               [5, 14, 'expression', 'Gene_expression'],
#               [19, 27, 'increased', 'Positive_regulation']],
#              'These data suggest that blocking TSPO function in tumor cells induces cell death and denotes a survival role for TSPO in prostate cancer and provides the first evidence for the use of benzodiazepines in prostate cancer therapeutics.': [[33,
#                36,
#                'TSPO',
#                'GP'],
#               [121, 135, 'prostate cancer', 'DS'],
#               [24, 31, 'blocking', 'Negative_regulation']],
#              'To evaluate retrospectively the effectiveness of transurethral resection of the prostate (TURP) in diagnosing prostate cancer in patients with obstructive voiding symptoms and a history of negative transrectal prostate biopsy but elevated prostate-specific antigen (PSA) and/or abnormal digital rectal examination (DRE).': [[266,
#                268,
#                'PSA',
#                'GP'],
#               [110, 124, 'prostate cancer', 'DS'],
#               [230, 237, 'elevated', 'Positive_regulation']],
#              'Increased levels of plasma haemoxygenase-1 in prostate cancer.': [[20,
#                41,
#                'plasma haemoxygenase-1',
#                'GP'],
#               [46, 60, 'prostate cancer', 'DS'],
#               [10, 15, 'levels', 'Gene_expression'],
#               [0, 8, 'Increased', 'Positive_regulation']],
#              'PDLIM4 mRNA and protein-expression levels were reduced in LNCaP, LAPC4, DU145, CWR22, and PC3 prostate cancer cells.': [[0,
#                10,
#                'PDLIM4 mRNA',
#                'GP'],
#               [94, 108, 'prostate cancer', 'DS'],
#               [16, 33, 'protein-expression', 'Gene_expression'],
#               [47, 53, 'reduced', 'Negative_regulation'],
#               [0, 10, 'PDLIM4 mRNA', 'GP'],
#               [94, 108, 'prostate cancer', 'DS'],
#               [47, 53, 'reduced', 'Negative_regulation']],
#              'Overexpression of PIM-1 is a potential biomarker in prostate carcinoma.': [[18,
#                22,
#                'PIM-1',
#                'GP'],
#               [52, 69, 'prostate carcinoma', 'DS'],
#               [0, 13, 'Overexpression', 'Gene_expression'],
#               [0, 13, 'Overexpression', 'Positive_regulation']],
#              'Methylseleninic acid enhances taxane drug efficacy against human prostate cancer and down-regulates antiapoptotic proteins Bcl-XL and survivin.': [[123,
#                128,
#                'Bcl-XL',
#                'GP'],
#               [65, 79, 'prostate cancer', 'DS'],
#               [85, 98, 'down-regulates', 'Negative_regulation'],
#               [134, 141, 'survivin', 'GP'],
#               [65, 79, 'prostate cancer', 'DS'],
#               [85, 98, 'down-regulates', 'Negative_regulation']],
#              'Compared with BPH, the PCa patients showed decreased expressions of miR-98, let-7d and let-7g, and decreased expressions of miR-96, miR-182 and miR-183, with statistically significant differences between the two groups (P &lt; 0.05).': [[132,
#                138,
#                'miR-182',
#                'GP'],
#               [14, 16, 'BPH', 'DS'],
#               [109, 119, 'expressions', 'Gene_expression'],
#               [99, 107, 'decreased', 'Negative_regulation'],
#               [144, 150, 'miR-183', 'GP'],
#               [14, 16, 'BPH', 'DS'],
#               [109, 119, 'expressions', 'Gene_expression'],
#               [99, 107, 'decreased', 'Negative_regulation'],
#               [68, 73, 'miR-98', 'GP'],
#               [14, 16, 'BPH', 'DS'],
#               [53, 63, 'expressions', 'Gene_expression'],
#               [43, 51, 'decreased', 'Negative_regulation'],
#               [124, 129, 'miR-96', 'GP'],
#               [14, 16, 'BPH', 'DS'],
#               [109, 119, 'expressions', 'Gene_expression'],
#               [99, 107, 'decreased', 'Negative_regulation']],
#              'With the treatment of 9-cis RA, the NKX3.1 promoter activity was increased in reporter gene assay and NKX3.1 expression was enhanced at both mRNA and protein levels in LNCaP cells.': [[102,
#                107,
#                'NKX3.1',
#                'GP'],
#               [168, 172, 'LNCaP', 'DS'],
#               [109, 118, 'expression', 'Gene_expression'],
#               [124, 131, 'enhanced', 'Positive_regulation'],
#               [36, 50, 'NKX3.1 promoter', 'GP'],
#               [168, 172, 'LNCaP', 'DS'],
#               [65, 73, 'increased', 'Positive_regulation']],
#              'Our results demonstrated that 9-cis RA as a differentiating agent can arrest prostate cancer cells in G(1) phase and reduce cell mitosis, and upregulate the expression of human homeobox gene NKX3.1, which is thought to play an important role in prostate differentiation and to act as a tumor suppressor gene in the prostate.': [[171,
#                196,
#                'human homeobox gene NKX3.1',
#                'GP'],
#               [77, 91, 'prostate cancer', 'DS'],
#               [157, 166, 'expression', 'Gene_expression'],
#               [142, 151, 'upregulate', 'Positive_regulation']],
#              'Our findings indicate that bcl-2 expression is augmented following androgen ablation and is correlated with the progression of prostate cancer from androgen dependence to androgen independence.': [[27,
#                31,
#                'bcl-2',
#                'GP'],
#               [127, 141, 'prostate cancer', 'DS'],
#               [33, 42, 'expression', 'Gene_expression'],
#               [47, 55, 'augmented', 'Positive_regulation']],
#              'A novel component of the ubiquitin pathway, ubiquitin carboxyl extension protein 1 is overexpressed in prostate cancer.': [[44,
#                81,
#                'ubiquitin carboxyl extension protein 1',
#                'GP'],
#               [103, 117, 'prostate cancer', 'DS'],
#               [86, 98, 'overexpressed', 'Gene_expression'],
#               [86, 98, 'overexpressed', 'Positive_regulation']],
#              'Using this approach we found an up-regulation of ubiquitin carboxyl extension protein 1 (UBCEP-1) mRNA in prostate carcinoma cells compared to the normal glandular epithelium of the prostate proper.': [[89,
#                95,
#                'UBCEP-1',
#                'GP'],
#               [106, 123, 'prostate carcinoma', 'DS'],
#               [32, 44, 'up-regulation', 'Positive_regulation'],
# ...
#                'STAT3',
#                'GP'],
#               [109, 121, 'breast cancer', 'DS'],
#               [40, 50, 'expressions', 'Gene_expression'],
#               [76, 84, 'decreased', 'Negative_regulation']],
#              'These compounds decreased ERalpha in MCF-7 cells at both mRNA and protein levels, and suppressed estrogen-stimulated genes.': [[26,
#                32,
#                'ERalpha',
#                'GP'],
#               [37, 41, 'MCF-7', 'DS'],
#               [16, 24, 'decreased', 'Negative_regulation']],
#              'Oestradiol acutely increases PI3-kinase and Akt activities in MCF-7 cells.': [[44,
#                46,
#                'Akt',
#                'GP'],
#               [62, 66, 'MCF-7', 'DS'],
#               [19, 27, 'increases', 'Positive_regulation']],
#              'The Src inhibitor, PP1, prevents hormone stimulation of Akt and PI3-kinase activities in MCF-7 cells.': [[56,
#                58,
#                'Akt',
#                'GP'],
#               [89, 93, 'MCF-7', 'DS'],
#               [41, 51, 'stimulation', 'Positive_regulation']],
#              'In turn, stimulation of Src activity is abolished in ERalpha-expressing NIH 3T3 fibroblasts by co-transfection of the dominant-negative p85alpha and in MCF-7 cells by the PI3-kinase inhibitor, LY294002.': [[118,
#                143,
#                'dominant-negative p85alpha',
#                'GP'],
#               [152, 156, 'MCF-7', 'DS'],
#               [95, 109, 'co-transfection', 'Gene_expression'],
#               [95, 109, 'co-transfection', 'Positive_regulation']],
#              'Our findings suggest loss of E-cadherin expression in some breast cancers may be due to dominant repression of the trans-acting pathways that regulate E-cadherin transcription.': [[29,
#                38,
#                'E-cadherin',
#                'GP'],
#               [59, 72, 'breast cancers', 'DS'],
#               [40, 49, 'expression', 'Gene_expression'],
#               [21, 24, 'loss', 'Negative_regulation']],
#              'Heregulin and agonistic anti-p185(c-erbB2) antibodies inhibit proliferation but increase invasiveness of breast cancer cells that overexpress p185(c-erbB2): increased invasiveness may contribute to poor prognosis.': [[142,
#                145,
#                'p185',
#                'GP'],
#               [105, 117, 'breast cancer', 'DS'],
#               [130, 140, 'overexpress', 'Gene_expression'],
#               [130, 140, 'overexpress', 'Positive_regulation']],
#              'PKC-zeta is required for angiotensin II-induced activation of ERK and synthesis of C-FOS in MCF-7 cells.': [[62,
#                64,
#                'ERK',
#                'GP'],
#               [92, 96, 'MCF-7', 'DS'],
#               [48, 57, 'activation', 'Positive_regulation']],
#              'When the epidermal growth factor-receptor (EGFR) tyrosine kinase activity was inhibited by the use of its inhibitor AG1478, Ang II was still able to induce ERK1/2 phosphorylation and c-fos expression, therefore proving that the transactivation of EGFR was not required for these Ang II effects in MCF-7 cells.': [[9,
#                40,
#                'epidermal growth factor-receptor',
#                'GP'],
#               [297, 301, 'MCF-7', 'DS'],
#               [78, 86, 'inhibited', 'Negative_regulation'],
#               [183, 187, 'c-fos', 'GP'],
#               [297, 301, 'MCF-7', 'DS'],
#               [149, 154, 'induce', 'Positive_regulation']],
#              'Our results suggest that in MCF-7 cells Ang II activates multiple signalling pathways involving PKC-zeta, PI3K and MAPK; of these pathways only PKC-zeta appears responsible for the induction of c-fos.': [[194,
#                198,
#                'c-fos',
#                'GP'],
#               [28, 32, 'MCF-7', 'DS'],
#               [181, 189, 'induction', 'Positive_regulation']],
#              'In the former group, ErbB2 overexpression was strongly associated with increased risk of recurrence (RR = 4.7; 95% CI, 2.1-10.4) and breast cancer death (RR = 5.4; 95% CI, 2.3-12.6).': [[21,
#                25,
#                'ErbB2',
#                'GP'],
#               [133, 145, 'breast cancer', 'DS'],
#               [27, 40, 'overexpression', 'Gene_expression'],
#               [27, 40, 'overexpression', 'Positive_regulation']],
#              'Transfecting A2780 cells with active Notch 1-IC resulted in a proliferative and colony formation advantage compared to mock transfected cells.': [[37,
#                46,
#                'Notch 1-IC',
#                'GP'],
#               [13, 17, 'A2780', 'DS'],
#               [0, 11, 'Transfecting', 'Gene_expression'],
#               [0, 11, 'Transfecting', 'Positive_regulation']],
#              'Immunoblotting analysis demonstrated that PRB protein expression was markedly up-regulated in OVCAR-3, whereas the PRA and PRB isoforms both appeared to be increased in NOV-31.': [[42,
#                52,
#                'PRB protein',
#                'GP'],
#               [94, 100, 'OVCAR-3', 'DS'],
#               [54, 63, 'expression', 'Gene_expression'],
#               [78, 89, 'up-regulated', 'Positive_regulation']],
#              'These results suggest that down-regulation of PRA is associated with the development of ovarian epithelial carcinoma.': [[46,
#                48,
#                'PRA',
#                'GP'],
#               [88, 115, 'ovarian epithelial carcinoma', 'DS'],
#               [27, 41, 'down-regulation', 'Negative_regulation']],
#              'Up-regulation of AR by 1,25(OH)2D3 and of VDR by DHT provides evidence of cross-talk between 2 signaling pathways in OVCAR-3 cells.': [[42,
#                44,
#                'VDR',
#                'GP'],
#               [117, 123, 'OVCAR-3', 'DS'],
#               [0, 12, 'Up-regulation', 'Positive_regulation']],
#              'Overexpression of p185(c-erbB2) (p185/NEU/HER2) by tumor cells is associated with a poor prognosis in many but not all studies of breast and ovarian cancer.': [[33,
#                45,
#                'p185/NEU/HER2',
#                'GP'],
#               [141, 154, 'ovarian cancer', 'DS'],
#               [0, 13, 'Overexpression', 'Gene_expression'],
#               [0, 13, 'Overexpression', 'Positive_regulation']],
#              'Moreover, the poor prognosis of breast and ovarian cancers that overexpress p185(c-erbB2) could relate in part to enhanced invasiveness rather than to increased proliferative capacity.': [[76,
#                79,
#                'p185',
#                'GP'],
#               [43, 57, 'ovarian cancers', 'DS'],
#               [64, 74, 'overexpress', 'Gene_expression'],
#               [64, 74, 'overexpress', 'Positive_regulation']],
#              'Evaluation of differential gene expression in drug-sensitive (A2780) and drug-resistant (A2780cp) ovarian carcinoma cell lines exposed to 0.1 microg/ml HMN-176 up to 48 h using cDNA microarrays with 1,154 known human genes revealed significant drug effects on tumor associated genes, including upregulation of tissue inhibitor matrix metalloproteinases gene (TIMP) in both cell lines, suggesting that HMN-176 could potentially overcome tumor drug resistance.': [[359,
#                362,
#                'TIMP',
#                'GP'],
#               [98, 114, 'ovarian carcinoma', 'DS'],
#               [294, 305, 'upregulation', 'Positive_regulation']],
#              'This study showed that IL-18 serum levels were elevated in ovarian cancer patients and were correlated with overall survival, although they were shown not to be an independent prognostic factor.': [[23,
#                27,
#                'IL-18',
#                'GP'],
#               [59, 72, 'ovarian cancer', 'DS'],
#               [47, 54, 'elevated', 'Positive_regulation']],
#              'Overexpression of TUBB3 protein was observed in 56 (85%) of the 66 ovarian cancers, and was significantly associated with aggressive tumor behavior (advanced stage, presence of ascites, suboptimal cytoreduction at surgery and presence of lymph node metastasis) (P<0.05).': [[18,
#                30,
#                'TUBB3 protein',
#                'GP'],
#               [67, 81, 'ovarian cancers', 'DS'],
#               [0, 13, 'Overexpression', 'Gene_expression'],
#               [0, 13, 'Overexpression', 'Positive_regulation']],
#              'In 2 cell lines with weak expression of TUBB3 protein (OVCAR-3 and JHOC-8), TUBB3 induction was independently induced by treatment with 5-Aza-CdR (JHOC-8) or PBA (OVCAR-3), while neither agent markedly altered TUBB3 mRNA/protein expression in a strongly TUBB3-expressing cell line (JHOC-5).': [[76,
#                80,
#                'TUBB3',
#                'GP'],
#               [55, 61, 'OVCAR-3', 'DS'],
#               [82, 90, 'induction', 'Positive_regulation']],
#              'A CpG island of another cell line showing faint expression of TUBB3 protein (OVCAR-3), in which a significant gain of TUBB3 expression was induced by treatment with PBA but not with 5-Aza-CdR, was hypomethylated, similarly to a cell line (JHOC-5) showing constitutive expression of TUBB3.': [[118,
#                122,
#                'TUBB3',
#                'GP'],
#               [77, 83, 'OVCAR-3', 'DS'],
#               [124, 133, 'expression', 'Gene_expression'],
#               [139, 145, 'induced', 'Positive_regulation']],
#              'p53 accumulation in ovarian carcinomas and its prognostic implications.': [[0,
#                2,
#                'p53',
#                'GP'],
#               [20, 37, 'ovarian carcinomas', 'DS'],
#               [4, 15, 'accumulation', 'Positive_regulation']],
#              'These results suggest that p53 accumulation occurs more frequently in tumors with aggressive behavior and that p53 immunoreactivity may have a prognostic role in certain subsets of patients with ovarian carcinoma.': [[27,
#                29,
#                'p53',
#                'GP'],
#               [195, 211, 'ovarian carcinoma', 'DS'],
#               [31, 42, 'accumulation', 'Positive_regulation']],
#              'Induction of MDR1-gene expression by antineoplastic agents in ovarian cancer cell lines.': [[13,
#                21,
#                'MDR1-gene',
#                'GP'],
#               [62, 75, 'ovarian cancer', 'DS'],
#               [23, 32, 'expression', 'Gene_expression'],
#               [0, 8, 'Induction', 'Positive_regulation']],
#              'Induction of gamma-glutamyl transpeptidase mRNA by platinum complexes in a human ovarian carcinoma cell line.': [[13,
#                46,
#                'gamma-glutamyl transpeptidase mRNA',
#                'GP'],
#               [81, 97, 'ovarian carcinoma', 'DS'],
#               [0, 8, 'Induction', 'Positive_regulation']],
#              'Our previous studies have shown that sublines of human ovarian carcinoma cell line A2780, which exhibited low levels of resistance to oxaliplatin, showed elevated steady state levels of mRNA and activity of gamma-glutamyl transpeptidase (gamma-GT, EC 2.3.2.2), but not of gamma-glutamylcysteine synthetase (gamma-GCS, EC 6.3.2.2) [El-akawi et al., Cancer Lett. 105:5-14; 1966].': [[207,
#                235,
#                'gamma-glutamyl transpeptidase',
#                'GP'],
#               [55, 71, 'ovarian carcinoma', 'DS'],
#               [154, 161, 'elevated', 'Positive_regulation']],
#              'Thus, ING1 mutation is very rare in breast or ovarian cancers, however, repression of ING1 expression frequently accompanies tumour development of breast cancer.': [[86,
#                89,
#                'ING1',
#                'GP'],
#               [46, 60, 'ovarian cancers', 'DS'],
#               [91, 100, 'expression', 'Gene_expression'],
#               [72, 81, 'repression', 'Negative_regulation']],
#              'Pronounced increases in the concentration of an ovarian tumor marker, CA-125, in serum of a healthy subject during menstruation.': [[70,
#                75,
#                'CA-125',
#                'GP'],
#               [48, 60, 'ovarian tumor', 'DS'],
#               [11, 19, 'increases', 'Positive_regulation']],
#              '[Antitumor effect of endothelial progenitor cells with TRAIL gene transfection on ovarian carcinoma xenografts in nude mice].': [[55,
#                64,
#                'TRAIL gene',
#                'GP'],
#               [82, 98, 'ovarian carcinoma', 'DS'],
#               [66, 77, 'transfection', 'Gene_expression'],
#               [66, 77, 'transfection', 'Positive_regulation']],
#              'Lewis y overexpression led to an increase in both mRNA and protein expression levels of cyclin A, cyclin D1 and cyclin E in ovarian cancer cells, decrease in both mRNA and protein expression levels of p16 and p21, and decrease of p27 at only the protein expression level without change in its mRNA level.': [[88,
#                95,
#                'cyclin A',
#                'GP'],
#               [124, 137, 'ovarian cancer', 'DS'],
#               [33, 40, 'increase', 'Positive_regulation'],
#               [230, 232, 'p27', 'GP'],
#               [124, 137, 'ovarian cancer', 'DS'],
#               [218, 225, 'decrease', 'Negative_regulation']],
#              'Abdominopelvic tuberculosis simulating disseminated ovarian carcinoma with elevated CA-125 level: report of two cases.': [[84,
#                89,
#                'CA-125',
#                'GP'],
#               [52, 68, 'ovarian carcinoma', 'DS'],
#               [75, 82, 'elevated', 'Positive_regulation']],
#              'Ovarian cancer patients with elevated CA 125 levels after three chemotherapy courses have a poor prognosis.': [[38,
#                43,
#                'CA 125',
#                'GP'],
#               [0, 13, 'Ovarian cancer', 'DS'],
#               [29, 36, 'elevated', 'Positive_regulation']],
#              'The antisense oligonucleotides targeting VEGF-A significantly decreased VEGF-A protein and mRNA expression and inhibited cell migration in SKOV3 ovarian cancer cells.': [[72,
#                94,
#                'VEGF-A protein and mRNA',
#                'GP'],
#               [145, 158, 'ovarian cancer', 'DS'],
#               [96, 105, 'expression', 'Gene_expression'],
#               [62, 70, 'decreased', 'Negative_regulation']],
#              'This new modified antisense oligonucleotides targeting VEGF-A can decrease VEGF-A expression and inhibit cell migration in SKOV3 ovarian cancer cells.': [[75,
#                80,
#                'VEGF-A',
#                'GP'],
#               [129, 142, 'ovarian cancer', 'DS'],
#               [82, 91, 'expression', 'Gene_expression'],
#               [66, 73, 'decrease', 'Negative_regulation']],
#              'Patients with invasive ovarian cancer were found to have significantly higher median c-erbB-2 oncoprotein expression than patients with either benign ovarian cyst (P = 0.002) or control groups (P = 0.001).': [[85,
#                104,
#                'c-erbB-2 oncoprotein',
#                'GP'],
#               [23, 36, 'ovarian cancer', 'DS'],
#               [106, 115, 'expression', 'Gene_expression'],
#               [71, 76, 'higher', 'Positive_regulation']],
#              'Overexpression of c-erbB-2 oncoprotein was found in seven (21.9%) of 32 epithelial ovarian cancers.': [[18,
#                37,
#                'c-erbB-2 oncoprotein',
#                'GP'],
#               [72, 97, 'epithelial ovarian cancers', 'DS'],
#               [0, 13, 'Overexpression', 'Gene_expression'],
#               [0, 13, 'Overexpression', 'Positive_regulation']],
#              'CCBE1 is expressed in normal ovary, but is reduced in ovarian cancer cell lines and primary carcinomas.': [[0,
#                4,
#                'CCBE1',
#                'GP'],
#               [54, 67, 'ovarian cancer', 'DS'],
#               [43, 49, 'reduced', 'Negative_regulation']],
#              'Pharmacological demethylation/deacetylation in ovarian cancer cell lines re-induced CCBE1 expression, indicating that epigenetic mechanisms contribute to its silencing in cancer.': [[84,
#                88,
#                'CCBE1',
#                'GP'],
#               [47, 60, 'ovarian cancer', 'DS'],
#               [73, 82, 're-induced', 'Positive_regulation']]})

# %%
# Generate train, test and dev pmc ids
import math
import random
import os
import pathlib
import csv
from nltk.tokenize import WordPunctTokenizer, wordpunct_tokenize


def get_train_dev_test_indxs(total_num_annotations):

    percentage=0.80
    iter = 0

    trainids = []
    devids = []
    testids =[]

    nLines = total_num_annotations
    nTrain = int(nLines*percentage) 
    nValid = math.floor((nLines - nTrain)/2)
    nTest = nLines - (nTrain+nValid)

    deck = list(range(0, nLines))
    random.seed(45) # This will be fixed for reproducibility
    random.shuffle(deck)

    train_ids = deck[0:nTrain]
    devel_ids = deck[nTrain:nTrain+nValid]
    test_ids = deck[nTrain+nValid:nTrain+nValid+nTest]

    return train_ids, devel_ids, test_ids

# %%
def find_sub_span(sub_span_range, full_spans_range):
    # if a sub span is present in full span return it
    if sub_span_range[0] in range(full_spans_range[0], full_spans_range[1]):
        return sub_span_range


def convert2IOB(text_data, ner_tags):
    tokenizer = WordPunctTokenizer()

    tokens = []
    ners = []
    spans = []

    split_text = tokenizer.tokenize(text_data)
    span_text = list(tokenizer.span_tokenize(text_data))
    # for each word token append 'O'
    arr = ['O'] * len(split_text)

    if 'None' in ner_tags:
        return zip(split_text, arr)

    ner_tags = sorted(ner_tags, key=lambda x: len(x[3]), reverse=True)

    for each_tag in ner_tags:
        span_list = (each_tag[0], each_tag[1])
        token_list = wordpunct_tokenize(each_tag[2])
        ner_list = wordpunct_tokenize(each_tag[3])

        if (len(token_list) > len(ner_list)):
            ner_list = len(token_list) * ner_list
        for i in range(0, len(ner_list)):
            # The logic here is look for the first B-tag and then append I-tag next
            if (i == 0):
                ner_list[i] = 'B-' + ner_list[i]
            else:
                ner_list[i] = 'I-' + ner_list[i]

        tokens.append(token_list)
        ners.append(ner_list)
        spans.append(span_list)

    split_token_span_list = list(zip(split_text, span_text))
    span_ner_list = list(zip(spans, ners))

    sub_spans = []  # get sub spans from the full spans of the ner

    for each_span_ner_list in span_ner_list:
        # in full range ner e.g., [144, 150, 'GM-CSF', 'GP']
        count = 0
        # count is to keep track of the B, I, sub tags in the ner list
        for each_token in split_token_span_list:
            sub_spans_ = find_sub_span(each_token[1], each_span_ner_list[0])
            if sub_spans_:
                sub_spans.append([sub_spans_, each_span_ner_list[1][count]])
                count = count + 1

    for i, each_span_token in enumerate(split_token_span_list):
        for each_ner_span in sub_spans:
            if each_span_token[1] == each_ner_span[0]:
                arr[i] = ''.join(each_ner_span[1])

    return zip(split_text, arr)

# %%
def convert_to_IOB_format(dictionary_dataset, train_ids, devel_ids, test_ids, path, folder_name):
    
    result_path = cwd_+folder_name
    pathlib.Path(result_path).mkdir(parents=True, exist_ok=True)
    
    with open(result_path + 'train.csv', 'w', newline='\n') as f1, open(result_path + 'devel.csv', 'w',
                        newline='\n') as f2, open(result_path + 'test.csv', 'w', newline='\n') as f3:

        train_writer = csv.writer(f1, delimiter='\t', lineterminator='\n')
        dev_writer = csv.writer(f2, delimiter='\t', lineterminator='\n')
        test_writer = csv.writer(f3, delimiter='\t', lineterminator='\n')
        
        iter = 0

        for key, values in tqdm(dictionary_dataset.items(), total=len(dictionary_dataset)):
            
            text = str(key)
#             print(text)
            tagged_tokens = convert2IOB(text, values)


            if iter in train_ids:
                for each_token in tagged_tokens:
                    train_writer.writerow(list(each_token))
                train_writer.writerow('')

            elif iter in devel_ids:
                for each_token in tagged_tokens:
                    dev_writer.writerow(list(each_token))
                dev_writer.writerow('')

            elif iter in test_ids:
                for each_token in tagged_tokens:
                    test_writer.writerow(list(each_token))
                test_writer.writerow('')
            
            iter = iter+1

# %%
cwd_ = datapath

# %%
trainidx, develidx, testidx = get_train_dev_test_indxs(len(reldataset))
convert_to_IOB_format(reldataset,trainidx, develidx, testidx, cwd_, '/relation_dataset/' )
# Out:
# 100%|██████████| 610/610 [00:00<00:00, 2966.99it/s]
