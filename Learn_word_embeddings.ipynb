# %%
# Here I am using gensim for learning the word embeddings from the EUADR corpus
# This is just a rough start to learn 
import gensim
import logging
import os
import pandas as pd

# %%
# start the log
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO)

# %%
# get the current working directory
data_path = '/home/stirunag/Work/OTAR dumps/'

# Although the dataset says csv, it is tab delimited. In addition to this, they have severe codels problems. 
# So best to parse throught codes first. 
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 2: invalid start byte

#open for reading with "universal" type set

import codecs

sentences_t = codecs.open(data_path+'OTAR_sentences_toy'+'.csv','rU','UTF-8') 
met_gen_sentences = pd.read_csv(sentences_t, header = None)

logging.info("Done reading data files")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-db4efd371140> in <module>
#      10 import codecs
#      11
# ---> 12 sentences_t = codecs.open(data_path+'OTAR_sentences_toy'+'.csv','rU','UTF-8')
#      13 met_gen_sentences = pd.read_csv(sentences_t, header = None)
#      14
#
# ~/anaconda3/lib/python3.7/codecs.py in open(filename, mode, encoding, errors, buffering)
#     896         # Force opening of the file in binary mode
#     897         mode = mode + 'b'
# --> 898     file = builtins.open(filename, mode, buffering)
#     899     if encoding is None:
#     900         return file
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/stirunag/Work/OTAR dumps/OTAR_sentences_toy.csv'

# %%
met_gen_sentences.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
sentences =  met_gen_sentences[6].values.tolist()

# %%
sentences[1:10]
# Out:
# ['Emerging evidence indicates that tumor-promoting macrophages support cancer stem cell renewal, maintenance, and migratory capacity through the secretion of numerous factors including IL-6 and TNFÎ±.',
#  'For the OPN- and Runx1-positive phenotype, switching to the normal intestinal phenotype would require first a switching to the OPN- and Runx1-negative phenotype, from S2 to S1, through suppression of RARs signalling and simultaneous anti-inflammation (reducing Stat3, increasing TGF-Î² signalling).',
#  'Although it is unknown how the increase in macrophage infiltration may effect stem cell populations in PN1a lesions, the increased secretion of IL-6 and TNFÎ± may support cancer stem cell function in PN1a lesions, which could contribute to the enhanced tumor-forming potential of PN1a lesions as compared to PN1b lesions.',
#  'The p53/p27-positive CRC type could be converted to the OPN- and Runx1-positive phenotype via S4, by promoting inflammation (NF-ÎºB and TNF-Î±) and suppressing retinoic acid signalling RARs.',
#  'Suppression of insulin receptor activation by overexpression of the protein-tyrosine phosphatase LAR in hepatoma cells.',
#  'The etiology of diabetic cataract is usually explained by the following process; the conversion of glucose and galactose to polyol by aldose reductase, then the accumulation of polyol in lens, and the opacity of lens.',
#  'How many patients with rheumatic diseases and TNF inhibitors treatment have latent tuberculosis?',
#  'Emerging evidence indicates that tumor-promoting macrophages support cancer stem cell renewal, maintenance, and migratory capacity through the secretion of numerous factors including IL-6 and TNFÎ±.',
#  'A portion of the cells was treated with 0.5 ÃŽÂ¼mol/l staurosporine and examined for signs of apoptosis by assessing mitochondrial membrane polarisation state (intravital JC-1 staining), by YO-PRO-1 and propidium iodide staining, by determining fragmentation of nuclei by sub-G1 DNA content, by immunocytochemistry for cleaved caspase-3, cleaved caspase-8, Bcl2-associated X protein (Bax) and B-cell lymphoma 2 (Bcl-2), and by western blotting for cleaved caspase-3 and cleaved poly (ADP-ribose) polymerase (PARP).']

# %%
#########################  tokenisation ###############################################
documents = []
for row in sentences:
    try:
        documents.append(row.split())
    except AttributeError:
        pass

# %%
documents[1:3]
# Out:
# [['Emerging',
#   'evidence',
#   'indicates',
#   'that',
#   'tumor-promoting',
#   'macrophages',
#   'support',
#   'cancer',
#   'stem',
#   'cell',
#   'renewal,',
#   'maintenance,',
#   'and',
#   'migratory',
#   'capacity',
#   'through',
#   'the',
#   'secretion',
#   'of',
#   'numerous',
#   'factors',
#   'including',
#   'IL-6',
#   'and',
#   'TNFÎ±.'],
#  ['For',
#   'the',
#   'OPN-',
#   'and',
#   'Runx1-positive',
#   'phenotype,',
#   'switching',
#   'to',
#   'the',
#   'normal',
#   'intestinal',
#   'phenotype',
#   'would',
#   'require',
#   'first',
#   'a',
#   'switching',
#   'to',
#   'the',
#   'OPN-',
#   'and',
#   'Runx1-negative',
#   'phenotype,',
#   'from',
#   'S2',
#   'to',
#   'S1,',
#   'through',
#   'suppression',
#   'of',
#   'RARs',
#   'signalling',
#   'and',
#   'simultaneous',
#   'anti-inflammation',
#   '(reducing',
#   'Stat3,',
#   'increasing',
#   'TGF-Î²',
#   'signalling).']]

# %%
from gensim.models import Word2Vec, Phrases, phrases, KeyedVectors


# OTAR_wv = KeyedVectors.load_word2vec_format('/home/santosh/pre-trained_word_embeddings/PubMed-and-PMC-w2v.bin', binary=True)

# min_count = 3
# model = Word2Vec(size=200, min_count=min_count, iter=10, window=10, workers=10)
# model.build_vocab(documents)
# training_examples_count = model.corpus_count
# # below line will make it 1, so saving it before
# model.build_vocab([list(PMC_wv.vocab.keys())], update=True)
# model.intersect_word2vec_format("/home/santosh/pre-trained_word_embeddings/PubMed-and-PMC-w2v.bin", binary=True, lockf=1.0)
# model.train(sentences, total_examples=training_examples_count, epochs=model.iter)


model = gensim.models.Word2Vec(
    documents,
    size=300,
    window=10,
    min_count=5,
    workers=10)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# 2019-08-08 17:49:58,781 : INFO : collecting all words and their counts
# 2019-08-08 17:49:58,790 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-08-08 17:49:59,772 : INFO : PROGRESS: at sentence #10000, processed 315825 words, keeping 27479 word types
# 2019-08-08 17:50:00,450 : INFO : PROGRESS: at sentence #20000, processed 624089 words, keeping 44954 word types
# 2019-08-08 17:50:00,717 : INFO : PROGRESS: at sentence #30000, processed 918795 words, keeping 59491 word types
# 2019-08-08 17:50:00,952 : INFO : PROGRESS: at sentence #40000, processed 1220174 words, keeping 73359 word types
# 2019-08-08 17:50:01,204 : INFO : PROGRESS: at sentence #50000, processed 1535313 words, keeping 86379 word types
# 2019-08-08 17:50:01,625 : INFO : PROGRESS: at sentence #60000, processed 1857486 words, keeping 98478 word types
# 2019-08-08 17:50:02,021 : INFO : PROGRESS: at sentence #70000, processed 2170482 words, keeping 110622 word types
# 2019-08-08 17:50:02,395 : INFO : PROGRESS: at sentence #80000, processed 2494705 words, keeping 124075 word types
# 2019-08-08 17:50:02,647 : INFO : PROGRESS: at sentence #90000, processed 2800303 words, keeping 134348 word types
# 2019-08-08 17:50:02,959 : INFO : PROGRESS: at sentence #100000, processed 3119784 words, keeping 145459 word types
# 2019-08-08 17:50:03,345 : INFO : PROGRESS: at sentence #110000, processed 3451949 words, keeping 156281 word types
# 2019-08-08 17:50:03,620 : INFO : PROGRESS: at sentence #120000, processed 3754562 words, keeping 164807 word types
# 2019-08-08 17:50:03,896 : INFO : PROGRESS: at sentence #130000, processed 4069379 words, keeping 174027 word types
# 2019-08-08 17:50:04,159 : INFO : PROGRESS: at sentence #140000, processed 4397521 words, keeping 182971 word types
# 2019-08-08 17:50:04,405 : INFO : PROGRESS: at sentence #150000, processed 4706229 words, keeping 191443 word types
# 2019-08-08 17:50:04,659 : INFO : PROGRESS: at sentence #160000, processed 5014834 words, keeping 200837 word types
# 2019-08-08 17:50:04,900 : INFO : PROGRESS: at sentence #170000, processed 5317381 words, keeping 208205 word types
# 2019-08-08 17:50:05,185 : INFO : PROGRESS: at sentence #180000, processed 5616202 words, keeping 216213 word types
# 2019-08-08 17:50:05,409 : INFO : PROGRESS: at sentence #190000, processed 5910276 words, keeping 223754 word types
# 2019-08-08 17:50:05,630 : INFO : PROGRESS: at sentence #200000, processed 6217245 words, keeping 232350 word types
# 2019-08-08 17:50:05,881 : INFO : PROGRESS: at sentence #210000, processed 6524398 words, keeping 240058 word types
# 2019-08-08 17:50:06,157 : INFO : PROGRESS: at sentence #220000, processed 6833554 words, keeping 247526 word types
# 2019-08-08 17:50:06,425 : INFO : PROGRESS: at sentence #230000, processed 7156415 words, keeping 255138 word types
# 2019-08-08 17:50:06,690 : INFO : PROGRESS: at sentence #240000, processed 7464663 words, keeping 262855 word types
# 2019-08-08 17:50:06,959 : INFO : PROGRESS: at sentence #250000, processed 7776043 words, keeping 271726 word types
# 2019-08-08 17:50:07,206 : INFO : PROGRESS: at sentence #260000, processed 8082581 words, keeping 279730 word types
# 2019-08-08 17:50:07,509 : INFO : PROGRESS: at sentence #270000, processed 8383650 words, keeping 286232 word types
# 2019-08-08 17:50:07,769 : INFO : PROGRESS: at sentence #280000, processed 8683104 words, keeping 292196 word types
# 2019-08-08 17:50:08,021 : INFO : PROGRESS: at sentence #290000, processed 8989752 words, keeping 299153 word types
# 2019-08-08 17:50:08,219 : INFO : PROGRESS: at sentence #300000, processed 9278077 words, keeping 305234 word types
# 2019-08-08 17:50:08,455 : INFO : PROGRESS: at sentence #310000, processed 9566944 words, keeping 312144 word types
# 2019-08-08 17:50:08,718 : INFO : PROGRESS: at sentence #320000, processed 9884578 words, keeping 318906 word types
# 2019-08-08 17:50:08,953 : INFO : PROGRESS: at sentence #330000, processed 10202316 words, keeping 326120 word types
# 2019-08-08 17:50:09,229 : INFO : PROGRESS: at sentence #340000, processed 10505698 words, keeping 333672 word types
# 2019-08-08 17:50:09,533 : INFO : PROGRESS: at sentence #350000, processed 10809745 words, keeping 341559 word types
# 2019-08-08 17:50:09,787 : INFO : PROGRESS: at sentence #360000, processed 11129046 words, keeping 350290 word types
# 2019-08-08 17:50:10,093 : INFO : PROGRESS: at sentence #370000, processed 11436538 words, keeping 357017 word types
# 2019-08-08 17:50:10,332 : INFO : PROGRESS: at sentence #380000, processed 11750847 words, keeping 363658 word types
# 2019-08-08 17:50:10,734 : INFO : PROGRESS: at sentence #390000, processed 12082213 words, keeping 370934 word types
# 2019-08-08 17:50:11,117 : INFO : PROGRESS: at sentence #400000, processed 12396722 words, keeping 378376 word types
# 2019-08-08 17:50:11,444 : INFO : PROGRESS: at sentence #410000, processed 12712324 words, keeping 385879 word types
# 2019-08-08 17:50:11,683 : INFO : PROGRESS: at sentence #420000, processed 13005800 words, keeping 392283 word types
# 2019-08-08 17:50:11,905 : INFO : PROGRESS: at sentence #430000, processed 13297945 words, keeping 398691 word types
# 2019-08-08 17:50:12,169 : INFO : PROGRESS: at sentence #440000, processed 13586689 words, keeping 404263 word types
# 2019-08-08 17:50:12,414 : INFO : PROGRESS: at sentence #450000, processed 13892726 words, keeping 410865 word types
# 2019-08-08 17:50:12,745 : INFO : PROGRESS: at sentence #460000, processed 14246338 words, keeping 416620 word types
# 2019-08-08 17:50:12,984 : INFO : PROGRESS: at sentence #470000, processed 14550578 words, keeping 422996 word types
# 2019-08-08 17:50:13,246 : INFO : PROGRESS: at sentence #480000, processed 14856737 words, keeping 429117 word types
# 2019-08-08 17:50:13,499 : INFO : PROGRESS: at sentence #490000, processed 15148473 words, keeping 434724 word types
# 2019-08-08 17:50:13,700 : INFO : PROGRESS: at sentence #500000, processed 15444429 words, keeping 440924 word types
# 2019-08-08 17:50:13,936 : INFO : PROGRESS: at sentence #510000, processed 15751308 words, keeping 446655 word types
# 2019-08-08 17:50:14,220 : INFO : PROGRESS: at sentence #520000, processed 16058201 words, keeping 452336 word types
# 2019-08-08 17:50:14,442 : INFO : PROGRESS: at sentence #530000, processed 16366609 words, keeping 458365 word types
# 2019-08-08 17:50:14,742 : INFO : PROGRESS: at sentence #540000, processed 16703755 words, keeping 467563 word types
# 2019-08-08 17:50:15,032 : INFO : PROGRESS: at sentence #550000, processed 17013946 words, keeping 473399 word types
# 2019-08-08 17:50:15,252 : INFO : PROGRESS: at sentence #560000, processed 17322908 words, keeping 479651 word types
# 2019-08-08 17:50:15,522 : INFO : PROGRESS: at sentence #570000, processed 17623572 words, keeping 485876 word types
# 2019-08-08 17:50:15,734 : INFO : PROGRESS: at sentence #580000, processed 17911318 words, keeping 490860 word types
# 2019-08-08 17:50:15,954 : INFO : PROGRESS: at sentence #590000, processed 18203608 words, keeping 496261 word types
# 2019-08-08 17:50:16,234 : INFO : PROGRESS: at sentence #600000, processed 18505419 words, keeping 502643 word types
# 2019-08-08 17:50:16,450 : INFO : PROGRESS: at sentence #610000, processed 18813581 words, keeping 508768 word types
# 2019-08-08 17:50:16,704 : INFO : PROGRESS: at sentence #620000, processed 19130913 words, keeping 514877 word types
# 2019-08-08 17:50:16,979 : INFO : PROGRESS: at sentence #630000, processed 19456221 words, keeping 520440 word types
# 2019-08-08 17:50:17,320 : INFO : PROGRESS: at sentence #640000, processed 19785540 words, keeping 528487 word types
# 2019-08-08 17:50:17,684 : INFO : PROGRESS: at sentence #650000, processed 20135957 words, keeping 535064 word types
# 2019-08-08 17:50:17,919 : INFO : PROGRESS: at sentence #660000, processed 20453629 words, keeping 541077 word types
# 2019-08-08 17:50:18,203 : INFO : PROGRESS: at sentence #670000, processed 20749151 words, keeping 546293 word types
# 2019-08-08 17:50:18,439 : INFO : PROGRESS: at sentence #680000, processed 21071095 words, keeping 551732 word types
# 2019-08-08 17:50:18,650 : INFO : PROGRESS: at sentence #690000, processed 21364479 words, keeping 556549 word types
# 2019-08-08 17:50:18,853 : INFO : PROGRESS: at sentence #700000, processed 21662574 words, keeping 561733 word types
# 2019-08-08 17:50:19,104 : INFO : PROGRESS: at sentence #710000, processed 21978158 words, keeping 567276 word types
# 2019-08-08 17:50:19,413 : INFO : PROGRESS: at sentence #720000, processed 22285470 words, keeping 573082 word types
# 2019-08-08 17:50:19,641 : INFO : PROGRESS: at sentence #730000, processed 22589974 words, keeping 578308 word types
# 2019-08-08 17:50:19,882 : INFO : PROGRESS: at sentence #740000, processed 22897098 words, keeping 583515 word types
# 2019-08-08 17:50:20,144 : INFO : PROGRESS: at sentence #750000, processed 23224739 words, keeping 590569 word types
# 2019-08-08 17:50:20,455 : INFO : PROGRESS: at sentence #760000, processed 23554152 words, keeping 596381 word types
# 2019-08-08 17:50:20,745 : INFO : PROGRESS: at sentence #770000, processed 23931290 words, keeping 602333 word types
# 2019-08-08 17:50:21,075 : INFO : PROGRESS: at sentence #780000, processed 24245024 words, keeping 609008 word types
# 2019-08-08 17:50:21,310 : INFO : PROGRESS: at sentence #790000, processed 24553939 words, keeping 614533 word types
# 2019-08-08 17:50:21,537 : INFO : PROGRESS: at sentence #800000, processed 24861855 words, keeping 620032 word types
# 2019-08-08 17:50:21,753 : INFO : PROGRESS: at sentence #810000, processed 25159756 words, keeping 625570 word types
# 2019-08-08 17:50:22,112 : INFO : PROGRESS: at sentence #820000, processed 25473874 words, keeping 631793 word types
# 2019-08-08 17:50:22,343 : INFO : PROGRESS: at sentence #830000, processed 25771260 words, keeping 637264 word types
# 2019-08-08 17:50:22,685 : INFO : PROGRESS: at sentence #840000, processed 26082560 words, keeping 643352 word types
# 2019-08-08 17:50:22,943 : INFO : PROGRESS: at sentence #850000, processed 26422926 words, keeping 649067 word types
# 2019-08-08 17:50:23,253 : INFO : PROGRESS: at sentence #860000, processed 26725689 words, keeping 654694 word types
# 2019-08-08 17:50:23,494 : INFO : PROGRESS: at sentence #870000, processed 27022905 words, keeping 659463 word types
# 2019-08-08 17:50:23,731 : INFO : PROGRESS: at sentence #880000, processed 27315464 words, keeping 663997 word types
# 2019-08-08 17:50:24,031 : INFO : PROGRESS: at sentence #890000, processed 27620224 words, keeping 669296 word types
# 2019-08-08 17:50:24,334 : INFO : PROGRESS: at sentence #900000, processed 27934916 words, keeping 675944 word types
# 2019-08-08 17:50:24,553 : INFO : PROGRESS: at sentence #910000, processed 28255201 words, keeping 682562 word types
# 2019-08-08 17:50:24,815 : INFO : PROGRESS: at sentence #920000, processed 28564767 words, keeping 688181 word types
# 2019-08-08 17:50:25,080 : INFO : PROGRESS: at sentence #930000, processed 28883596 words, keeping 694621 word types
# 2019-08-08 17:50:25,399 : INFO : PROGRESS: at sentence #940000, processed 29199682 words, keeping 699899 word types
# 2019-08-08 17:50:25,596 : INFO : PROGRESS: at sentence #950000, processed 29500382 words, keeping 705337 word types
# 2019-08-08 17:50:25,839 : INFO : PROGRESS: at sentence #960000, processed 29801396 words, keeping 710483 word types
# 2019-08-08 17:50:26,175 : INFO : PROGRESS: at sentence #970000, processed 30114608 words, keeping 715288 word types
# 2019-08-08 17:50:26,356 : INFO : PROGRESS: at sentence #980000, processed 30419425 words, keeping 720334 word types
# 2019-08-08 17:50:26,497 : INFO : PROGRESS: at sentence #990000, processed 30706820 words, keeping 724657 word types
# 2019-08-08 17:50:26,672 : INFO : PROGRESS: at sentence #1000000, processed 31002433 words, keeping 729382 word types
# 2019-08-08 17:50:26,844 : INFO : PROGRESS: at sentence #1010000, processed 31307044 words, keeping 733917 word types
# 2019-08-08 17:50:27,038 : INFO : PROGRESS: at sentence #1020000, processed 31610538 words, keeping 738615 word types
# 2019-08-08 17:50:27,212 : INFO : PROGRESS: at sentence #1030000, processed 31916475 words, keeping 743890 word types
# 2019-08-08 17:50:27,384 : INFO : PROGRESS: at sentence #1040000, processed 32249053 words, keeping 752268 word types
# 2019-08-08 17:50:27,528 : INFO : PROGRESS: at sentence #1050000, processed 32565278 words, keeping 758024 word types
# 2019-08-08 17:50:27,749 : INFO : PROGRESS: at sentence #1060000, processed 32874206 words, keeping 763041 word types
# 2019-08-08 17:50:27,921 : INFO : PROGRESS: at sentence #1070000, processed 33180537 words, keeping 768110 word types
# 2019-08-08 17:50:28,143 : INFO : PROGRESS: at sentence #1080000, processed 33496039 words, keeping 773974 word types
# 2019-08-08 17:50:28,323 : INFO : PROGRESS: at sentence #1090000, processed 33811802 words, keeping 778122 word types
# 2019-08-08 17:50:28,485 : INFO : PROGRESS: at sentence #1100000, processed 34111949 words, keeping 783091 word types
# 2019-08-08 17:50:28,649 : INFO : PROGRESS: at sentence #1110000, processed 34405982 words, keeping 788727 word types
# 2019-08-08 17:50:28,857 : INFO : PROGRESS: at sentence #1120000, processed 34774932 words, keeping 795668 word types
# 2019-08-08 17:50:29,139 : INFO : PROGRESS: at sentence #1130000, processed 35073866 words, keeping 800943 word types
# 2019-08-08 17:50:29,292 : INFO : PROGRESS: at sentence #1140000, processed 35381329 words, keeping 806051 word types
# 2019-08-08 17:50:29,496 : INFO : PROGRESS: at sentence #1150000, processed 35698843 words, keeping 811174 word types
# 2019-08-08 17:50:29,739 : INFO : PROGRESS: at sentence #1160000, processed 36036632 words, keeping 817046 word types
# 2019-08-08 17:50:29,909 : INFO : PROGRESS: at sentence #1170000, processed 36366972 words, keeping 822258 word types
# 2019-08-08 17:50:30,085 : INFO : PROGRESS: at sentence #1180000, processed 36672567 words, keeping 826955 word types
# 2019-08-08 17:50:30,241 : INFO : PROGRESS: at sentence #1190000, processed 36971499 words, keeping 831463 word types
# 2019-08-08 17:50:30,438 : INFO : PROGRESS: at sentence #1200000, processed 37267503 words, keeping 835741 word types
# 2019-08-08 17:50:30,580 : INFO : PROGRESS: at sentence #1210000, processed 37557226 words, keeping 840209 word types
# 2019-08-08 17:50:30,760 : INFO : PROGRESS: at sentence #1220000, processed 37852426 words, keeping 844677 word types
# 2019-08-08 17:50:30,940 : INFO : PROGRESS: at sentence #1230000, processed 38176292 words, keeping 849037 word types
# 2019-08-08 17:50:31,145 : INFO : PROGRESS: at sentence #1240000, processed 38466553 words, keeping 852994 word types
# 2019-08-08 17:50:31,314 : INFO : PROGRESS: at sentence #1250000, processed 38761989 words, keeping 857490 word types
# 2019-08-08 17:50:31,488 : INFO : PROGRESS: at sentence #1260000, processed 39063042 words, keeping 862461 word types
# 2019-08-08 17:50:31,667 : INFO : PROGRESS: at sentence #1270000, processed 39356693 words, keeping 867286 word types
# 2019-08-08 17:50:31,929 : INFO : PROGRESS: at sentence #1280000, processed 39726133 words, keeping 873338 word types
# 2019-08-08 17:50:32,155 : INFO : PROGRESS: at sentence #1290000, processed 40040095 words, keeping 878558 word types
# 2019-08-08 17:50:32,310 : INFO : PROGRESS: at sentence #1300000, processed 40358679 words, keeping 883491 word types
# 2019-08-08 17:50:32,515 : INFO : PROGRESS: at sentence #1310000, processed 40716675 words, keeping 889172 word types
# 2019-08-08 17:50:32,665 : INFO : PROGRESS: at sentence #1320000, processed 41008036 words, keeping 893471 word types
# 2019-08-08 17:50:32,927 : INFO : PROGRESS: at sentence #1330000, processed 41333372 words, keeping 897983 word types
# 2019-08-08 17:50:33,088 : INFO : PROGRESS: at sentence #1340000, processed 41637865 words, keeping 902467 word types
# 2019-08-08 17:50:33,251 : INFO : PROGRESS: at sentence #1350000, processed 41929087 words, keeping 906889 word types
# 2019-08-08 17:50:33,403 : INFO : PROGRESS: at sentence #1360000, processed 42213868 words, keeping 910831 word types
# 2019-08-08 17:50:33,613 : INFO : PROGRESS: at sentence #1370000, processed 42529977 words, keeping 915220 word types
# 2019-08-08 17:50:33,774 : INFO : PROGRESS: at sentence #1380000, processed 42826516 words, keeping 919626 word types
# 2019-08-08 17:50:33,928 : INFO : PROGRESS: at sentence #1390000, processed 43123664 words, keeping 923604 word types
# 2019-08-08 17:50:34,096 : INFO : PROGRESS: at sentence #1400000, processed 43416507 words, keeping 928504 word types
# 2019-08-08 17:50:34,273 : INFO : PROGRESS: at sentence #1410000, processed 43720165 words, keeping 933623 word types
# 2019-08-08 17:50:34,480 : INFO : PROGRESS: at sentence #1420000, processed 44017331 words, keeping 939017 word types
# 2019-08-08 17:50:34,655 : INFO : PROGRESS: at sentence #1430000, processed 44319714 words, keeping 942978 word types
# 2019-08-08 17:50:34,826 : INFO : PROGRESS: at sentence #1440000, processed 44629574 words, keeping 947690 word types
# 2019-08-08 17:50:35,030 : INFO : PROGRESS: at sentence #1450000, processed 44933211 words, keeping 952479 word types
# 2019-08-08 17:50:35,178 : INFO : PROGRESS: at sentence #1460000, processed 45233253 words, keeping 956640 word types
# 2019-08-08 17:50:35,401 : INFO : PROGRESS: at sentence #1470000, processed 45542440 words, keeping 960879 word types
# 2019-08-08 17:50:35,557 : INFO : PROGRESS: at sentence #1480000, processed 45848536 words, keeping 965069 word types
# 2019-08-08 17:50:35,736 : INFO : PROGRESS: at sentence #1490000, processed 46155641 words, keeping 969191 word types
# 2019-08-08 17:50:35,919 : INFO : PROGRESS: at sentence #1500000, processed 46459555 words, keeping 972966 word types
# 2019-08-08 17:50:36,164 : INFO : PROGRESS: at sentence #1510000, processed 46759739 words, keeping 977326 word types
# 2019-08-08 17:50:36,381 : INFO : PROGRESS: at sentence #1520000, processed 47078782 words, keeping 981584 word types
# 2019-08-08 17:50:36,559 : INFO : PROGRESS: at sentence #1530000, processed 47384377 words, keeping 986064 word types
# 2019-08-08 17:50:36,706 : INFO : PROGRESS: at sentence #1540000, processed 47670583 words, keeping 990031 word types
# 2019-08-08 17:50:36,880 : INFO : PROGRESS: at sentence #1550000, processed 47958623 words, keeping 994130 word types
# 2019-08-08 17:50:37,233 : INFO : PROGRESS: at sentence #1560000, processed 48265564 words, keeping 998531 word types
# 2019-08-08 17:50:37,456 : INFO : PROGRESS: at sentence #1570000, processed 48579509 words, keeping 1003513 word types
# 2019-08-08 17:50:37,621 : INFO : PROGRESS: at sentence #1580000, processed 48879309 words, keeping 1007666 word types
# 2019-08-08 17:50:37,779 : INFO : PROGRESS: at sentence #1590000, processed 49171798 words, keeping 1011679 word types
# 2019-08-08 17:50:37,940 : INFO : PROGRESS: at sentence #1600000, processed 49466243 words, keeping 1016172 word types
# 2019-08-08 17:50:38,153 : INFO : PROGRESS: at sentence #1610000, processed 49769950 words, keeping 1020220 word types
# 2019-08-08 17:50:38,351 : INFO : PROGRESS: at sentence #1620000, processed 50063128 words, keeping 1024021 word types
# 2019-08-08 17:50:38,504 : INFO : PROGRESS: at sentence #1630000, processed 50357518 words, keeping 1027737 word types
# 2019-08-08 17:50:38,658 : INFO : PROGRESS: at sentence #1640000, processed 50658186 words, keeping 1032354 word types
# 2019-08-08 17:50:38,862 : INFO : PROGRESS: at sentence #1650000, processed 50958867 words, keeping 1036195 word types
# 2019-08-08 17:50:39,029 : INFO : PROGRESS: at sentence #1660000, processed 51261713 words, keeping 1040442 word types
# 2019-08-08 17:50:39,210 : INFO : PROGRESS: at sentence #1670000, processed 51575172 words, keeping 1044229 word types
# 2019-08-08 17:50:39,434 : INFO : PROGRESS: at sentence #1680000, processed 51894942 words, keeping 1048658 word types
# 2019-08-08 17:50:39,593 : INFO : PROGRESS: at sentence #1690000, processed 52203285 words, keeping 1052875 word types
# 2019-08-08 17:50:39,756 : INFO : PROGRESS: at sentence #1700000, processed 52509241 words, keeping 1057728 word types
# 2019-08-08 17:50:39,962 : INFO : PROGRESS: at sentence #1710000, processed 52818556 words, keeping 1061741 word types
# 2019-08-08 17:50:40,145 : INFO : PROGRESS: at sentence #1720000, processed 53113487 words, keeping 1065896 word types
# 2019-08-08 17:50:40,352 : INFO : PROGRESS: at sentence #1730000, processed 53426596 words, keeping 1070389 word types
# 2019-08-08 17:50:40,527 : INFO : PROGRESS: at sentence #1740000, processed 53720976 words, keeping 1074840 word types
# 2019-08-08 17:50:40,787 : INFO : PROGRESS: at sentence #1750000, processed 54026089 words, keeping 1079193 word types
# 2019-08-08 17:50:41,071 : INFO : PROGRESS: at sentence #1760000, processed 54317996 words, keeping 1083561 word types
# 2019-08-08 17:50:41,377 : INFO : PROGRESS: at sentence #1770000, processed 54621172 words, keeping 1088757 word types
# 2019-08-08 17:50:41,637 : INFO : PROGRESS: at sentence #1780000, processed 54942025 words, keeping 1094676 word types
# 2019-08-08 17:50:41,901 : INFO : PROGRESS: at sentence #1790000, processed 55256542 words, keeping 1101473 word types
# 2019-08-08 17:50:42,189 : INFO : PROGRESS: at sentence #1800000, processed 55570584 words, keeping 1105888 word types
# 2019-08-08 17:50:42,411 : INFO : PROGRESS: at sentence #1810000, processed 55871686 words, keeping 1109730 word types
# 2019-08-08 17:50:42,678 : INFO : PROGRESS: at sentence #1820000, processed 56185785 words, keeping 1114293 word types
# 2019-08-08 17:50:42,953 : INFO : PROGRESS: at sentence #1830000, processed 56478749 words, keeping 1118344 word types
# 2019-08-08 17:50:43,260 : INFO : PROGRESS: at sentence #1840000, processed 56802732 words, keeping 1124193 word types
# 2019-08-08 17:50:43,496 : INFO : PROGRESS: at sentence #1850000, processed 57107353 words, keeping 1129153 word types
# 2019-08-08 17:50:43,689 : INFO : PROGRESS: at sentence #1860000, processed 57406921 words, keeping 1133257 word types
# 2019-08-08 17:50:43,963 : INFO : PROGRESS: at sentence #1870000, processed 57710365 words, keeping 1137470 word types
# 2019-08-08 17:50:44,250 : INFO : PROGRESS: at sentence #1880000, processed 58031237 words, keeping 1143330 word types
# 2019-08-08 17:50:44,524 : INFO : PROGRESS: at sentence #1890000, processed 58341353 words, keeping 1148624 word types
# 2019-08-08 17:50:44,871 : INFO : PROGRESS: at sentence #1900000, processed 58675126 words, keeping 1153409 word types
# 2019-08-08 17:50:45,507 : INFO : PROGRESS: at sentence #1910000, processed 58974309 words, keeping 1157576 word types
# 2019-08-08 17:50:45,774 : INFO : PROGRESS: at sentence #1920000, processed 59274583 words, keeping 1161324 word types
# 2019-08-08 17:50:46,095 : INFO : PROGRESS: at sentence #1930000, processed 59591151 words, keeping 1166540 word types
# 2019-08-08 17:50:46,340 : INFO : PROGRESS: at sentence #1940000, processed 59889570 words, keeping 1170561 word types
# 2019-08-08 17:50:46,616 : INFO : PROGRESS: at sentence #1950000, processed 60190714 words, keeping 1174414 word types
# 2019-08-08 17:50:46,828 : INFO : PROGRESS: at sentence #1960000, processed 60483019 words, keeping 1179026 word types
# 2019-08-08 17:50:47,107 : INFO : PROGRESS: at sentence #1970000, processed 60829138 words, keeping 1184978 word types
# 2019-08-08 17:50:47,356 : INFO : PROGRESS: at sentence #1980000, processed 61164466 words, keeping 1190378 word types
# 2019-08-08 17:50:47,644 : INFO : PROGRESS: at sentence #1990000, processed 61475220 words, keeping 1195171 word types
# 2019-08-08 17:50:47,880 : INFO : PROGRESS: at sentence #2000000, processed 61808796 words, keeping 1200365 word types
# 2019-08-08 17:50:48,099 : INFO : PROGRESS: at sentence #2010000, processed 62108345 words, keeping 1205489 word types
# 2019-08-08 17:50:48,445 : INFO : PROGRESS: at sentence #2020000, processed 62461713 words, keeping 1210785 word types
# 2019-08-08 17:50:48,693 : INFO : PROGRESS: at sentence #2030000, processed 62790994 words, keeping 1216249 word types
# 2019-08-08 17:50:48,992 : INFO : PROGRESS: at sentence #2040000, processed 63129725 words, keeping 1223126 word types
# 2019-08-08 17:50:49,247 : INFO : PROGRESS: at sentence #2050000, processed 63465267 words, keeping 1229378 word types
# 2019-08-08 17:50:49,534 : INFO : PROGRESS: at sentence #2060000, processed 63824375 words, keeping 1235339 word types
# 2019-08-08 17:50:49,813 : INFO : PROGRESS: at sentence #2070000, processed 64149067 words, keeping 1240311 word types
# 2019-08-08 17:50:50,061 : INFO : PROGRESS: at sentence #2080000, processed 64474366 words, keeping 1244844 word types
# 2019-08-08 17:50:50,333 : INFO : PROGRESS: at sentence #2090000, processed 64783608 words, keeping 1249051 word types
# 2019-08-08 17:50:50,547 : INFO : PROGRESS: at sentence #2100000, processed 65097636 words, keeping 1253976 word types
# 2019-08-08 17:50:50,817 : INFO : PROGRESS: at sentence #2110000, processed 65429600 words, keeping 1259800 word types
# 2019-08-08 17:50:51,070 : INFO : PROGRESS: at sentence #2120000, processed 65745729 words, keeping 1264039 word types
# 2019-08-08 17:50:51,352 : INFO : PROGRESS: at sentence #2130000, processed 66075650 words, keeping 1269602 word types
# 2019-08-08 17:50:51,613 : INFO : PROGRESS: at sentence #2140000, processed 66408751 words, keeping 1275937 word types
# 2019-08-08 17:50:51,853 : INFO : PROGRESS: at sentence #2150000, processed 66733256 words, keeping 1281272 word types
# 2019-08-08 17:50:52,150 : INFO : PROGRESS: at sentence #2160000, processed 67062537 words, keeping 1286874 word types
# 2019-08-08 17:50:52,391 : INFO : PROGRESS: at sentence #2170000, processed 67383702 words, keeping 1291917 word types
# 2019-08-08 17:50:52,662 : INFO : PROGRESS: at sentence #2180000, processed 67748218 words, keeping 1297395 word types
# 2019-08-08 17:50:53,053 : INFO : PROGRESS: at sentence #2190000, processed 68128425 words, keeping 1302662 word types
# 2019-08-08 17:50:53,299 : INFO : PROGRESS: at sentence #2200000, processed 68472791 words, keeping 1307609 word types
# 2019-08-08 17:50:53,545 : INFO : PROGRESS: at sentence #2210000, processed 68794982 words, keeping 1313059 word types
# 2019-08-08 17:50:53,849 : INFO : PROGRESS: at sentence #2220000, processed 69111948 words, keeping 1318887 word types
# 2019-08-08 17:50:54,243 : INFO : PROGRESS: at sentence #2230000, processed 69566041 words, keeping 1326025 word types
# 2019-08-08 17:50:54,497 : INFO : PROGRESS: at sentence #2240000, processed 69884856 words, keeping 1330929 word types
# 2019-08-08 17:50:54,760 : INFO : PROGRESS: at sentence #2250000, processed 70209608 words, keeping 1336222 word types
# 2019-08-08 17:50:55,016 : INFO : PROGRESS: at sentence #2260000, processed 70532889 words, keeping 1341877 word types
# 2019-08-08 17:50:55,323 : INFO : PROGRESS: at sentence #2270000, processed 70865423 words, keeping 1347832 word types
# 2019-08-08 17:50:55,572 : INFO : PROGRESS: at sentence #2280000, processed 71186480 words, keeping 1352815 word types
# 2019-08-08 17:50:55,809 : INFO : PROGRESS: at sentence #2290000, processed 71508104 words, keeping 1357998 word types
# 2019-08-08 17:50:56,149 : INFO : PROGRESS: at sentence #2300000, processed 71819613 words, keeping 1363605 word types
# 2019-08-08 17:50:56,464 : INFO : PROGRESS: at sentence #2310000, processed 72166669 words, keeping 1369858 word types
# 2019-08-08 17:50:56,729 : INFO : PROGRESS: at sentence #2320000, processed 72500775 words, keeping 1375690 word types
# 2019-08-08 17:50:56,946 : INFO : PROGRESS: at sentence #2330000, processed 72803883 words, keeping 1380336 word types
# 2019-08-08 17:50:57,275 : INFO : PROGRESS: at sentence #2340000, processed 73147620 words, keeping 1386204 word types
# 2019-08-08 17:50:57,546 : INFO : PROGRESS: at sentence #2350000, processed 73499811 words, keeping 1391494 word types
# 2019-08-08 17:50:57,815 : INFO : PROGRESS: at sentence #2360000, processed 73808108 words, keeping 1396698 word types
# 2019-08-08 17:50:58,169 : INFO : PROGRESS: at sentence #2370000, processed 74129407 words, keeping 1402514 word types
# 2019-08-08 17:50:58,406 : INFO : PROGRESS: at sentence #2380000, processed 74458460 words, keeping 1408869 word types
# 2019-08-08 17:50:58,683 : INFO : PROGRESS: at sentence #2390000, processed 74778123 words, keeping 1415057 word types
# 2019-08-08 17:50:58,942 : INFO : PROGRESS: at sentence #2400000, processed 75117633 words, keeping 1422085 word types
# 2019-08-08 17:50:59,183 : INFO : PROGRESS: at sentence #2410000, processed 75438175 words, keeping 1427730 word types
# 2019-08-08 17:50:59,463 : INFO : PROGRESS: at sentence #2420000, processed 75781636 words, keeping 1433961 word types
# 2019-08-08 17:50:59,712 : INFO : PROGRESS: at sentence #2430000, processed 76126154 words, keeping 1439537 word types
# 2019-08-08 17:50:59,922 : INFO : PROGRESS: at sentence #2440000, processed 76426201 words, keeping 1444323 word types
# 2019-08-08 17:51:00,190 : INFO : PROGRESS: at sentence #2450000, processed 76737365 words, keeping 1448907 word types
# 2019-08-08 17:51:00,426 : INFO : PROGRESS: at sentence #2460000, processed 77062085 words, keeping 1455084 word types
# 2019-08-08 17:51:00,692 : INFO : PROGRESS: at sentence #2470000, processed 77395692 words, keeping 1460079 word types
# 2019-08-08 17:51:00,971 : INFO : PROGRESS: at sentence #2480000, processed 77723413 words, keeping 1465403 word types
# 2019-08-08 17:51:01,244 : INFO : PROGRESS: at sentence #2490000, processed 78048632 words, keeping 1470852 word types
# 2019-08-08 17:51:01,517 : INFO : PROGRESS: at sentence #2500000, processed 78354822 words, keeping 1474962 word types
# 2019-08-08 17:51:01,735 : INFO : PROGRESS: at sentence #2510000, processed 78662338 words, keeping 1479155 word types
# 2019-08-08 17:51:02,008 : INFO : PROGRESS: at sentence #2520000, processed 79001379 words, keeping 1484780 word types
# 2019-08-08 17:51:02,285 : INFO : PROGRESS: at sentence #2530000, processed 79317090 words, keeping 1488776 word types
# 2019-08-08 17:51:02,515 : INFO : PROGRESS: at sentence #2540000, processed 79645183 words, keeping 1493464 word types
# 2019-08-08 17:51:02,772 : INFO : PROGRESS: at sentence #2550000, processed 79962896 words, keeping 1498096 word types
# 2019-08-08 17:51:03,044 : INFO : PROGRESS: at sentence #2560000, processed 80278097 words, keeping 1503272 word types
# 2019-08-08 17:51:03,303 : INFO : PROGRESS: at sentence #2570000, processed 80617190 words, keeping 1508397 word types
# 2019-08-08 17:51:03,585 : INFO : PROGRESS: at sentence #2580000, processed 80954644 words, keeping 1513833 word types
# 2019-08-08 17:51:03,813 : INFO : PROGRESS: at sentence #2590000, processed 81281756 words, keeping 1519534 word types
# 2019-08-08 17:51:04,107 : INFO : PROGRESS: at sentence #2600000, processed 81619294 words, keeping 1524730 word types
# 2019-08-08 17:51:04,366 : INFO : PROGRESS: at sentence #2610000, processed 81939638 words, keeping 1530617 word types
# 2019-08-08 17:51:04,610 : INFO : PROGRESS: at sentence #2620000, processed 82279646 words, keeping 1537888 word types
# 2019-08-08 17:51:04,905 : INFO : PROGRESS: at sentence #2630000, processed 82616625 words, keeping 1543696 word types
# 2019-08-08 17:51:05,158 : INFO : PROGRESS: at sentence #2640000, processed 82938866 words, keeping 1548008 word types
# 2019-08-08 17:51:05,481 : INFO : PROGRESS: at sentence #2650000, processed 83291726 words, keeping 1554632 word types
# 2019-08-08 17:51:05,736 : INFO : PROGRESS: at sentence #2660000, processed 83609748 words, keeping 1559264 word types
# 2019-08-08 17:51:05,960 : INFO : PROGRESS: at sentence #2670000, processed 83926850 words, keeping 1563876 word types
# 2019-08-08 17:51:06,245 : INFO : PROGRESS: at sentence #2680000, processed 84240681 words, keeping 1568050 word types
# 2019-08-08 17:51:06,485 : INFO : PROGRESS: at sentence #2690000, processed 84558595 words, keeping 1572923 word types
# 2019-08-08 17:51:06,818 : INFO : PROGRESS: at sentence #2700000, processed 84933338 words, keeping 1577677 word types
# 2019-08-08 17:51:07,070 : INFO : PROGRESS: at sentence #2710000, processed 85239461 words, keeping 1582302 word types
# 2019-08-08 17:51:07,375 : INFO : PROGRESS: at sentence #2720000, processed 85585072 words, keeping 1589159 word types
# 2019-08-08 17:51:07,679 : INFO : PROGRESS: at sentence #2730000, processed 85989820 words, keeping 1595948 word types
# 2019-08-08 17:51:07,937 : INFO : PROGRESS: at sentence #2740000, processed 86325071 words, keeping 1601207 word types
# 2019-08-08 17:51:08,183 : INFO : PROGRESS: at sentence #2750000, processed 86643590 words, keeping 1606095 word types
# 2019-08-08 17:51:08,436 : INFO : PROGRESS: at sentence #2760000, processed 86967234 words, keeping 1610771 word types
# 2019-08-08 17:51:08,726 : INFO : PROGRESS: at sentence #2770000, processed 87280554 words, keeping 1615351 word types
# 2019-08-08 17:51:08,941 : INFO : PROGRESS: at sentence #2780000, processed 87587549 words, keeping 1619691 word types
# 2019-08-08 17:51:09,155 : INFO : PROGRESS: at sentence #2790000, processed 87914539 words, keeping 1624448 word types
# 2019-08-08 17:51:09,381 : INFO : PROGRESS: at sentence #2800000, processed 88241787 words, keeping 1629229 word types
# 2019-08-08 17:51:09,648 : INFO : PROGRESS: at sentence #2810000, processed 88570759 words, keeping 1633956 word types
# 2019-08-08 17:51:09,891 : INFO : PROGRESS: at sentence #2820000, processed 88884875 words, keeping 1638243 word types
# 2019-08-08 17:51:10,149 : INFO : PROGRESS: at sentence #2830000, processed 89212601 words, keeping 1643501 word types
# 2019-08-08 17:51:10,430 : INFO : PROGRESS: at sentence #2840000, processed 89545961 words, keeping 1647785 word types
# 2019-08-08 17:51:10,665 : INFO : PROGRESS: at sentence #2850000, processed 89880838 words, keeping 1654073 word types
# 2019-08-08 17:51:10,935 : INFO : PROGRESS: at sentence #2860000, processed 90208897 words, keeping 1658234 word types
# 2019-08-08 17:51:11,214 : INFO : PROGRESS: at sentence #2870000, processed 90527984 words, keeping 1662516 word types
# 2019-08-08 17:51:11,516 : INFO : PROGRESS: at sentence #2880000, processed 90856768 words, keeping 1667413 word types
# 2019-08-08 17:51:11,760 : INFO : PROGRESS: at sentence #2890000, processed 91178699 words, keeping 1671506 word types
# 2019-08-08 17:51:12,033 : INFO : PROGRESS: at sentence #2900000, processed 91514280 words, keeping 1675631 word types
# 2019-08-08 17:51:12,294 : INFO : PROGRESS: at sentence #2910000, processed 91829501 words, keeping 1680015 word types
# 2019-08-08 17:51:12,517 : INFO : PROGRESS: at sentence #2920000, processed 92139839 words, keeping 1683745 word types
# 2019-08-08 17:51:12,728 : INFO : PROGRESS: at sentence #2930000, processed 92439762 words, keeping 1687640 word types
# 2019-08-08 17:51:13,047 : INFO : PROGRESS: at sentence #2940000, processed 92769378 words, keeping 1691230 word types
# 2019-08-08 17:51:13,290 : INFO : PROGRESS: at sentence #2950000, processed 93103632 words, keeping 1695034 word types
# 2019-08-08 17:51:13,538 : INFO : PROGRESS: at sentence #2960000, processed 93417455 words, keeping 1698774 word types
# 2019-08-08 17:51:13,824 : INFO : PROGRESS: at sentence #2970000, processed 93755366 words, keeping 1704330 word types
# 2019-08-08 17:51:14,066 : INFO : PROGRESS: at sentence #2980000, processed 94079965 words, keeping 1710127 word types
# 2019-08-08 17:51:14,343 : INFO : PROGRESS: at sentence #2990000, processed 94409377 words, keeping 1716315 word types
# 2019-08-08 17:51:14,624 : INFO : PROGRESS: at sentence #3000000, processed 94764412 words, keeping 1721940 word types
# 2019-08-08 17:51:14,979 : INFO : PROGRESS: at sentence #3010000, processed 95140181 words, keeping 1727715 word types
# 2019-08-08 17:51:15,328 : INFO : PROGRESS: at sentence #3020000, processed 95471222 words, keeping 1733631 word types
# 2019-08-08 17:51:15,684 : INFO : PROGRESS: at sentence #3030000, processed 95851345 words, keeping 1738776 word types
# 2019-08-08 17:51:15,937 : INFO : PROGRESS: at sentence #3040000, processed 96189246 words, keeping 1743577 word types
# 2019-08-08 17:51:16,262 : INFO : PROGRESS: at sentence #3050000, processed 96553912 words, keeping 1748894 word types
# 2019-08-08 17:51:16,550 : INFO : PROGRESS: at sentence #3060000, processed 96885526 words, keeping 1753987 word types
# 2019-08-08 17:51:16,807 : INFO : PROGRESS: at sentence #3070000, processed 97211328 words, keeping 1758131 word types
# 2019-08-08 17:51:17,116 : INFO : PROGRESS: at sentence #3080000, processed 97542088 words, keeping 1762037 word types
# 2019-08-08 17:51:17,342 : INFO : PROGRESS: at sentence #3090000, processed 97849664 words, keeping 1766087 word types
# 2019-08-08 17:51:17,574 : INFO : PROGRESS: at sentence #3100000, processed 98164977 words, keeping 1771017 word types
# 2019-08-08 17:51:17,846 : INFO : PROGRESS: at sentence #3110000, processed 98482787 words, keeping 1775869 word types
# 2019-08-08 17:51:18,081 : INFO : PROGRESS: at sentence #3120000, processed 98806269 words, keeping 1779864 word types
# 2019-08-08 17:51:18,336 : INFO : PROGRESS: at sentence #3130000, processed 99129454 words, keeping 1784351 word types
# 2019-08-08 17:51:18,593 : INFO : PROGRESS: at sentence #3140000, processed 99441733 words, keeping 1788581 word types
# 2019-08-08 17:51:18,822 : INFO : PROGRESS: at sentence #3150000, processed 99764985 words, keeping 1792734 word types
# 2019-08-08 17:51:19,126 : INFO : PROGRESS: at sentence #3160000, processed 100090928 words, keeping 1797396 word types
# 2019-08-08 17:51:19,392 : INFO : PROGRESS: at sentence #3170000, processed 100438184 words, keeping 1802996 word types
# 2019-08-08 17:51:19,680 : INFO : PROGRESS: at sentence #3180000, processed 100770208 words, keeping 1808229 word types
# 2019-08-08 17:51:19,917 : INFO : PROGRESS: at sentence #3190000, processed 101088780 words, keeping 1813195 word types
# 2019-08-08 17:51:20,175 : INFO : PROGRESS: at sentence #3200000, processed 101441932 words, keeping 1818226 word types
# 2019-08-08 17:51:20,464 : INFO : PROGRESS: at sentence #3210000, processed 101780134 words, keeping 1824045 word types
# 2019-08-08 17:51:20,746 : INFO : PROGRESS: at sentence #3220000, processed 102170629 words, keeping 1828666 word types
# 2019-08-08 17:51:21,012 : INFO : PROGRESS: at sentence #3230000, processed 102489393 words, keeping 1832534 word types
# 2019-08-08 17:51:21,252 : INFO : PROGRESS: at sentence #3240000, processed 102800184 words, keeping 1836627 word types
# 2019-08-08 17:51:21,500 : INFO : PROGRESS: at sentence #3250000, processed 103110400 words, keeping 1841067 word types
# 2019-08-08 17:51:21,806 : INFO : PROGRESS: at sentence #3260000, processed 103437085 words, keeping 1845585 word types
# 2019-08-08 17:51:22,033 : INFO : PROGRESS: at sentence #3270000, processed 103760372 words, keeping 1850475 word types
# 2019-08-08 17:51:22,293 : INFO : PROGRESS: at sentence #3280000, processed 104094277 words, keeping 1856221 word types
# 2019-08-08 17:51:22,543 : INFO : PROGRESS: at sentence #3290000, processed 104408657 words, keeping 1860931 word types
# 2019-08-08 17:51:22,822 : INFO : PROGRESS: at sentence #3300000, processed 104773219 words, keeping 1867307 word types
# 2019-08-08 17:51:23,115 : INFO : PROGRESS: at sentence #3310000, processed 105091762 words, keeping 1871652 word types
# 2019-08-08 17:51:23,392 : INFO : PROGRESS: at sentence #3320000, processed 105443742 words, keeping 1877568 word types
# 2019-08-08 17:51:23,673 : INFO : PROGRESS: at sentence #3330000, processed 105783761 words, keeping 1882243 word types
# 2019-08-08 17:51:23,946 : INFO : PROGRESS: at sentence #3340000, processed 106097786 words, keeping 1886371 word types
# 2019-08-08 17:51:24,175 : INFO : PROGRESS: at sentence #3350000, processed 106401312 words, keeping 1890027 word types
# 2019-08-08 17:51:24,475 : INFO : PROGRESS: at sentence #3360000, processed 106734678 words, keeping 1895990 word types
# 2019-08-08 17:51:24,689 : INFO : PROGRESS: at sentence #3370000, processed 107047236 words, keeping 1899786 word types
# 2019-08-08 17:51:24,926 : INFO : PROGRESS: at sentence #3380000, processed 107373563 words, keeping 1905006 word types
# 2019-08-08 17:51:25,232 : INFO : PROGRESS: at sentence #3390000, processed 107704480 words, keeping 1909703 word types
# 2019-08-08 17:51:25,496 : INFO : PROGRESS: at sentence #3400000, processed 108034355 words, keeping 1915004 word types
# 2019-08-08 17:51:25,718 : INFO : PROGRESS: at sentence #3410000, processed 108359057 words, keeping 1919656 word types
# 2019-08-08 17:51:26,038 : INFO : PROGRESS: at sentence #3420000, processed 108704968 words, keeping 1927315 word types
# 2019-08-08 17:51:26,336 : INFO : PROGRESS: at sentence #3430000, processed 109035503 words, keeping 1932648 word types
# 2019-08-08 17:51:26,602 : INFO : PROGRESS: at sentence #3440000, processed 109355241 words, keeping 1937700 word types
# 2019-08-08 17:51:26,805 : INFO : PROGRESS: at sentence #3450000, processed 109662552 words, keeping 1941124 word types
# 2019-08-08 17:51:27,069 : INFO : PROGRESS: at sentence #3460000, processed 109978444 words, keeping 1944752 word types
# 2019-08-08 17:51:27,315 : INFO : PROGRESS: at sentence #3470000, processed 110311170 words, keeping 1949054 word types
# 2019-08-08 17:51:27,539 : INFO : PROGRESS: at sentence #3480000, processed 110638807 words, keeping 1953121 word types
# 2019-08-08 17:51:27,843 : INFO : PROGRESS: at sentence #3490000, processed 110989723 words, keeping 1957908 word types
# 2019-08-08 17:51:28,107 : INFO : PROGRESS: at sentence #3500000, processed 111317771 words, keeping 1962424 word types
# 2019-08-08 17:51:28,371 : INFO : PROGRESS: at sentence #3510000, processed 111634059 words, keeping 1966725 word types
# 2019-08-08 17:51:28,627 : INFO : PROGRESS: at sentence #3520000, processed 111981069 words, keeping 1970933 word types
# 2019-08-08 17:51:28,890 : INFO : PROGRESS: at sentence #3530000, processed 112303184 words, keeping 1975006 word types
# 2019-08-08 17:51:29,157 : INFO : PROGRESS: at sentence #3540000, processed 112615364 words, keeping 1978702 word types
# 2019-08-08 17:51:29,384 : INFO : PROGRESS: at sentence #3550000, processed 112924895 words, keeping 1982435 word types
# 2019-08-08 17:51:29,618 : INFO : PROGRESS: at sentence #3560000, processed 113237901 words, keeping 1987206 word types
# 2019-08-08 17:51:29,900 : INFO : PROGRESS: at sentence #3570000, processed 113549257 words, keeping 1991795 word types
# 2019-08-08 17:51:30,190 : INFO : PROGRESS: at sentence #3580000, processed 113886123 words, keeping 1996647 word types
# 2019-08-08 17:51:30,472 : INFO : PROGRESS: at sentence #3590000, processed 114204342 words, keeping 2000831 word types
# 2019-08-08 17:51:30,732 : INFO : PROGRESS: at sentence #3600000, processed 114530025 words, keeping 2004917 word types
# 2019-08-08 17:51:30,980 : INFO : PROGRESS: at sentence #3610000, processed 114857175 words, keeping 2009886 word types
# 2019-08-08 17:51:31,352 : INFO : PROGRESS: at sentence #3620000, processed 115299255 words, keeping 2015753 word types
# 2019-08-08 17:51:31,605 : INFO : PROGRESS: at sentence #3630000, processed 115648199 words, keeping 2021048 word types
# 2019-08-08 17:51:31,922 : INFO : PROGRESS: at sentence #3640000, processed 115995207 words, keeping 2025715 word types
# 2019-08-08 17:51:32,210 : INFO : PROGRESS: at sentence #3650000, processed 116321639 words, keeping 2031174 word types
# 2019-08-08 17:51:32,459 : INFO : PROGRESS: at sentence #3660000, processed 116652937 words, keeping 2035563 word types
# 2019-08-08 17:51:32,742 : INFO : PROGRESS: at sentence #3670000, processed 116973944 words, keeping 2040003 word types
# 2019-08-08 17:51:32,972 : INFO : PROGRESS: at sentence #3680000, processed 117286261 words, keeping 2044798 word types
# 2019-08-08 17:51:33,303 : INFO : PROGRESS: at sentence #3690000, processed 117621611 words, keeping 2050310 word types
# 2019-08-08 17:51:33,553 : INFO : PROGRESS: at sentence #3700000, processed 117950003 words, keeping 2055161 word types
# 2019-08-08 17:51:33,826 : INFO : PROGRESS: at sentence #3710000, processed 118270966 words, keeping 2059210 word types
# 2019-08-08 17:51:34,095 : INFO : PROGRESS: at sentence #3720000, processed 118588862 words, keeping 2063584 word types
# 2019-08-08 17:51:34,333 : INFO : PROGRESS: at sentence #3730000, processed 118922839 words, keeping 2068736 word types
# 2019-08-08 17:51:34,613 : INFO : PROGRESS: at sentence #3740000, processed 119246694 words, keeping 2073873 word types
# 2019-08-08 17:51:34,890 : INFO : PROGRESS: at sentence #3750000, processed 119596645 words, keeping 2078626 word types
# 2019-08-08 17:51:35,162 : INFO : PROGRESS: at sentence #3760000, processed 119917164 words, keeping 2082674 word types
# 2019-08-08 17:51:35,432 : INFO : PROGRESS: at sentence #3770000, processed 120292424 words, keeping 2087092 word types
# 2019-08-08 17:51:35,692 : INFO : PROGRESS: at sentence #3780000, processed 120621203 words, keeping 2092210 word types
# 2019-08-08 17:51:35,985 : INFO : PROGRESS: at sentence #3790000, processed 120958757 words, keeping 2096899 word types
# 2019-08-08 17:51:36,258 : INFO : PROGRESS: at sentence #3800000, processed 121303960 words, keeping 2101429 word types
# 2019-08-08 17:51:36,581 : INFO : PROGRESS: at sentence #3810000, processed 121654515 words, keeping 2106656 word types
# 2019-08-08 17:51:36,876 : INFO : PROGRESS: at sentence #3820000, processed 122023495 words, keeping 2112013 word types
# 2019-08-08 17:51:37,192 : INFO : PROGRESS: at sentence #3830000, processed 122369268 words, keeping 2116163 word types
# 2019-08-08 17:51:37,451 : INFO : PROGRESS: at sentence #3840000, processed 122722667 words, keeping 2121378 word types
# 2019-08-08 17:51:37,739 : INFO : PROGRESS: at sentence #3850000, processed 123110082 words, keeping 2128088 word types
# 2019-08-08 17:51:38,041 : INFO : PROGRESS: at sentence #3860000, processed 123463311 words, keeping 2133647 word types
# 2019-08-08 17:51:38,272 : INFO : PROGRESS: at sentence #3870000, processed 123798975 words, keeping 2138667 word types
# 2019-08-08 17:51:38,570 : INFO : PROGRESS: at sentence #3880000, processed 124157561 words, keeping 2144003 word types
# 2019-08-08 17:51:38,847 : INFO : PROGRESS: at sentence #3890000, processed 124537742 words, keeping 2149286 word types
# 2019-08-08 17:51:39,147 : INFO : PROGRESS: at sentence #3900000, processed 124879557 words, keeping 2153924 word types
# 2019-08-08 17:51:39,398 : INFO : PROGRESS: at sentence #3910000, processed 125217950 words, keeping 2158942 word types
# 2019-08-08 17:51:39,660 : INFO : PROGRESS: at sentence #3920000, processed 125553790 words, keeping 2164352 word types
# 2019-08-08 17:51:39,967 : INFO : PROGRESS: at sentence #3930000, processed 125872055 words, keeping 2168801 word types
# 2019-08-08 17:51:40,269 : INFO : PROGRESS: at sentence #3940000, processed 126225573 words, keeping 2174900 word types
# 2019-08-08 17:51:40,531 : INFO : PROGRESS: at sentence #3950000, processed 126554198 words, keeping 2178621 word types
# 2019-08-08 17:51:40,780 : INFO : PROGRESS: at sentence #3960000, processed 126866019 words, keeping 2181839 word types
# 2019-08-08 17:51:41,206 : INFO : PROGRESS: at sentence #3970000, processed 127194389 words, keeping 2187076 word types
# 2019-08-08 17:51:41,486 : INFO : PROGRESS: at sentence #3980000, processed 127525704 words, keeping 2191492 word types
# 2019-08-08 17:51:41,778 : INFO : PROGRESS: at sentence #3990000, processed 127889900 words, keeping 2197073 word types
# 2019-08-08 17:51:42,048 : INFO : PROGRESS: at sentence #4000000, processed 128202776 words, keeping 2201362 word types
# 2019-08-08 17:51:42,296 : INFO : PROGRESS: at sentence #4010000, processed 128530586 words, keeping 2205915 word types
# 2019-08-08 17:51:42,623 : INFO : PROGRESS: at sentence #4020000, processed 128876154 words, keeping 2210365 word types
# 2019-08-08 17:51:42,911 : INFO : PROGRESS: at sentence #4030000, processed 129245749 words, keeping 2216372 word types
# 2019-08-08 17:51:43,228 : INFO : PROGRESS: at sentence #4040000, processed 129578128 words, keeping 2220781 word types
# 2019-08-08 17:51:43,505 : INFO : PROGRESS: at sentence #4050000, processed 129942136 words, keeping 2226281 word types
# 2019-08-08 17:51:43,788 : INFO : PROGRESS: at sentence #4060000, processed 130307491 words, keeping 2230816 word types
# 2019-08-08 17:51:44,099 : INFO : PROGRESS: at sentence #4070000, processed 130659917 words, keeping 2236374 word types
# ...
# 2019-08-08 17:59:07,134 : INFO : PROGRESS: at sentence #14060000, processed 482242994 words, keeping 6263237 word types
# 2019-08-08 17:59:07,804 : INFO : PROGRESS: at sentence #14070000, processed 482558039 words, keeping 6266115 word types
# 2019-08-08 17:59:08,196 : INFO : PROGRESS: at sentence #14080000, processed 482894173 words, keeping 6268902 word types
# 2019-08-08 17:59:08,779 : INFO : PROGRESS: at sentence #14090000, processed 483224316 words, keeping 6272864 word types
# 2019-08-08 17:59:09,199 : INFO : PROGRESS: at sentence #14100000, processed 483583624 words, keeping 6276168 word types
# 2019-08-08 17:59:09,767 : INFO : PROGRESS: at sentence #14110000, processed 483914259 words, keeping 6278793 word types
# 2019-08-08 17:59:10,162 : INFO : PROGRESS: at sentence #14120000, processed 484253574 words, keeping 6282721 word types
# 2019-08-08 17:59:10,769 : INFO : PROGRESS: at sentence #14130000, processed 484606731 words, keeping 6287504 word types
# 2019-08-08 17:59:11,359 : INFO : PROGRESS: at sentence #14140000, processed 484928856 words, keeping 6289875 word types
# 2019-08-08 17:59:11,766 : INFO : PROGRESS: at sentence #14150000, processed 485259400 words, keeping 6293146 word types
# 2019-08-08 17:59:12,408 : INFO : PROGRESS: at sentence #14160000, processed 485653025 words, keeping 6296570 word types
# 2019-08-08 17:59:12,787 : INFO : PROGRESS: at sentence #14170000, processed 485982676 words, keeping 6299780 word types
# 2019-08-08 17:59:13,527 : INFO : PROGRESS: at sentence #14180000, processed 486428543 words, keeping 6303000 word types
# 2019-08-08 17:59:13,961 : INFO : PROGRESS: at sentence #14190000, processed 486775437 words, keeping 6307351 word types
# 2019-08-08 17:59:14,542 : INFO : PROGRESS: at sentence #14200000, processed 487116135 words, keeping 6310591 word types
# 2019-08-08 17:59:15,085 : INFO : PROGRESS: at sentence #14210000, processed 487455949 words, keeping 6314078 word types
# 2019-08-08 17:59:15,882 : INFO : PROGRESS: at sentence #14220000, processed 487774963 words, keeping 6316895 word types
# 2019-08-08 17:59:16,665 : INFO : PROGRESS: at sentence #14230000, processed 488125110 words, keeping 6320560 word types
# 2019-08-08 17:59:17,454 : INFO : PROGRESS: at sentence #14240000, processed 488452972 words, keeping 6323451 word types
# 2019-08-08 17:59:18,048 : INFO : PROGRESS: at sentence #14250000, processed 488810808 words, keeping 6327287 word types
# 2019-08-08 17:59:18,756 : INFO : PROGRESS: at sentence #14260000, processed 489140888 words, keeping 6330945 word types
# 2019-08-08 17:59:19,372 : INFO : PROGRESS: at sentence #14270000, processed 489501283 words, keeping 6335755 word types
# 2019-08-08 17:59:20,104 : INFO : PROGRESS: at sentence #14280000, processed 489844431 words, keeping 6339490 word types
# 2019-08-08 17:59:20,652 : INFO : PROGRESS: at sentence #14290000, processed 490157262 words, keeping 6342502 word types
# 2019-08-08 17:59:21,255 : INFO : PROGRESS: at sentence #14300000, processed 490506685 words, keeping 6346198 word types
# 2019-08-08 17:59:22,060 : INFO : PROGRESS: at sentence #14310000, processed 490885740 words, keeping 6350062 word types
# 2019-08-08 17:59:22,812 : INFO : PROGRESS: at sentence #14320000, processed 491305800 words, keeping 6354963 word types
# 2019-08-08 17:59:23,447 : INFO : PROGRESS: at sentence #14330000, processed 491711849 words, keeping 6360577 word types
# 2019-08-08 17:59:24,263 : INFO : PROGRESS: at sentence #14340000, processed 492022023 words, keeping 6363629 word types
# 2019-08-08 17:59:24,945 : INFO : PROGRESS: at sentence #14350000, processed 492465520 words, keeping 6367450 word types
# 2019-08-08 17:59:25,549 : INFO : PROGRESS: at sentence #14360000, processed 492801687 words, keeping 6370774 word types
# 2019-08-08 17:59:26,325 : INFO : PROGRESS: at sentence #14370000, processed 493176169 words, keeping 6374218 word types
# 2019-08-08 17:59:28,028 : INFO : PROGRESS: at sentence #14380000, processed 493596965 words, keeping 6377186 word types
# 2019-08-08 17:59:28,574 : INFO : PROGRESS: at sentence #14390000, processed 493913154 words, keeping 6379519 word types
# 2019-08-08 17:59:29,110 : INFO : PROGRESS: at sentence #14400000, processed 494244070 words, keeping 6383326 word types
# 2019-08-08 17:59:29,867 : INFO : PROGRESS: at sentence #14410000, processed 494559916 words, keeping 6387582 word types
# 2019-08-08 17:59:30,430 : INFO : PROGRESS: at sentence #14420000, processed 494853972 words, keeping 6390183 word types
# 2019-08-08 17:59:31,106 : INFO : PROGRESS: at sentence #14430000, processed 495161322 words, keeping 6392669 word types
# 2019-08-08 17:59:31,716 : INFO : PROGRESS: at sentence #14440000, processed 495508185 words, keeping 6396904 word types
# 2019-08-08 17:59:32,461 : INFO : PROGRESS: at sentence #14450000, processed 495831524 words, keeping 6399955 word types
# 2019-08-08 17:59:32,980 : INFO : PROGRESS: at sentence #14460000, processed 496133296 words, keeping 6402620 word types
# 2019-08-08 17:59:33,544 : INFO : PROGRESS: at sentence #14470000, processed 496449323 words, keeping 6405777 word types
# 2019-08-08 17:59:34,332 : INFO : PROGRESS: at sentence #14480000, processed 496788591 words, keeping 6409354 word types
# 2019-08-08 17:59:34,965 : INFO : PROGRESS: at sentence #14490000, processed 497120340 words, keeping 6412058 word types
# 2019-08-08 17:59:35,721 : INFO : PROGRESS: at sentence #14500000, processed 497431211 words, keeping 6414860 word types
# 2019-08-08 17:59:36,301 : INFO : PROGRESS: at sentence #14510000, processed 497760975 words, keeping 6418282 word types
# 2019-08-08 17:59:37,405 : INFO : PROGRESS: at sentence #14520000, processed 498213789 words, keeping 6423299 word types
# 2019-08-08 17:59:38,219 : INFO : PROGRESS: at sentence #14530000, processed 498562471 words, keeping 6428194 word types
# 2019-08-08 17:59:38,947 : INFO : PROGRESS: at sentence #14540000, processed 498905010 words, keeping 6433307 word types
# 2019-08-08 17:59:39,746 : INFO : PROGRESS: at sentence #14550000, processed 499292660 words, keeping 6437255 word types
# 2019-08-08 17:59:40,509 : INFO : PROGRESS: at sentence #14560000, processed 499649068 words, keeping 6441274 word types
# 2019-08-08 17:59:41,583 : INFO : PROGRESS: at sentence #14570000, processed 499991587 words, keeping 6444862 word types
# 2019-08-08 17:59:42,250 : INFO : PROGRESS: at sentence #14580000, processed 500309742 words, keeping 6447552 word types
# 2019-08-08 17:59:43,036 : INFO : PROGRESS: at sentence #14590000, processed 500634742 words, keeping 6450856 word types
# 2019-08-08 17:59:43,823 : INFO : PROGRESS: at sentence #14600000, processed 500982947 words, keeping 6455458 word types
# 2019-08-08 17:59:44,683 : INFO : PROGRESS: at sentence #14610000, processed 501310624 words, keeping 6458150 word types
# 2019-08-08 17:59:45,387 : INFO : PROGRESS: at sentence #14620000, processed 501634478 words, keeping 6462013 word types
# 2019-08-08 17:59:46,302 : INFO : PROGRESS: at sentence #14630000, processed 502019462 words, keeping 6467450 word types
# 2019-08-08 17:59:47,086 : INFO : PROGRESS: at sentence #14640000, processed 502374146 words, keeping 6472662 word types
# 2019-08-08 17:59:47,730 : INFO : PROGRESS: at sentence #14650000, processed 502699271 words, keeping 6475951 word types
# 2019-08-08 17:59:48,387 : INFO : PROGRESS: at sentence #14660000, processed 503029662 words, keeping 6479001 word types
# 2019-08-08 17:59:49,192 : INFO : PROGRESS: at sentence #14670000, processed 503375740 words, keeping 6482314 word types
# 2019-08-08 17:59:50,003 : INFO : PROGRESS: at sentence #14680000, processed 503675095 words, keeping 6484651 word types
# 2019-08-08 17:59:50,558 : INFO : PROGRESS: at sentence #14690000, processed 503998000 words, keeping 6487184 word types
# 2019-08-08 17:59:51,493 : INFO : PROGRESS: at sentence #14700000, processed 504330874 words, keeping 6489595 word types
# 2019-08-08 17:59:52,151 : INFO : PROGRESS: at sentence #14710000, processed 504632772 words, keeping 6492184 word types
# 2019-08-08 17:59:52,798 : INFO : PROGRESS: at sentence #14720000, processed 504959070 words, keeping 6495975 word types
# 2019-08-08 17:59:53,688 : INFO : PROGRESS: at sentence #14730000, processed 505319650 words, keeping 6499523 word types
# 2019-08-08 17:59:54,497 : INFO : PROGRESS: at sentence #14740000, processed 505669383 words, keeping 6503254 word types
# 2019-08-08 17:59:55,147 : INFO : PROGRESS: at sentence #14750000, processed 505995496 words, keeping 6506817 word types
# 2019-08-08 17:59:55,995 : INFO : PROGRESS: at sentence #14760000, processed 506309301 words, keeping 6510564 word types
# 2019-08-08 17:59:56,680 : INFO : PROGRESS: at sentence #14770000, processed 506618743 words, keeping 6513689 word types
# 2019-08-08 17:59:57,515 : INFO : PROGRESS: at sentence #14780000, processed 506931464 words, keeping 6516945 word types
# 2019-08-08 17:59:58,119 : INFO : PROGRESS: at sentence #14790000, processed 507244807 words, keeping 6520774 word types
# 2019-08-08 17:59:59,057 : INFO : PROGRESS: at sentence #14800000, processed 507593011 words, keeping 6524252 word types
# 2019-08-08 17:59:59,824 : INFO : PROGRESS: at sentence #14810000, processed 507957275 words, keeping 6528407 word types
# 2019-08-08 18:00:00,774 : INFO : PROGRESS: at sentence #14820000, processed 508311752 words, keeping 6533113 word types
# 2019-08-08 18:00:01,378 : INFO : PROGRESS: at sentence #14830000, processed 508620155 words, keeping 6535484 word types
# 2019-08-08 18:00:02,113 : INFO : PROGRESS: at sentence #14840000, processed 508925824 words, keeping 6538393 word types
# 2019-08-08 18:00:03,361 : INFO : PROGRESS: at sentence #14850000, processed 509254920 words, keeping 6541958 word types
# 2019-08-08 18:00:03,946 : INFO : PROGRESS: at sentence #14860000, processed 509562933 words, keeping 6544595 word types
# 2019-08-08 18:00:04,811 : INFO : PROGRESS: at sentence #14870000, processed 509885923 words, keeping 6548133 word types
# 2019-08-08 18:00:05,656 : INFO : PROGRESS: at sentence #14880000, processed 510200461 words, keeping 6550592 word types
# 2019-08-08 18:00:06,363 : INFO : PROGRESS: at sentence #14890000, processed 510519053 words, keeping 6553265 word types
# 2019-08-08 18:00:07,177 : INFO : PROGRESS: at sentence #14900000, processed 510839706 words, keeping 6555892 word types
# 2019-08-08 18:00:08,035 : INFO : PROGRESS: at sentence #14910000, processed 511144647 words, keeping 6558161 word types
# 2019-08-08 18:00:08,649 : INFO : PROGRESS: at sentence #14920000, processed 511451030 words, keeping 6560651 word types
# 2019-08-08 18:00:09,520 : INFO : PROGRESS: at sentence #14930000, processed 511802054 words, keeping 6565209 word types
# 2019-08-08 18:00:10,058 : INFO : PROGRESS: at sentence #14940000, processed 512127991 words, keeping 6567561 word types
# 2019-08-08 18:00:10,693 : INFO : PROGRESS: at sentence #14950000, processed 512441739 words, keeping 6570566 word types
# 2019-08-08 18:00:11,625 : INFO : PROGRESS: at sentence #14960000, processed 512767661 words, keeping 6573627 word types
# 2019-08-08 18:00:12,279 : INFO : PROGRESS: at sentence #14970000, processed 513096180 words, keeping 6577367 word types
# 2019-08-08 18:00:13,035 : INFO : PROGRESS: at sentence #14980000, processed 513442378 words, keeping 6580582 word types
# 2019-08-08 18:00:13,888 : INFO : PROGRESS: at sentence #14990000, processed 513768067 words, keeping 6584463 word types
# 2019-08-08 18:00:14,601 : INFO : PROGRESS: at sentence #15000000, processed 514082018 words, keeping 6586677 word types
# 2019-08-08 18:00:15,249 : INFO : PROGRESS: at sentence #15010000, processed 514397001 words, keeping 6589501 word types
# 2019-08-08 18:00:15,998 : INFO : PROGRESS: at sentence #15020000, processed 514717193 words, keeping 6592327 word types
# 2019-08-08 18:00:16,582 : INFO : PROGRESS: at sentence #15030000, processed 515029852 words, keeping 6594974 word types
# 2019-08-08 18:00:17,382 : INFO : PROGRESS: at sentence #15040000, processed 515384153 words, keeping 6597979 word types
# 2019-08-08 18:00:18,110 : INFO : PROGRESS: at sentence #15050000, processed 515703583 words, keeping 6600544 word types
# 2019-08-08 18:00:19,041 : INFO : PROGRESS: at sentence #15060000, processed 516064948 words, keeping 6604251 word types
# 2019-08-08 18:00:19,666 : INFO : PROGRESS: at sentence #15070000, processed 516393458 words, keeping 6607675 word types
# 2019-08-08 18:00:20,555 : INFO : PROGRESS: at sentence #15080000, processed 516723020 words, keeping 6610600 word types
# 2019-08-08 18:00:21,386 : INFO : PROGRESS: at sentence #15090000, processed 517060867 words, keeping 6614342 word types
# 2019-08-08 18:00:21,934 : INFO : PROGRESS: at sentence #15100000, processed 517395054 words, keeping 6618173 word types
# 2019-08-08 18:00:22,617 : INFO : PROGRESS: at sentence #15110000, processed 517721035 words, keeping 6620834 word types
# 2019-08-08 18:00:23,610 : INFO : PROGRESS: at sentence #15120000, processed 518053522 words, keeping 6624210 word types
# 2019-08-08 18:00:24,236 : INFO : PROGRESS: at sentence #15130000, processed 518380281 words, keeping 6627077 word types
# 2019-08-08 18:00:24,954 : INFO : PROGRESS: at sentence #15140000, processed 518696147 words, keeping 6629579 word types
# 2019-08-08 18:00:25,787 : INFO : PROGRESS: at sentence #15150000, processed 519001323 words, keeping 6632291 word types
# 2019-08-08 18:00:26,633 : INFO : PROGRESS: at sentence #15160000, processed 519310125 words, keeping 6635278 word types
# 2019-08-08 18:00:27,250 : INFO : PROGRESS: at sentence #15170000, processed 519636015 words, keeping 6638620 word types
# 2019-08-08 18:00:28,021 : INFO : PROGRESS: at sentence #15180000, processed 519943451 words, keeping 6641074 word types
# 2019-08-08 18:00:28,797 : INFO : PROGRESS: at sentence #15190000, processed 520257165 words, keeping 6643431 word types
# 2019-08-08 18:00:29,612 : INFO : PROGRESS: at sentence #15200000, processed 520619744 words, keeping 6647523 word types
# 2019-08-08 18:00:30,349 : INFO : PROGRESS: at sentence #15210000, processed 520943813 words, keeping 6650459 word types
# 2019-08-08 18:00:30,953 : INFO : PROGRESS: at sentence #15220000, processed 521264028 words, keeping 6653221 word types
# 2019-08-08 18:00:31,804 : INFO : PROGRESS: at sentence #15230000, processed 521598381 words, keeping 6656769 word types
# 2019-08-08 18:00:32,411 : INFO : PROGRESS: at sentence #15240000, processed 521934483 words, keeping 6661160 word types
# 2019-08-08 18:00:33,318 : INFO : PROGRESS: at sentence #15250000, processed 522278169 words, keeping 6664672 word types
# 2019-08-08 18:00:34,077 : INFO : PROGRESS: at sentence #15260000, processed 522600219 words, keeping 6668467 word types
# 2019-08-08 18:00:35,073 : INFO : PROGRESS: at sentence #15270000, processed 522955508 words, keeping 6671555 word types
# 2019-08-08 18:00:35,906 : INFO : PROGRESS: at sentence #15280000, processed 523296269 words, keeping 6675599 word types
# 2019-08-08 18:00:36,623 : INFO : PROGRESS: at sentence #15290000, processed 523632006 words, keeping 6678363 word types
# 2019-08-08 18:00:37,573 : INFO : PROGRESS: at sentence #15300000, processed 523966117 words, keeping 6683658 word types
# 2019-08-08 18:00:38,296 : INFO : PROGRESS: at sentence #15310000, processed 524321911 words, keeping 6687407 word types
# 2019-08-08 18:00:39,001 : INFO : PROGRESS: at sentence #15320000, processed 524699172 words, keeping 6691789 word types
# 2019-08-08 18:00:39,913 : INFO : PROGRESS: at sentence #15330000, processed 525042575 words, keeping 6696595 word types
# 2019-08-08 18:00:40,866 : INFO : PROGRESS: at sentence #15340000, processed 525428954 words, keeping 6702595 word types
# 2019-08-08 18:00:41,841 : INFO : PROGRESS: at sentence #15350000, processed 525764219 words, keeping 6706005 word types
# 2019-08-08 18:00:42,718 : INFO : PROGRESS: at sentence #15360000, processed 526157542 words, keeping 6710174 word types
# 2019-08-08 18:00:43,599 : INFO : PROGRESS: at sentence #15370000, processed 526554075 words, keeping 6714274 word types
# 2019-08-08 18:00:44,319 : INFO : PROGRESS: at sentence #15380000, processed 526895016 words, keeping 6718084 word types

# %%
model.save("/home/stirunag/OTAR_wv_model")
model.wv.save("/home/stirunag/OTAR_wv")

# %%
w1 = "tyrosine"
print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))

# %%
# w1 = "antibiotics".lower()

# print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))

# %%
# w1 = "ias".lower()

# print("Most similar to {0}".format(w1), model.wv.most_similar(positive=w1))

# %%
# word = 'gut'
# new_sentence = word.split()
# model.wv.most_similar(positive=filter(lambda x: x in model.wv.vocab, new_sentence), topn=20)

# %%
# word = 'fresh-water microbiome'
# new_sentence = word.split()
# model.wv.most_similar(positive=filter(lambda x: x in model.wv.vocab, new_sentence), topn=50)

# %%
# import spacy
# parse = spacy.load('biobio')

# text = u'INTRODUCTION The hydrolysis of phosphatidylcholine (PC) by phospholipase D (PLD) generates the signaling lipid phosphatidic acid (PA) (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ). PA has been hypothesized to act as a fusogenic lipid in vesicular transport such as exocytosis (Way et al. , 2000 ; Caumont et al. , 1998 ) or endocytosis (Schmidt et al. , 1999a ). PA also may act as an anchor for signaling molecules that act in proliferation pathways, such as the Raf-1 kinase (Rizzo et al. , 2000 ), as regulators of cell shape through the stimulation of PI4P5-kinase (Honda et al. , 1999 ) or as the substrate to generate diacylglycerol or lysophosphatidic acid (LPA) through further metabolism (reviewed in Frohman et al. , 1999 ; Jones et al. , 1999 ). Many cell types express the known PLD1 (Hammond et al. , 1995 ) and/or PLD2 (Colley et al. , 1997 ) isoenzymes, which become activated in response to a wide variety of agonists that signal through heterotrimeric G protein-coupled or tyrosine kinase receptors (reviewed in Liscovitch et al. , 2000 ). It has been proposed that the link between receptor stimulation and PLD activation is mediated by protein kinase C (PKC), ADP-ribosylation factor (ARF), and Rho family members (Singer et al. , 1995 ; Siddiqi et al. , 1995 ; Liscovitch et al. , 2000 ), which have been shown to stimulate PLD1 directly using in vitro reconstitution assays (Hammond et al. , 1997 ). Since ARF, Rho, and PKC stimulate multiple downstream effector pathways that ultimately regulate cellular morphology, proliferation, and secretion, there has been intense interest in determining the relationship of PLD stimulation through each activator to these cell biological events. Such studies generally have been approached through the manipulation of PKC, Rho, or ARF activity using the overexpression of activated or inactive alleles, toxins, or pharmacologic agents to activate or inhibit them (Liscovitch et al. , 2000 ). A key issue raised by many of these studies has been whether PLD1 is actually activated in vivo through direct stimulation by its effectors, or whether indirect pathways are more critical. Specifically, inhibitors of the enzymatic activity of PKC have been shown to block PLD activation, even though the direct stimulation of PLD1 by PKC in vitro involves an interaction with the regulatory domain of PKC and is ATP-independent (Liscovitch et al. , 2000 ). This suggests that a PKC target other than PLD is critical for the activation of PLD by PKC in vivo. Similarly, it has been proposed that the primary mechanism through which Rho activates PLD1 is an indirect one in which Rho activates Rho-kinase, which then activates PLD via an unknown pathway (Schmidt et al. , 1999b ). However, these approaches involve complicated interpretations, since manipulation of PKC, Rho, and ARF levels of activity affect many things aside from PLD regulation. These include cross-regulation of the other stimulators and alterations in availability of PI4,5P2  (a required cofactor for PLD). In addition, the pharmacologic agents are inevitably found to exhibit less than complete specificity (Zhang et al. , 1999 ). Moreover, reagents such as Rho-dominant negative alleles cause undesired widespread effects by sequestering the guanine?nucleotide exchange factors required to activate other small G-proteins. In recent years, we have described an alternative approach based on generating alleles of PLD that exhibit altered regulation. These include mutants that are inactive (Sung et al. , 1997 ), selectively nonresponsive to PKC (Zhang et al. , 1999 ), or insensitive to PI4,5P2  (Sciorra et al. , 1999 ). The rationale for this scheme was given in earlier studies that demonstrated that the stimulators of PLD1 physically interact with it at distinct sites in the molecule (Hammond et al. , 1997 ; Sung et al. , 1997 ; Sung et al. , 1999b ; Yamazaki et al. , 1999 ). Our previous study using an allele selectively nonresponsive to PKC revealed that direct stimulation of PLD1 by PKC is required for much of the response of PLD1 to G protein-coupled agonists. In this report, we demonstrate that direct stimulation of PLD1 by Rho is also critical using novel, selectively nonresponsive alleles. Taken together, our results demonstrate that signal integration through both PKC and Rho via direct contact is required for significant physiologic in vivo activation of PLD1 during agonist signaling.'

# %%
# doc = parse(text)

# for w in doc:
#     # Prints "E" for being part of a biomedical entity, and shows IOB tagging.
#     print(w, w.ent_type_, w.ent_iob_)

# %%
# for s in doc.sents:
#     print('sentence: ' + str(s) + '\n')

# %%
# import re

# def remove_parenthesized_chunks(text):
#     new_text = re.sub('[\(\[].*?[\)\]]', '', text)
# #     new_text = re.sub(r'\(.*\)', '', text)
#     return new_text

# %%
# parse_1 = spacy.load('en')
# doc_1 = parse_1(text)
# for s in doc_1.sents:
#     print('sentence: ' + str(s) + '\n')

# %%
# remove_parenthesized_chunks(text)

# %%
# doc_1 = parse_1(remove_parenthesized_chunks(text))
# for s in doc_1.sents:
#     print('sentence: ' + str(s) + '\n')

# %%
# doc = parse(text)

# for w in doc:
#     # Prints "E" for being part of a biomedical entity, and shows IOB tagging.
#     print(w, w.ent_type_, w.ent_iob_)
