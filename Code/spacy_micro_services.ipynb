# %%
import sys
import random
import os
from pathlib import Path
import shutil
import json

import argparse
import tqdm
import spacy
from spacy.gold import minibatch
from spacy.language import Language
from spacy import util

# %%
from scispacy.data_util import read_full_med_mentions, read_ner_from_tsv
from scispacy.per_class_scorer import PerClassScorer
from scispacy.train_utils import evaluate_ner

# %%
# from spacy_transformers import TransformersLanguage, TransformersWordPiecer, TransformersTok2Vec

# name = "scibert-scivocab-uncased"
# path = "/nfs/gns/literature/Santosh_Tirunagari/pretrained_word_embeddings/scibert_scivocab_uncased"

# nlp = TransformersLanguage(trf_name=name, meta={"lang": "en"})
# nlp.add_pipe(nlp.create_pipe("sentencizer"))
# nlp.add_pipe(TransformersWordPiecer.from_pretrained(nlp.vocab, path))
# nlp.add_pipe(TransformersTok2Vec.from_pretrained(nlp.vocab, path))

# %%
## Test best model performance on test set
best_model_path = '/nfs/gns/literature/Santosh_Tirunagari/GitHub/spacy_models/en-europepmc-lg/best'

print("Loading from", best_model_path)
nlp2 = util.load_model_from_path(best_model_path)
# Out:
# Loading from /nfs/gns/literature/Santosh_Tirunagari/GitHub/spacy_models/en-europepmc-lg/best

# %%
import pandas as pd
from tqdm import tqdm
from ast import literal_eval
import csv

# %%
import requests

def ground_annotation(exact,entity):
    grounded_value = 'not-grounded'
    
    root_url = 'https://www.ebi.ac.uk/ols/api/search?'
    URL = root_url
    
    if entity == 'DS':
        URL = root_url+'q='+exact+'&exact=false&ontology=efo'
    elif entity == 'OG':
        URL = root_url+'q='+exact+'&exact=false&ontology=ncbitaxon'
    elif entity == 'GP':
        URL = 'http://10.7.35.118:8157/solr/Genes/select?q='+exact
    else:
#         print(URL)
        return 'URL missing'
    
    r = requests.get(URL)

    if r.status_code ==200:
        json_data = r.json()
    else:
        return grounded_value


    if json_data['response']['numFound']!=0:
        if entity in ['DS', 'OG']:
            grounded_value = json_data['response']['docs'][0]['iri']
        elif entity in ['GP']:
            grounded_value = json_data['response']['docs'][0]['ID']
    
    return grounded_value

# %%
article_path = '/nfs/gns/literature/machine-learning/evaluation/time_complexity/articles/'
article_file_path = article_path+'PMC3649237_sentences.txt'

with open(article_file_path, 'r') as f:
    article_contents = f.read()
    
doc = nlp2(article_contents)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# chronic illness 380 395 DS
# chronic illnesses 1451 1468 DS
# chronic illness 1686 1701 DS
# chronic illness 1731 1746 DS
# chronically ill 2956 2971 DS
# chronic illness 3288 3303 DS
# and/or 4267 4273 GP
# chronicle illness 13589 13606 DS
# diseases studied 13642 13658 DS
# lung diseases 13674 13687 DS
# diabetes 13705 13713 DS
# cancer 13715 13721 DS
# stroke 13727 13733 DS
# Chronic illness 13736 13751 DS
# infectious diseases 13860 13879 DS
# chronicle illness 15382 15399 DS
# or 18406 18408 GP
# chronic illnesses 19485 19502 DS
# chronic illness 23410 23425 DS
# chronic illness 23513 23528 DS
# chronic illness 23654 23669 DS
# chronic illnesses 24953 24970 DS
# chronic illnesses 27479 27496 DS
# Chronically ill 29770 29785 DS
# ulcer 30865 30870 DS
# human 31028 31033 OG
# BP 32359 32361 DS
# postoperative problems 34298 34320 DS
# ischemic heart failure 34533 34555 DS
# heart failure 35787 35800 DS
# heart failure 36042 36055 DS
# heart failure 36100 36113 DS
# chronic illnesses 36777 36794 DS
# cancer 37222 37228 DS
# diabetes 38190 38198 DS
# diabetes 38376 38384 DS
# heart failure 38748 38761 DS
# diabetes 38766 38774 DS
# heart failure 39681 39694 DS
# diabetes 40762 40770 DS
# diabetes 41069 41077 DS
# diabetes 41190 41198 DS
# hypertension 41203 41215 DS
# stroke 42574 42580 DS
# stroke 43002 43008 DS
# diabetes 47808 47816 DS
# diabetes 48580 48588 DS
# heart failure 48651 48664 DS
# heart failure 49910 49923 DS
# dementia 51288 51296 DS
# heart failure 51905 51918 DS
# heart failure 52069 52082 DS
# heart failure 54609 54622 DS
# chronic heart failure 56948 56969 DS
# BP 57243 57245 DS
# Chronic Heart Failure 57577 57598 DS
# depression 60582 60592 DS
# chronically ill 62820 62835 DS
# cancer 63261 63267 DS
# cancer 63328 63334 DS
# cancer 63500 63506 DS
# chronic leg ulcers 67734 67752 DS
# chronic leg ulcers 67802 67820 DS
# chronic obstructive pulmonary disease 68765 68802 DS
# COPD 68804 68808 DS
# COPD 69194 69198 DS
# chronic diseases 69486 69502 DS
# congestive heart failure 70320 70344 DS
# congestive heart failure 70820 70844 DS
# congestive heart failure 71712 71736 DS
# type 2 diabetes mellitus 72957 72981 DS
# haemoglobin 73264 73275 GP
# cancer 73508 73514 DS
# cancer 73619 73625 DS
# stroke 74282 74288 DS
# stroke 74648 74654 DS
# stroke 74690 74696 DS
# heart failure disease 76321 76342 DS
# depression 76647 76657 DS
# heart failure 76812 76825 DS
# depression 76985 76995 DS
# heart failure 77247 77260 DS
# heart failure 77347 77360 DS
# heart failure 77532 77545 DS
# diabetic foot ulcers 77815 77835 DS
# HIV 78623 78626 OG
# AIDs 78627 78631 DS
# Asthma 79161 79167 DS
# asthma 79279 79285 DS
# asthma 79330 79336 DS
# asthma 79839 79845 DS
# stroke 82514 82520 DS
# depression 82551 82561 DS
# stroke 82670 82676 DS
# stroke 83358 83364 DS
# stroke 83600 83606 DS
# stroke 83895 83901 DS
# chronic obstructive pulmonary disease 84097 84134 DS
# COPD 84136 84140 DS
# acute infections 85039 85055 DS
# acute infection 85338 85353 DS
# acute infection 85654 85669 DS
# colorectal cancer 86683 86700 DS
# cancer 87254 87260 DS
# cancer 87416 87422 DS
# cancer 87534 87540 DS
# diabetes 88408 88416 DS
# type 2 diabetes 88856 88871 DS
# Diabetes 89058 89066 DS
# congestive heart failure 90156 90180 DS
# chronically ill 91115 91130 DS
# chronically ill 91792 91807 DS
# chronic illnesses 92027 92044 DS
# infection 93012 93021 DS
# infection 93393 93402 DS
# stroke 95041 95047 DS
# stroke 95145 95151 DS
# stroke 95236 95242 DS
# ventricular tachycardia 96802 96825 DS
# ventricular fibrillation 96827 96851 DS
# supraventricular tachycardia 96905 96933 DS
# cardioverter-defibrillator failure 97343 97377 DS
# heart failure 97634 97647 DS
# heart failure 97981 97994 DS
# heart failure 98095 98108 DS
# heart failure 98134 98147 DS
# heart failure 98324 98337 DS
# prostate cancer 98575 98590 DS
# CD 98752 98754 DS
# cancer 98819 98825 DS
# prostate cancer 99290 99305 DS
# diabetes 100136 100144 DS
# diabetes 100733 100741 DS
# angiotensin-converting enzyme 102299 102328 GP
# chronic heart failure 103076 103097 DS
# HF 104287 104289 DS
# HF 104907 104909 DS
# obstructive sleep apnea 106725 106748 DS
# sleep apnea 107401 107412 DS
# chronic illness 109924 109939 DS
# chronic illness 110142 110157 DS
# chronic illness 110469 110484 DS
# heart failure 110877 110890 DS
# hypertension 112602 112614 DS
# chronic obstructive pulmonary disease 113231 113268 DS
# COPD 113270 113274 DS
# and/or congestive heart failure 113276 113307 DS
# COPD 113354 113358 DS
# asthma 113889 113895 DS
# asthma 114001 114007 DS
# asthma 114044 114050 DS
# asthma 114090 114096 DS
# Asthma 114163 114169 DS
# asthma 114417 114423 DS
# asthma 114496 114502 DS
# stroke 114663 114669 DS
# insulin 115050 115057 GP
# chronic respiratory failure 115932 115959 DS
# CRF 115961 115964 GP
# chronic respiratory failure 116620 116647 DS
# COPD 116894 116898 DS
# chronic respiratory failure 117131 117158 DS
# chronic obstructive pulmonary disease 117299 117336 DS
# heart failure 118145 118158 DS
# heart failure 118512 118525 DS
# heart disease 118690 118703 DS

# %%
import time
import glob
import os
import json

article_path = '/nfs/gns/literature/machine-learning/evaluation/time_complexity/articles/'
all_files = sorted(glob.glob(article_path + '*.txt*'))
result_json_dump_path = '/nfs/gns/literature/machine-learning/evaluation/time_complexity/en-pubmed-pmc-lg/'

offset = 26

already_processed_files = sorted(glob.glob(result_json_dump_path + '*.json*'))
names = [os.path.basename(x) for x in already_processed_files]
already_processed_PMC_ids = [x[:-5]+'.json' for x in names]

# article_file_path = article_path+'PMC3649237_sentences.txt'

for article_file_path in all_files:
    
    result_file_name = os.path.basename(article_file_path)[:-4] + '.json'
    
    if not result_file_name in already_processed_PMC_ids:
        with open(article_file_path, 'r') as f:
            article_contents = f.read()

            tstart = time.time()

#             predicted_sentences = flair_model.predict(sentences)
            doc = nlp2(article_contents)
            entity_dict={}
            all_entities = []
            list_names = ['exact', 'prefix','postfix','entity','ground']

            for ent in doc.ents:
#                 print(ent.text, ent.start_char, ent.end_char, ent.label_)
                exact = ent.text
                prefix = article_contents[ent.start_char-offset:ent.start_char-1]
                postfix = article_contents[ent.end_char+1:ent.end_char+offset]
                entity = ent.label_
                normalise = ground_annotation(exact,entity)
                data_names = [exact, prefix,postfix,entity,normalise]
                all_entities.append(dict(zip(list_names,data_names)))

            tend = time.time()
            t_elapsed = round(tend - tstart)
            print(t_elapsed) 

            entity_dict['tagged_entities'] = all_entities
            entity_dict['time_taken'] = t_elapsed

            with open(result_json_dump_path+result_file_name, 'w') as outfile:
                json.dump(entity_dict, outfile)
# Out:
# 5
# 3
# 16
# 6
# 10
# 2
# 2
# 7
# 5
# 7
# 9
# 1
# 5
# 4
# 8
# 6
# 17
# 4
# 21
# 5
# 10
# 3
# 4
# 9
# 17
# 32
# 12
# 10
# 8
# 11
# 5
# 10
# 7
# 2
# 20
# 25
# 5
# 19
# 10
# 5
# 5
# 10
# 10
# 17
