# %%
# Here I am using gensim for learning the word embeddings from the EUADR corpus
# This is just a rough start to learn 
import gensim
import logging
import os
import pandas as pd

# %%
# start the log
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO)

# %%
# get the current working directory
data_path = os.path.abspath(os.path.join(os.path.dirname( '__file__' ), '..', 'Datasets'))+'/'

# Although the dataset says csv, it is tab delimited. In addition to this, they have severe codels problems. 
# So best to parse throught codes first. 
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 2: invalid start byte

#open for reading with "universal" type set

import codecs

doc_d_t = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_drug_target'+'.csv','rU','UTF-8') 
EUADR_drug_target = pd.read_csv(doc_d_t, sep='\t', na_filter = False)
EUADR_drug_target['CLASS'] = 'drug_gene'

doc_t_d = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_target_disease'+'.csv','rU','UTF-8',errors='ignore') 
EUADR_target_disease = pd.read_csv(doc_t_d, sep='\t', na_filter = False)
EUADR_target_disease['CLASS'] = 'gene_disease'
       
doc_d_d = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_drug_disease'+'.csv','rU','UTF-8')                       
EUADR_drug_disease = pd.read_csv(doc_d_d, sep='\t', na_filter = False)
EUADR_drug_disease['CLASS'] = 'drug_disease'

logging.info("Done reading data files")
# Out:
# 2019-07-04 16:53:29,542 : INFO : Done reading data files

# %%
dataset =  EUADR_drug_target.append(EUADR_target_disease).append(EUADR_drug_disease)

# %%
dataset.head(10)
# Out:
#   ASSOCIATION_TYPE      PMID  NUM_SENTENCE            ENTITY1_TEXT  \
# 0               PA  17938326             0                   ABCG2
# 1               PA  17938326             5                    EGFR
# 2               PA  17938326             0                   ABCG2
# 3               PA  17938326             2  ABCG2 drug transporter
# 4               PA  17938326            12                    EGFR
# 5               PA  17938326             8  ABCG2 drug transporter
# 6               PA  17938326             6                   ABCG2
# 7               PA  17938326             9                   ABCG2
# 8               PA  17938326            12                    EGFR
# 9               PA  17938326             8                    EGFR
#
#    ENTITY1_INI  ENTITY1_END                 ENTITY1_TYPE ENTITY2_TEXT  \
# 0           71           76  Genes & Molecular Sequences  doxorubicin
# 1           16           20  Genes & Molecular Sequences    gefitinib
# 2           71           76  Genes & Molecular Sequences    Gefitinib
# 3          161          183  Genes & Molecular Sequences  doxorubicin
# 4           20           24  Genes & Molecular Sequences    gefitinib
# 5           80          102  Genes & Molecular Sequences  doxorubicin
# 6          128          133  Genes & Molecular Sequences  doxorubicin
# 7          126          131  Genes & Molecular Sequences  doxorubicin
# 8           20           24  Genes & Molecular Sequences  doxorubicin
# 9           14           18  Genes & Molecular Sequences  doxorubicin
#
#    ENTITY2_INI  ENTITY2_END       ENTITY2_TYPE  \
# 0           43           54  Chemicals & Drugs
# 1           31           40  Chemicals & Drugs
# 2            0            9  Chemicals & Drugs
# 3          140          151  Chemicals & Drugs
# 4           35           44  Chemicals & Drugs
# 5          173          184  Chemicals & Drugs
# 6          172          183  Chemicals & Drugs
# 7           93          104  Chemicals & Drugs
# 8          173          184  Chemicals & Drugs
# 9          173          184  Chemicals & Drugs
#
#                                             SENTENCE      CLASS
# 0  Gefitinib inhibition of drug resistance to dox...  drug_gene
# 1  Inactivation of EGFR kinase by gefitinib was a...  drug_gene
# 2  Gefitinib inhibition of drug resistance to dox...  drug_gene
# 3  Extrusion assays using flow cytometry analysis...  drug_gene
# 4  Inactivation of the EGFR kinase by gefitinib p...  drug_gene
# 5  Inhibition of EGFR kinase activity by gefitini...  drug_gene
# 6  A terminal deoxynucleotidyl transferase-mediat...  drug_gene
# 7  Both ARO and WRO demonstrated differential ABC...  drug_gene
# 8  Inactivation of the EGFR kinase by gefitinib p...  drug_gene
# 9  Inhibition of EGFR kinase activity by gefitini...  drug_gene

# %%
import nltk

from nltk.tokenize import word_tokenize

# use boolean flags to customize function
def tokenise_text(text):

    # Step 2: Tokenize
    output = word_tokenize(text)
    return(output)

# %%
dataset['SENTENCE_normalised'] = [tokenise_text(article) for article in dataset['SENTENCE']]

# %%
# convert text into doc2vec input format i.e. tuple containing list of tokens and index for each doc
from gensim.models.doc2vec import TaggedDocument

def doc_tagger(data, tokens_col_name, class_col_name):
    return(data.apply(lambda r: TaggedDocument(words=r[tokens_col_name], tags=[r[class_col_name]]), axis=1))


# Specify parameters for doc2vec: DBOW with word2vec training
from gensim.models.doc2vec import Doc2Vec

def train_doc2vec_model(corpus, vec_size, window, n_epochs, n_cpu):
    
    docs = corpus.values
    doc2vec_model = Doc2Vec(docs, vector_size=vec_size, window=window, epochs=n_epochs, dm=0, dbow_words=1, workers=n_cpu)
    
    return(doc2vec_model)

def learn_vectors(doc2vec_model, corpus):
    
    docs = corpus.values
    labels, feats = zip(*[(doc.tags[0], doc2vec_model.infer_vector(doc[0], steps=20)) for doc in docs])
    
    return(feats, labels)

# %%
train_tagged = doc_tagger(dataset, 'SENTENCE_normalised', 'CLASS')

# %%
import multiprocessing

doc2vec_model = train_doc2vec_model(train_tagged, vec_size=10, window=10, n_epochs=20, n_cpu=multiprocessing.cpu_count())
# Out:
# 2019-07-04 17:04:05,079 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-07-04 17:04:05,081 : INFO : collecting all words and their counts
# 2019-07-04 17:04:05,084 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-07-04 17:04:05,098 : INFO : collected 3311 word types and 3 unique tags from a corpus of 846 examples and 27842 words
# 2019-07-04 17:04:05,099 : INFO : Loading a fresh vocabulary
# 2019-07-04 17:04:05,103 : INFO : min_count=5 retains 1048 unique words (31% of original 3311, drops 2263)
# 2019-07-04 17:04:05,105 : INFO : min_count=5 leaves 23239 word corpus (83% of original 27842, drops 4603)
# 2019-07-04 17:04:05,108 : INFO : deleting the raw counts dictionary of 3311 items
# 2019-07-04 17:04:05,109 : INFO : sample=0.001 downsamples 45 most-common words
# 2019-07-04 17:04:05,110 : INFO : downsampling leaves estimated 15972 word corpus (68.7% of prior 23239)
# 2019-07-04 17:04:05,112 : INFO : estimated required memory for 1048 words and 10 dimensions: 608560 bytes
# 2019-07-04 17:04:05,113 : INFO : resetting layer weights
# 2019-07-04 17:04:05,121 : INFO : training model with 16 workers on 1048 vocabulary and 10 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2019-07-04 17:04:05,130 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17
: INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:04:07,357 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:04:07,360 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:04:07,361 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:04:07,363 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:04:07,364 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:04:07,368 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:04:07,373 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:04:07,379 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:04:07,386 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:04:07,389 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:04:07,450 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:04:07,462 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:04:07,469 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:04:07,470 : INFO : EPOCH - 16 : training on 27842 raw words (16823 effective words) took 0.1s, 133951 effective words/s
# 2019-07-04 17:04:07,481 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:04:07,485 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:04:07,488 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:04:07,492 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:04:07,495 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:04:07,497 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:04:07,501 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:04:07,504 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:04:07,507 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:04:07,508 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:04:07,510 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:04:07,513 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:04:07,515 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:04:07,581 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:04:07,602 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:04:07,605 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:04:07,605 : INFO : EPOCH - 17 : training on 27842 raw words (16810 effective words) took 0.1s, 132965 effective words/s
# 2019-07-04 17:04:07,617 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:04:07,621 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:04:07,623 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:04:07,628 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:04:07,633 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:04:07,636 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:04:07,638 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:04:07,641 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:04:07,643 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:04:07,645 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:04:07,648 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:04:07,650 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:04:07,653 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:04:07,723 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:04:07,741 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:04:07,747 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:04:07,748 : INFO : EPOCH - 18 : training on 27842 raw words (16754 effective words) took 0.1s, 126193 effective words/s
# 2019-07-04 17:04:07,760 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:04:07,763 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:04:07,766 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:04:07,769 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:04:07,772 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:04:07,775 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:04:07,777 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:04:07,780 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:04:07,781 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:04:07,785 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:04:07,788 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:04:07,791 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:04:07,793 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:04:07,883 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:04:07,893 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:04:07,896 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:04:07,898 : INFO : EPOCH - 19 : training on 27842 raw words (16839 effective words) took 0.1s, 121401 effective words/s
# 2019-07-04 17:04:07,909 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:04:07,912 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:04:07,916 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:04:07,921 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:04:07,923 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:04:07,924 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:04:07,925 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:04:07,928 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:04:07,930 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:04:07,932 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:04:07,936 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:04:07,937 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:04:07,940 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:04:08,007 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:04:08,025 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:04:08,033 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:04:08,035 : INFO : EPOCH - 20 : training on 27842 raw words (16863 effective words) took 0.1s, 134473 effective words/s
# 2019-07-04 17:04:08,036 : INFO : training on a 556840 raw words (336357 effective words) took 2.9s, 115444 effective words/s
# 2019-07-04 17:04:08,037 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
doc2vec_model.wv.most_similar('MDR1', topn=10)
# Out:
# 2019-07-04 17:04:09,768 : INFO : precomputing L2-norms of word weight vectors
# [('adults', 0.9315659999847412),
#  ('Previous', 0.9239931106567383),
#  ('systemic', 0.9200870990753174),
#  ('Recently', 0.9191992282867432),
#  ('a', 0.9117146730422974),
#  ('TNFSF4', 0.9076061844825745),
#  ('genome-wide', 0.9035455584526062),
#  ('HIV-1', 0.8988310694694519),
#  ('COL1A2', 0.8981502652168274),
#  ('there', 0.8970949649810791)]

# %%
# from scipy import spatial

sentence = 'However, the majority of colon cancer cells have deregulation of the Wnt/beta-catenin pathway.'

inferred_vector=doc2vec_model.infer_vector(sentence.split())

# print (1-  spatial.distance.cosine(inferred_vector,doc2vec_model.docvecs['SA']))
sims = doc2vec_model.docvecs.most_similar([inferred_vector], topn=len(doc2vec_model.docvecs))
sims
# Out:
# [('drug_gene', 0.8196185231208801),
#  ('drug_disease', 0.5184629559516907),
#  ('gene_disease', 0.4750712513923645)]
