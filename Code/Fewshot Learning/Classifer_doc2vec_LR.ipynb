# %%
# Here I am using gensim for learning the word embeddings from the EUADR corpus
# This is just a rough start to learn 
import gensim
import logging
import os
import pandas as pd

# %%
# start the log
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO)

# %%
# get the current working directory
data_path = os.path.abspath(os.path.join(os.path.dirname( '__file__' ), '..', 'Datasets'))+'/'

# Although the dataset says csv, it is tab delimited. In addition to this, they have severe codels problems. 
# So best to parse throught codes first. 
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 2: invalid start byte

#open for reading with "universal" type set

import codecs

doc_d_t = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_drug_target'+'.csv','rU','UTF-8') 
EUADR_drug_target = pd.read_csv(doc_d_t, sep='\t', na_filter = False)
EUADR_drug_target['CLASS'] = 'drug_gene'

doc_t_d = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_target_disease'+'.csv','rU','UTF-8',errors='ignore') 
EUADR_target_disease = pd.read_csv(doc_t_d, sep='\t', na_filter = False)
EUADR_target_disease['CLASS'] = 'gene_disease'
       
doc_d_d = codecs.open(data_path+'EUADR_Corpus_IBIgroup/'+'EUADR_drug_disease'+'.csv','rU','UTF-8')                       
EUADR_drug_disease = pd.read_csv(doc_d_d, sep='\t', na_filter = False)
EUADR_drug_disease['CLASS'] = 'drug_disease'

logging.info("Done reading data files")
# Out:
# 2019-07-04 17:27:12,394 : INFO : Done reading data files

# %%
FO_data =  EUADR_drug_target.append(EUADR_target_disease).append(EUADR_drug_disease)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# use boolean flags to customize function
def normalize_text(text, lowercase=True, punctuation=True, prune_stopwords=True, stem=True, join=True):
    
    # Step 1: Separate hyphenated words so they are not filtered when punctuation is removed (e.g. London-based)
    output = text.replace('-', ' ')
    
    # Step 2: Tokenize
    output = word_tokenize(output)
    
    # Step 3: Convert to lowercase (optional)
    if lowercase:
        output = [word.lower() for word in output]
        
    # Step 4: Remove punctuation and numbers (optional)
    if punctuation:
        output = [word for word in output if word.isalpha()]
    
    # Step 5: Remove stopwords (optional)
    if prune_stopwords:
        stop = set(stopwords.words('english'))
        output = [word for word in output if not word in stop]
    
    # Step 6: Stem words (optional)
    if stem:
        porter = PorterStemmer()
        output = [porter.stem(word) for word in output]
        
    # Step 7: Join words with spaces to obtain a single string (optional)
    if join: 
        output = ' '.join(output)

    return(output)
# Out:
# [nltk_data] Downloading package punkt to /home/stirunag/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/stirunag/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
FO_data['article_normalized'] = [normalize_text(article, lowercase=True, punctuation=True, prune_stopwords=True, stem=False, join=False) for article in FO_data['SENTENCE']]

# %%
# convert text into doc2vec input format i.e. tuple containing list of tokens and index for each doc
from gensim.models.doc2vec import TaggedDocument

def doc_tagger(data, tokens_col_name, class_col_name):
    return(data.apply(lambda r: TaggedDocument(words=r[tokens_col_name], tags=[r[class_col_name]]), axis=1))


# Specify parameters for doc2vec: DBOW with word2vec training
from gensim.models.doc2vec import Doc2Vec

def train_doc2vec_model(corpus, vec_size, window, n_epochs, n_cpu):
    
    docs = corpus.values
    doc2vec_model = Doc2Vec(docs, vector_size=vec_size, window=window, epochs=n_epochs, dm=0, dbow_words=1, workers=n_cpu)
    
    return(doc2vec_model)

def learn_vectors(doc2vec_model, corpus):
    
    docs = corpus.values
    labels, feats = zip(*[(doc.tags[0], doc2vec_model.infer_vector(doc[0], steps=20)) for doc in docs])
    
    return(feats, labels)

# %%
from sklearn import model_selection

FO_train, FO_test = model_selection.train_test_split(FO_data)

# %%
FO_train_tagged = doc_tagger(FO_train, 'article_normalized', 'CLASS')
FO_test_tagged = doc_tagger(FO_test, 'article_normalized', 'CLASS')

# %%
import multiprocessing

FO_doc2vec_model = train_doc2vec_model(FO_train_tagged, vec_size=100, window=10, n_epochs=20, n_cpu=multiprocessing.cpu_count())
# Out:
# 2019-07-04 17:27:14,165 : INFO : collecting all words and their counts
# 2019-07-04 17:27:14,167 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-07-04 17:27:14,174 : INFO : collected 2229 word types and 3 unique tags from a corpus of 634 examples and 10765 words
# 2019-07-04 17:27:14,176 : INFO : Loading a fresh vocabulary
# 2019-07-04 17:27:14,179 : INFO : min_count=5 retains 629 unique words (28% of original 2229, drops 1600)
# 2019-07-04 17:27:14,179 : INFO : min_count=5 leaves 7695 word corpus (71% of original 10765, drops 3070)
# 2019-07-04 17:27:14,182 : INFO : deleting the raw counts dictionary of 2229 items
# 2019-07-04 17:27:14,183 : INFO : sample=0.001 downsamples 86 most-common words
# 2019-07-04 17:27:14,184 : INFO : downsampling leaves estimated 6753 word corpus (87.8% of prior 7695)
# 2019-07-04 17:27:14,185 : INFO : estimated required memory for 629 words and 100 dimensions: 819500 bytes
# 2019-07-04 17:27:14,187 : INFO : resetting layer weights
# 2019-07-04 17:27:14,200 : INFO : training model with 16 workers on 629 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2019-07-04 17:27:14,212 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,216 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,219 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,220 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,221 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,222 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,224 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,227 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,228 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,236 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,238 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,242 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,246 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,249 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,257 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,302 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,303 : INFO : EPOCH - 1 : training on 10765 raw words (7388 effective words) took 0.1s, 81441 effective words/s
# 2019-07-04 17:27:14,309 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,314 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,317 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,319 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,323 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,325 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,329 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,332 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,334 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,336 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,338 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,340 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,342 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,351 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,406 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,408 : INFO : EPOCH - 2 : training on 10765 raw words (7408 effective words) took 0.1s, 75140 effective words/s
# 2019-07-04 17:27:14,416 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,419 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,422 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,424 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,425 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,428 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,430 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,432 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,434 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,436 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,438 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,442 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,446 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,448 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,460 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,515 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,516 : INFO : EPOCH - 3 : training on 10765 raw words (7379 effective words) took 0.1s, 73848 effective words/s
# 2019-07-04 17:27:14,529 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,535 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,539 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,543 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,544 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,547 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,550 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,551 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,553 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,555 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,557 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,559 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,561 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,563 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,569 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,608 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,609 : INFO : EPOCH - 4 : training on 10765 raw words (7399 effective words) took 0.1s, 92540 effective words/s
# 2019-07-04 17:27:14,623 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,629 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,633 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,635 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,638 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,640 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,643 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,646 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,652 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,655 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,659 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,664 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,666 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,670 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,677 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,722 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,723 : INFO : EPOCH - 5 : training on 10765 raw words (7388 effective words) took 0.1s, 74111 effective words/s
# 2019-07-04 17:27:14,733 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,735 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,736 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,741 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,745 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,748 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,749 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,751 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,753 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,759 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,760 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,763 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,763 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,768 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,777 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,819 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,820 : INFO : EPOCH - 6 : training on 10765 raw words (7380 effective words) took 0.1s, 82756 effective words/s
# 2019-07-04 17:27:14,828 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,830 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,833 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,833 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,835 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,837 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,838 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,840 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,844 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,847 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,849 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,852 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,853 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,856 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,862 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:14,910 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:14,911 : INFO : EPOCH - 7 : training on 10765 raw words (7418 effective words) took 0.1s, 88182 effective words/s
# 2019-07-04 17:27:14,919 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:14,922 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:14,926 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:14,929 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:14,932 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:14,933 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:14,936 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:14,936 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:14,939 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:14,942 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:14,944 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:14,947 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:14,948 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:14,951 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:14,957 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,012 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,013 : INFO : EPOCH - 8 : training on 10765 raw words (7384 effective words) took 0.1s, 78368 effective words/s
# 2019-07-04 17:27:15,023 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,025 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,029 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,032 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,034 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,036 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,037 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,039 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,040 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,043 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,050 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,052 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,053 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,056 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,063 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,106 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,108 : INFO : EPOCH - 9 : training on 10765 raw words (7417 effective words) took 0.1s, 87226 effective words/s
# 2019-07-04 17:27:15,116 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,119 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,121 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,124 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,127 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,129 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,132 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,134 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,138 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,140 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,143 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,145 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,150 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,153 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,160 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,213 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,214 : INFO : EPOCH - 10 : training on 10765 raw words (7382 effective words) took 0.1s, 75348 effective words/s
# 2019-07-04 17:27:15,227 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,230 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,232 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,233 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,235 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,237 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,238 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,241 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,242 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,244 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,245 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,247 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,248 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,251 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,258 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,305 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,306 : INFO : EPOCH - 11 : training on 10765 raw words (7402 effective words) took 0.1s, 93766 effective words/s
# 2019-07-04 17:27:15,314 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,318 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,320 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,321 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,322 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,328 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,329 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,333 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,335 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,337 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,339 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,341 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,343 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,350 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,402 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,405 : INFO : EPOCH - 12 : training on 10765 raw words (7379 effective words) took 0.1s, 80984 effective words/s
# 2019-07-04 17:27:15,419 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,421 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,423 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,427 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,431 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,434 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,435 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,436 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,439 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,440 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,445 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,448 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,450 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,455 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,504 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,506 : INFO : EPOCH - 13 : training on 10765 raw words (7392 effective words) took 0.1s, 84675 effective words/s
# 2019-07-04 17:27:15,516 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,520 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,523 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,525 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,527 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,529 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,534 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,537 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,538 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,541 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,544 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,545 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,547 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,549 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,557 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,597 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,599 : INFO : EPOCH - 14 : training on 10765 raw words (7405 effective words) took 0.1s, 86137 effective words/s
# 2019-07-04 17:27:15,608 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,611 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,613 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,615 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,616 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,619 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,621 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,623 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,624 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,627 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,629 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,632 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,635 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,636 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,644 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,686 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,687 : INFO : EPOCH - 15 : training on 10765 raw words (7425 effective words) took 0.1s, 92790 effective words/s
# 2019-07-04 17:27:15,696 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,698 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,701 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,704 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,708 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,711 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,715 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,718 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,720 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,722 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,725 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,726 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,728 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,730 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,739 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,779 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,779 : INFO : EPOCH - 16 : training on 10765 raw words (7376 effective words) took 0.1s, 88103 effective words/s
# 2019-07-04 17:27:15,788 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,792 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,793 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,795 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,799 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,800 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,802 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,804 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,807 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,810 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,812 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,814 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,816 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,818 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,825 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,871 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,872 : INFO : EPOCH - 17 : training on 10765 raw words (7423 effective words) took 0.1s, 87870 effective words/s
# 2019-07-04 17:27:15,884 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,889 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,891 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,894 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,899 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,901 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,904 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,907 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,909 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:15,911 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:15,912 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:15,915 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:15,917 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:15,920 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:15,927 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:15,966 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:15,967 : INFO : EPOCH - 18 : training on 10765 raw words (7363 effective words) took 0.1s, 88735 effective words/s
# 2019-07-04 17:27:15,981 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:15,984 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:15,985 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:15,988 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:15,989 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:15,992 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:15,993 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:15,995 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:15,997 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:16,001 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:16,004 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:16,006 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:16,009 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:16,010 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:16,020 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:16,062 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:16,063 : INFO : EPOCH - 19 : training on 10765 raw words (7411 effective words) took 0.1s, 88661 effective words/s
# 2019-07-04 17:27:16,071 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2019-07-04 17:27:16,073 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2019-07-04 17:27:16,077 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2019-07-04 17:27:16,079 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2019-07-04 17:27:16,082 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-07-04 17:27:16,084 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-07-04 17:27:16,086 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-07-04 17:27:16,087 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-07-04 17:27:16,093 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-07-04 17:27:16,095 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-07-04 17:27:16,097 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-07-04 17:27:16,100 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-07-04 17:27:16,102 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-07-04 17:27:16,103 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-04 17:27:16,109 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-04 17:27:16,148 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-04 17:27:16,149 : INFO : EPOCH - 20 : training on 10765 raw words (7414 effective words) took 0.1s, 95392 effective words/s
# 2019-07-04 17:27:16,150 : INFO : training on a 215300 raw words (147933 effective words) took 1.9s, 75898 effective words/s
# 2019-07-04 17:27:16,151 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# vectorize training data for classification
FO_train_X, FO_train_y = learn_vectors(FO_doc2vec_model, FO_train_tagged)
FO_test_X, FO_test_y = learn_vectors(FO_doc2vec_model, FO_test_tagged)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

FO_train_y_le = le.fit_transform(FO_train_y)
FO_test_y_le = le.fit_transform(FO_test_y)

# %%
from sklearn import metrics

# general classifier model function
def classifier(model, train_feats, train_labels, test_feats, test_labels):
    
    # define model
    clf = model
    
    # train model
    clf.fit(train_feats, train_labels)
    
    # predict labels for test set
    preds = clf.predict(test_feats)
    accuracy = metrics.accuracy_score(test_labels, preds)
    
    return accuracy

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

O_logreg_test_acc = np.round(100*classifier(LogisticRegression(), FO_train_X, FO_train_y_le, FO_test_X, FO_test_y_le), 2)

FO_logreg_test_acc
# Out:
# /home/stirunag/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/stirunag/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 83.49

# %%
FO_doc2vec_model.wv.most_similar('cancer', topn=10)

# %%
text = 'On multivariate analysis the CYP3A5 A6986G genotype *3/*3 (OR 8.205, 95% CI 1.616-41.667, p = 0.011) and smaller number of treatment cycles (OR 0.156, 95% CI 0.037-0.659, p = 0.011) were independent factors for leukocytopenia (grade 3 or greater) throughout the period of chemotherapy.'
text_normed = normalize_text(text, lowercase=True, punctuation=True, prune_stopwords=True, stem=False, join=False)
vec = FO_doc2vec_model.infer_vector(text_normed, steps=20)

# %%
from sklearn import metrics

# general classifier model function
def classifier(model, train_feats, train_labels, test_feats, test_labels):
    
    # define model
    clf = model
    
    # train model
    clf.fit(train_feats, train_labels)
    
    # predict labels for test set
    preds = clf.predict(test_feats)
    accuracy = metrics.accuracy_score(test_labels, preds)
    
    return clf

model_lr = classifier(LogisticRegression(), FO_train_X, FO_train_y_le, FO_test_X, FO_test_y_le)
# Out:
# /home/stirunag/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/stirunag/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
print(model_lr.predict_proba(vec.reshape(1, -1)))

le.inverse_transform(model_lr.predict(vec.reshape(1, -1)))
# Out:
# [[0.57649396 0.23467165 0.18883439]]
# array(['drug_disease'], dtype='<U12')
